# %% [markdown]
# - **Hypothesis 1.** Having more components means that the latent space is disturbed more by the prior loss, hence the reconstruction loss should be higher. **Conclusion.** Results show that this is not true.
#
# - **Hypothesis 2.** Having more components could mean that some components overlap significantly. Try this with a latent space of 2 dimensions.

# %%
import json
import matplotlib.pyplot as plt

# %%
def load_json(json_fname):
    with open(json_fname, 'r') as json_f:
        return np.array(json.load(json_f)['valid_history_rec'])

# %%
comps = [2, 4, 6, 8, 10, 12, 28]

for i in comps:
    try:
        plt.plot(load_json(f'rec_history_{i}.json'), label=f'{i} comp.')
    except:
        pass
    
plt.ylabel('Reconstruction loss'); plt.xlabel('Epoch')
plt.legend()
plt.show()
