# %% [markdown]
# # GM-VAE for SMB

# %%
num_epochs=10000
num_components=2  # only the starting number of components

# %% [markdown]
# ## Import Libraries

# %%
import json

import numpy as np
import argparse
import random
from torchvision import datasets, transforms
from torch.utils.data import TensorDataset, DataLoader
from torch.utils.data.sampler import SubsetRandomSampler
import torch.utils.data
from scipy.io import loadmat

import sys
sys.path.append('/home/yangz2/projects/gmvae_and_gmmvae/pytorch/')
sys.path.append('../../1906-pcgml/pcgml-gmmVae-exp/modules/')
import vglc_with_path_encodings

from model.GMVAE import *
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

import warnings
warnings.filterwarnings('ignore')

import sys
sys.path.append('/home/yangz2/projects/modules/')
from log_training_progress import email_training_progress

# %% [markdown]
# ## Load data

# %%
def open_json_as_nparray(json_fname):
    with open(json_fname, 'r') as json_f:
        return np.array(json.load(json_f))

# %%
chunks_int = open_json_as_nparray('/home/yangz2/projects/gmvae_and_gmmvae/data/smba_chunks_int.json')
chunks_onehot = np.eye(len(np.unique(chunks_int)))[chunks_int]
chunks_onehot.shape
# Out:
# (2698, 16, 16, 12)

# %%
chunks_onehot = chunks_onehot.reshape(
    chunks_onehot.shape[0], 
    chunks_onehot.shape[1] * chunks_onehot.shape[2] * chunks_onehot.shape[3]
)
chunks_onehot.shape
# Out:
# (2698, 3072)

# %%
def get_random_labels(num_components, size):
    return np.random.randint(num_components, size=size)

# %% [markdown]
# ## Input Parameters

# %%
num_components = 8

# %%
########################################################
## Input Parameters
#########################################################
parser = argparse.ArgumentParser(description='PyTorch Implementation of DGM Clustering')

## Used only in notebooks
parser.add_argument('-f', '--file',
                    help='Path for input file. First line should contain number of lines to search in')

## Dataset
parser.add_argument('--dataset', type=str, choices=['mnist'],
                    default='mnist', help='dataset (default: mnist)')
parser.add_argument('--seed', type=int, default=1, help='random seed (default: 1)')

## GPU
parser.add_argument('--cuda', type=int, default=1,
                    help='use of cuda (default: 1)')
parser.add_argument('--gpuID', type=int, default=0,
                    help='set gpu id to use (default: 0)')

## Training
parser.add_argument('--epochs', type=int, default=num_epochs,
                    help='number of total epochs to run (default: 200)')
parser.add_argument('--batch_size', default=64, type=int,
                    help='mini-batch size (default: 64)')
parser.add_argument('--batch_size_val', default=200, type=int,
                    help='mini-batch size of validation (default: 200)')
parser.add_argument('--learning_rate', default=1e-3, type=float,
                    help='learning rate (default: 0.001)')
parser.add_argument('--decay_epoch', default=-1, type=int, 
                    help='Reduces the learning rate every decay_epoch')
parser.add_argument('--lr_decay', default=0.5, type=float,
                    help='Learning rate decay for training (default: 0.5)')

## Architecture
parser.add_argument('--num_classes', type=int, default=num_components,
                    help='number of classes (default: 10)')  # edited for this task
parser.add_argument('--gaussian_size', default=64, type=int,
                    help='gaussian size (default: 64)')
parser.add_argument('--input_size', default=3072, type=int,
                    help='input size (default: 784)')  # edited for this task

## Partition parameters
parser.add_argument('--train_proportion', default=1, type=float,
                    help='proportion of examples to consider for training only (default: 1.0)')

## Gumbel parameters
parser.add_argument('--init_temp', default=1.0, type=float,
                    help='Initial temperature used in gumbel-softmax (recommended 0.5-1.0, default:1.0)')
parser.add_argument('--decay_temp', default=1, type=int, 
                    help='Set 1 to decay gumbel temperature at every epoch (default: 1)')
parser.add_argument('--hard_gumbel', default=0, type=int, 
                    help='Set 1 to use the hard version of gumbel-softmax (default: 1)')
parser.add_argument('--min_temp', default=0.5, type=float, 
                    help='Minimum temperature of gumbel-softmax after annealing (default: 0.5)' )
parser.add_argument('--decay_temp_rate', default=0.013862944, type=float,
                    help='Temperature decay rate at every epoch (default: 0.013862944)')

## Loss function parameters
parser.add_argument('--w_gauss', default=2, type=float,
                    help='weight of gaussian loss (default: 1)')
parser.add_argument('--w_categ', default=1, type=float,
                    help='weight of categorical loss (default: 1)')
parser.add_argument('--w_rec', default=1, type=float,
                    help='weight of reconstruction loss (default: 1)')
parser.add_argument('--rec_type', type=str, choices=['bce', 'mse'],
                    default='bce', help='desired reconstruction loss function (default: bce)')

## Others
parser.add_argument('--verbose', default=0, type=int,
                    help='print extra information at every epoch.(default: 0)')

args = parser.parse_args()

# %% [markdown]
# Set random seed in case it was specified in the parameters

# %%
## Random Seed
SEED = args.seed
np.random.seed(SEED)
random.seed(SEED)
torch.manual_seed(SEED)
if args.cuda:
    torch.cuda.manual_seed(SEED)

# %% [markdown]
# ## Data Partition

# %% [markdown]
# We split the training data into train and validation according to the *train_proportion* parameter:

# %%
def get_train_dl_and_valid_dl(chunks, labels):

    valid_indices = np.random.randint(len(chunks), size=100)
    train_chunks, valid_chunks = chunks, chunks[valid_indices]
    train_labels, valid_labels = labels, labels[valid_indices]

    train_ds = TensorDataset(torch.from_numpy(train_chunks).float(), torch.from_numpy(train_labels).long())
    valid_ds = TensorDataset(torch.from_numpy(valid_chunks).float(), torch.from_numpy(valid_labels).long())

    train_dl = DataLoader(train_ds, batch_size=args.batch_size, shuffle=True)
    valid_dl = DataLoader(valid_ds, batch_size=args.batch_size_val, shuffle=False)
    
    return train_dl, valid_dl

# %% [markdown]
# ## Train Model

# %%
email_training_progress(f'Training session has started!')
for num_components in [30, 40, 50]:
    
    args.num_classes = num_components
    gmvae = GMVAE(args)
    
    labels = get_random_labels(num_components, len(chunks_onehot))
    train_dl, valid_dl = get_train_dl_and_valid_dl(chunks_onehot, labels)
    gmvae.train(train_dl, valid_dl)
    
    torch.save(
        gmvae.network.state_dict(),
        f'../qualitative_clustering_analysis/smba_gmvae_{num_components}_{num_epochs}.pth'
    )
    
    email_training_progress(f'GM-VAE with {num_components} components has finished training!')
email_training_progress('Shutdown VM now!')
# Out:
# (Epoch 1 / 10000) Train_Loss: 470.017; Val_Loss: 245.197   Train_ACC: 11.453; Val_ACC: 15.000   Train_NMI: 0.498; Val_NMI: 0.000
# (Epoch 2 / 10000) Train_Loss: 230.271; Val_Loss: 230.489   Train_ACC: 11.601; Val_ACC: 17.000   Train_NMI: 0.429; Val_NMI: 4.793
# (Epoch 3 / 10000) Train_Loss: 227.159; Val_Loss: 227.129   Train_ACC: 12.417; Val_ACC: 22.000   Train_NMI: 0.583; Val_NMI: 10.505
# (Epoch 4 / 10000) Train_Loss: 221.750; Val_Loss: 214.051   Train_ACC: 12.231; Val_ACC: 17.000   Train_NMI: 0.922; Val_NMI: 4.065
# (Epoch 5 / 10000) Train_Loss: 213.646; Val_Loss: 210.526   Train_ACC: 12.268; Val_ACC: 21.000   Train_NMI: 0.660; Val_NMI: 10.983
# (Epoch 6 / 10000) Train_Loss: 209.701; Val_Loss: 206.910   Train_ACC: 11.935; Val_ACC: 18.000   Train_NMI: 0.550; Val_NMI: 6.826
# (Epoch 7 / 10000) Train_Loss: 204.785; Val_Loss: 201.469   Train_ACC: 12.342; Val_ACC: 23.000   Train_NMI: 0.754; Val_NMI: 13.297
# (Epoch 8 / 10000) Train_Loss: 202.071; Val_Loss: 201.431   Train_ACC: 12.009; Val_ACC: 20.000   Train_NMI: 0.667; Val_NMI: 6.299
# (Epoch 9 / 10000) Train_Loss: 199.853; Val_Loss: 197.061   Train_ACC: 12.120; Val_ACC: 23.000   Train_NMI: 0.526; Val_NMI: 11.069
# (Epoch 10 / 10000) Train_Loss: 196.747; Val_Loss: 188.107   Train_ACC: 12.305; Val_ACC: 22.000   Train_NMI: 0.514; Val_NMI: 10.353
# (Epoch 11 / 10000) Train_Loss: 194.456; Val_Loss: 187.028   Train_ACC: 12.528; Val_ACC: 20.000   Train_NMI: 0.675; Val_NMI: 9.965
# (Epoch 12 / 10000) Train_Loss: 193.233; Val_Loss: 188.376   Train_ACC: 12.565; Val_ACC: 21.000   Train_NMI: 0.518; Val_NMI: 10.133
# (Epoch 13 / 10000) Train_Loss: 190.043; Val_Loss: 182.242   Train_ACC: 12.120; Val_ACC: 23.000   Train_NMI: 0.432; Val_NMI: 9.591
# (Epoch 14 / 10000) Train_Loss: 184.713; Val_Loss: 177.246   Train_ACC: 12.676; Val_ACC: 27.000   Train_NMI: 0.639; Val_NMI: 14.187
# (Epoch 15 / 10000) Train_Loss: 182.309; Val_Loss: 174.541   Train_ACC: 12.305; Val_ACC: 22.000   Train_NMI: 0.500; Val_NMI: 14.167
# (Epoch 16 / 10000) Train_Loss: 179.692; Val_Loss: 172.302   Train_ACC: 12.565; Val_ACC: 24.000   Train_NMI: 0.529; Val_NMI: 15.322
# (Epoch 17 / 10000) Train_Loss: 176.257; Val_Loss: 169.450   Train_ACC: 11.972; Val_ACC: 24.000   Train_NMI: 0.448; Val_NMI: 16.352
# (Epoch 18 / 10000) Train_Loss: 174.056; Val_Loss: 165.139   Train_ACC: 11.972; Val_ACC: 23.000   Train_NMI: 0.535; Val_NMI: 14.807
# (Epoch 19 / 10000) Train_Loss: 172.469; Val_Loss: 164.044   Train_ACC: 12.787; Val_ACC: 23.000   Train_NMI: 0.567; Val_NMI: 15.921
# (Epoch 20 / 10000) Train_Loss: 170.943; Val_Loss: 161.778   Train_ACC: 12.009; Val_ACC: 26.000   Train_NMI: 0.501; Val_NMI: 17.570
# (Epoch 21 / 10000) Train_Loss: 168.227; Val_Loss: 159.154   Train_ACC: 12.305; Val_ACC: 26.000   Train_NMI: 0.724; Val_NMI: 18.863
# (Epoch 22 / 10000) Train_Loss: 167.622; Val_Loss: 159.019   Train_ACC: 12.046; Val_ACC: 25.000   Train_NMI: 0.562; Val_NMI: 15.775
# (Epoch 23 / 10000) Train_Loss: 166.993; Val_Loss: 157.848   Train_ACC: 12.342; Val_ACC: 25.000   Train_NMI: 0.627; Val_NMI: 20.159
# (Epoch 24 / 10000) Train_Loss: 165.554; Val_Loss: 156.624   Train_ACC: 12.417; Val_ACC: 26.000   Train_NMI: 0.654; Val_NMI: 15.583
# (Epoch 25 / 10000) Train_Loss: 164.927; Val_Loss: 157.561   Train_ACC: 12.602; Val_ACC: 24.000   Train_NMI: 0.708; Val_NMI: 13.887
# (Epoch 26 / 10000) Train_Loss: 162.967; Val_Loss: 153.229   Train_ACC: 12.454; Val_ACC: 26.000   Train_NMI: 0.754; Val_NMI: 14.406
# (Epoch 27 / 10000) Train_Loss: 161.569; Val_Loss: 151.880   Train_ACC: 12.898; Val_ACC: 25.000   Train_NMI: 0.865; Val_NMI: 18.495
# (Epoch 28 / 10000) Train_Loss: 160.938; Val_Loss: 152.243   Train_ACC: 12.305; Val_ACC: 27.000   Train_NMI: 0.760; Val_NMI: 18.780
# (Epoch 29 / 10000) Train_Loss: 158.992; Val_Loss: 151.117   Train_ACC: 12.342; Val_ACC: 24.000   Train_NMI: 0.689; Val_NMI: 16.991
# (Epoch 30 / 10000) Train_Loss: 158.190; Val_Loss: 151.158   Train_ACC: 12.083; Val_ACC: 25.000   Train_NMI: 0.650; Val_NMI: 16.545
# (Epoch 31 / 10000) Train_Loss: 157.295; Val_Loss: 147.899   Train_ACC: 12.491; Val_ACC: 22.000   Train_NMI: 0.699; Val_NMI: 16.161
# (Epoch 32 / 10000) Train_Loss: 156.986; Val_Loss: 148.155   Train_ACC: 12.380; Val_ACC: 26.000   Train_NMI: 0.795; Val_NMI: 18.870
# (Epoch 33 / 10000) Train_Loss: 156.356; Val_Loss: 147.072   Train_ACC: 12.268; Val_ACC: 24.000   Train_NMI: 0.797; Val_NMI: 18.177
# (Epoch 34 / 10000) Train_Loss: 153.749; Val_Loss: 143.885   Train_ACC: 12.454; Val_ACC: 27.000   Train_NMI: 0.731; Val_NMI: 20.149
# (Epoch 35 / 10000) Train_Loss: 153.518; Val_Loss: 144.958   Train_ACC: 12.454; Val_ACC: 26.000   Train_NMI: 0.704; Val_NMI: 22.537
# (Epoch 36 / 10000) Train_Loss: 154.047; Val_Loss: 144.679   Train_ACC: 12.602; Val_ACC: 24.000   Train_NMI: 0.601; Val_NMI: 18.383
# (Epoch 37 / 10000) Train_Loss: 151.354; Val_Loss: 142.345   Train_ACC: 12.528; Val_ACC: 22.000   Train_NMI: 0.815; Val_NMI: 17.905
# (Epoch 38 / 10000) Train_Loss: 150.670; Val_Loss: 142.506   Train_ACC: 12.157; Val_ACC: 24.000   Train_NMI: 0.778; Val_NMI: 17.064
# (Epoch 39 / 10000) Train_Loss: 150.159; Val_Loss: 142.206   Train_ACC: 12.565; Val_ACC: 23.000   Train_NMI: 0.778; Val_NMI: 17.490
# (Epoch 40 / 10000) Train_Loss: 149.614; Val_Loss: 141.980   Train_ACC: 12.417; Val_ACC: 24.000   Train_NMI: 0.633; Val_NMI: 17.971
# (Epoch 41 / 10000) Train_Loss: 148.528; Val_Loss: 139.135   Train_ACC: 12.565; Val_ACC: 23.000   Train_NMI: 0.753; Val_NMI: 17.844
# (Epoch 42 / 10000) Train_Loss: 147.450; Val_Loss: 140.650   Train_ACC: 12.491; Val_ACC: 25.000   Train_NMI: 0.660; Val_NMI: 21.929
# (Epoch 43 / 10000) Train_Loss: 147.187; Val_Loss: 138.779   Train_ACC: 12.380; Val_ACC: 23.000   Train_NMI: 0.712; Val_NMI: 17.391
# (Epoch 44 / 10000) Train_Loss: 146.999; Val_Loss: 138.483   Train_ACC: 12.454; Val_ACC: 24.000   Train_NMI: 0.644; Val_NMI: 20.231
# (Epoch 45 / 10000) Train_Loss: 145.729; Val_Loss: 135.187   Train_ACC: 12.602; Val_ACC: 21.000   Train_NMI: 0.784; Val_NMI: 18.192
# (Epoch 46 / 10000) Train_Loss: 145.910; Val_Loss: 137.752   Train_ACC: 12.454; Val_ACC: 25.000   Train_NMI: 0.653; Val_NMI: 19.486
# (Epoch 47 / 10000) Train_Loss: 144.631; Val_Loss: 137.514   Train_ACC: 12.417; Val_ACC: 24.000   Train_NMI: 0.607; Val_NMI: 16.425
# (Epoch 48 / 10000) Train_Loss: 144.269; Val_Loss: 136.189   Train_ACC: 12.454; Val_ACC: 24.000   Train_NMI: 0.670; Val_NMI: 19.930
# (Epoch 49 / 10000) Train_Loss: 142.145; Val_Loss: 135.886   Train_ACC: 12.676; Val_ACC: 27.000   Train_NMI: 0.621; Val_NMI: 22.481
# (Epoch 50 / 10000) Train_Loss: 141.211; Val_Loss: 134.911   Train_ACC: 12.824; Val_ACC: 27.000   Train_NMI: 0.729; Val_NMI: 22.219
# (Epoch 51 / 10000) Train_Loss: 140.629; Val_Loss: 132.007   Train_ACC: 12.602; Val_ACC: 24.000   Train_NMI: 0.660; Val_NMI: 21.149
# (Epoch 52 / 10000) Train_Loss: 139.417; Val_Loss: 132.209   Train_ACC: 12.417; Val_ACC: 28.000   Train_NMI: 0.601; Val_NMI: 22.810
# (Epoch 53 / 10000) Train_Loss: 138.550; Val_Loss: 132.889   Train_ACC: 12.713; Val_ACC: 24.000   Train_NMI: 0.664; Val_NMI: 20.509
# (Epoch 54 / 10000) Train_Loss: 139.461; Val_Loss: 133.350   Train_ACC: 12.750; Val_ACC: 25.000   Train_NMI: 0.617; Val_NMI: 18.271
# (Epoch 55 / 10000) Train_Loss: 138.512; Val_Loss: 127.206   Train_ACC: 12.602; Val_ACC: 28.000   Train_NMI: 0.571; Val_NMI: 23.447
# (Epoch 56 / 10000) Train_Loss: 136.486; Val_Loss: 130.019   Train_ACC: 12.676; Val_ACC: 24.000   Train_NMI: 0.659; Val_NMI: 21.009
# (Epoch 57 / 10000) Train_Loss: 136.360; Val_Loss: 129.269   Train_ACC: 12.342; Val_ACC: 25.000   Train_NMI: 0.627; Val_NMI: 20.867
# (Epoch 58 / 10000) Train_Loss: 135.717; Val_Loss: 127.014   Train_ACC: 12.936; Val_ACC: 25.000   Train_NMI: 0.676; Val_NMI: 19.639
# (Epoch 59 / 10000) Train_Loss: 134.666; Val_Loss: 128.844   Train_ACC: 12.194; Val_ACC: 26.000   Train_NMI: 0.571; Val_NMI: 21.788
# (Epoch 60 / 10000) Train_Loss: 135.289; Val_Loss: 130.741   Train_ACC: 12.491; Val_ACC: 26.000   Train_NMI: 0.628; Val_NMI: 21.671
# (Epoch 61 / 10000) Train_Loss: 134.066; Val_Loss: 126.468   Train_ACC: 12.602; Val_ACC: 26.000   Train_NMI: 0.708; Val_NMI: 22.641
# (Epoch 62 / 10000) Train_Loss: 132.515; Val_Loss: 126.421   Train_ACC: 12.454; Val_ACC: 25.000   Train_NMI: 0.656; Val_NMI: 20.595
# (Epoch 63 / 10000) Train_Loss: 132.187; Val_Loss: 123.246   Train_ACC: 12.380; Val_ACC: 27.000   Train_NMI: 0.663; Val_NMI: 22.569
# (Epoch 64 / 10000) Train_Loss: 132.015; Val_Loss: 125.309   Train_ACC: 12.157; Val_ACC: 26.000   Train_NMI: 0.568; Val_NMI: 20.506
# (Epoch 65 / 10000) Train_Loss: 131.575; Val_Loss: 123.324   Train_ACC: 12.417; Val_ACC: 25.000   Train_NMI: 0.652; Val_NMI: 18.206
# (Epoch 66 / 10000) Train_Loss: 130.335; Val_Loss: 123.767   Train_ACC: 12.417; Val_ACC: 26.000   Train_NMI: 0.703; Val_NMI: 22.047
# (Epoch 67 / 10000) Train_Loss: 129.583; Val_Loss: 122.716   Train_ACC: 12.676; Val_ACC: 23.000   Train_NMI: 0.740; Val_NMI: 20.025
# (Epoch 68 / 10000) Train_Loss: 127.908; Val_Loss: 122.549   Train_ACC: 12.380; Val_ACC: 26.000   Train_NMI: 0.573; Val_NMI: 21.908
# (Epoch 69 / 10000) Train_Loss: 127.578; Val_Loss: 119.872   Train_ACC: 12.417; Val_ACC: 24.000   Train_NMI: 0.694; Val_NMI: 18.876
# (Epoch 70 / 10000) Train_Loss: 127.110; Val_Loss: 119.698   Train_ACC: 12.380; Val_ACC: 24.000   Train_NMI: 0.537; Val_NMI: 20.046
# (Epoch 71 / 10000) Train_Loss: 126.414; Val_Loss: 120.428   Train_ACC: 12.231; Val_ACC: 26.000   Train_NMI: 0.647; Val_NMI: 19.584
# (Epoch 72 / 10000) Train_Loss: 126.251; Val_Loss: 119.209   Train_ACC: 12.639; Val_ACC: 24.000   Train_NMI: 0.703; Val_NMI: 19.003
# (Epoch 73 / 10000) Train_Loss: 125.244; Val_Loss: 120.239   Train_ACC: 12.417; Val_ACC: 26.000   Train_NMI: 0.561; Val_NMI: 18.636
# (Epoch 74 / 10000) Train_Loss: 127.135; Val_Loss: 116.005   Train_ACC: 12.305; Val_ACC: 24.000   Train_NMI: 0.528; Val_NMI: 18.194
# (Epoch 75 / 10000) Train_Loss: 123.765; Val_Loss: 117.271   Train_ACC: 12.565; Val_ACC: 26.000   Train_NMI: 0.687; Val_NMI: 21.671
# (Epoch 76 / 10000) Train_Loss: 123.475; Val_Loss: 114.077   Train_ACC: 12.491; Val_ACC: 24.000   Train_NMI: 0.577; Val_NMI: 18.725
# (Epoch 77 / 10000) Train_Loss: 122.929; Val_Loss: 114.890   Train_ACC: 12.528; Val_ACC: 24.000   Train_NMI: 0.643; Val_NMI: 19.797
# (Epoch 78 / 10000) Train_Loss: 121.799; Val_Loss: 113.878   Train_ACC: 12.120; Val_ACC: 24.000   Train_NMI: 0.626; Val_NMI: 22.152
# (Epoch 79 / 10000) Train_Loss: 120.802; Val_Loss: 113.557   Train_ACC: 12.713; Val_ACC: 25.000   Train_NMI: 0.669; Val_NMI: 20.304
# (Epoch 80 / 10000) Train_Loss: 120.778; Val_Loss: 111.920   Train_ACC: 12.491; Val_ACC: 26.000   Train_NMI: 0.594; Val_NMI: 22.307
# (Epoch 81 / 10000) Train_Loss: 120.432; Val_Loss: 112.861   Train_ACC: 12.787; Val_ACC: 24.000   Train_NMI: 0.698; Val_NMI: 19.444
# (Epoch 82 / 10000) Train_Loss: 119.394; Val_Loss: 115.469   Train_ACC: 12.565; Val_ACC: 23.000   Train_NMI: 0.657; Val_NMI: 18.482
# (Epoch 83 / 10000) Train_Loss: 119.210; Val_Loss: 110.849   Train_ACC: 12.787; Val_ACC: 24.000   Train_NMI: 0.795; Val_NMI: 21.556
# (Epoch 84 / 10000) Train_Loss: 118.218; Val_Loss: 111.305   Train_ACC: 12.787; Val_ACC: 28.000   Train_NMI: 0.730; Val_NMI: 23.157
# (Epoch 85 / 10000) Train_Loss: 118.489; Val_Loss: 111.008   Train_ACC: 12.454; Val_ACC: 24.000   Train_NMI: 0.693; Val_NMI: 19.842
# (Epoch 86 / 10000) Train_Loss: 117.183; Val_Loss: 109.765   Train_ACC: 12.528; Val_ACC: 23.000   Train_NMI: 0.669; Val_NMI: 22.205
# (Epoch 87 / 10000) Train_Loss: 116.818; Val_Loss: 108.612   Train_ACC: 12.565; Val_ACC: 23.000   Train_NMI: 0.626; Val_NMI: 21.822
# (Epoch 88 / 10000) Train_Loss: 116.591; Val_Loss: 109.168   Train_ACC: 12.973; Val_ACC: 24.000   Train_NMI: 0.680; Val_NMI: 19.606
# (Epoch 89 / 10000) Train_Loss: 114.975; Val_Loss: 107.780   Train_ACC: 12.713; Val_ACC: 24.000   Train_NMI: 0.682; Val_NMI: 20.099
# (Epoch 90 / 10000) Train_Loss: 116.309; Val_Loss: 108.812   Train_ACC: 12.639; Val_ACC: 26.000   Train_NMI: 0.698; Val_NMI: 23.252
# (Epoch 91 / 10000) Train_Loss: 114.145; Val_Loss: 109.068   Train_ACC: 12.565; Val_ACC: 25.000   Train_NMI: 0.659; Val_NMI: 21.931
# (Epoch 92 / 10000) Train_Loss: 113.754; Val_Loss: 104.939   Train_ACC: 12.750; Val_ACC: 26.000   Train_NMI: 0.714; Val_NMI: 21.508
# (Epoch 93 / 10000) Train_Loss: 113.715; Val_Loss: 105.979   Train_ACC: 12.639; Val_ACC: 24.000   Train_NMI: 0.674; Val_NMI: 20.153
# (Epoch 94 / 10000) Train_Loss: 112.143; Val_Loss: 103.719   Train_ACC: 12.713; Val_ACC: 24.000   Train_NMI: 0.709; Val_NMI: 19.110
# (Epoch 95 / 10000) Train_Loss: 111.165; Val_Loss: 105.567   Train_ACC: 12.676; Val_ACC: 26.000   Train_NMI: 0.790; Val_NMI: 21.495
# (Epoch 96 / 10000) Train_Loss: 110.503; Val_Loss: 104.666   Train_ACC: 12.602; Val_ACC: 26.000   Train_NMI: 0.737; Val_NMI: 20.992
# (Epoch 97 / 10000) Train_Loss: 110.887; Val_Loss: 101.873   Train_ACC: 12.639; Val_ACC: 27.000   Train_NMI: 0.682; Val_NMI: 22.293
# (Epoch 98 / 10000) Train_Loss: 108.660; Val_Loss: 103.497   Train_ACC: 12.602; Val_ACC: 24.000   Train_NMI: 0.693; Val_NMI: 20.849
# (Epoch 99 / 10000) Train_Loss: 108.696; Val_Loss: 100.806   Train_ACC: 12.602; Val_ACC: 24.000   Train_NMI: 0.704; Val_NMI: 20.669
# (Epoch 100 / 10000) Train_Loss: 107.516; Val_Loss: 102.215   Train_ACC: 12.417; Val_ACC: 25.000   Train_NMI: 0.730; Val_NMI: 20.406
# (Epoch 101 / 10000) Train_Loss: 108.268; Val_Loss: 103.077   Train_ACC: 13.158; Val_ACC: 23.000   Train_NMI: 0.801; Val_NMI: 20.789
# (Epoch 102 / 10000) Train_Loss: 106.771; Val_Loss: 98.287   Train_ACC: 12.750; Val_ACC: 24.000   Train_NMI: 0.644; Val_NMI: 21.607
# (Epoch 103 / 10000) Train_Loss: 106.645; Val_Loss: 99.429   Train_ACC: 12.861; Val_ACC: 23.000   Train_NMI: 0.742; Val_NMI: 19.325
# (Epoch 104 / 10000) Train_Loss: 105.585; Val_Loss: 99.121   Train_ACC: 12.676; Val_ACC: 24.000   Train_NMI: 0.709; Val_NMI: 21.110
# (Epoch 105 / 10000) Train_Loss: 105.020; Val_Loss: 99.285   Train_ACC: 12.639; Val_ACC: 24.000   Train_NMI: 0.613; Val_NMI: 19.798
# (Epoch 106 / 10000) Train_Loss: 106.013; Val_Loss: 96.340   Train_ACC: 12.750; Val_ACC: 25.000   Train_NMI: 0.798; Val_NMI: 19.741
# (Epoch 107 / 10000) Train_Loss: 103.928; Val_Loss: 98.150   Train_ACC: 12.936; Val_ACC: 26.000   Train_NMI: 0.708; Val_NMI: 24.509
# (Epoch 108 / 10000) Train_Loss: 103.486; Val_Loss: 98.798   Train_ACC: 12.787; Val_ACC: 24.000   Train_NMI: 0.754; Val_NMI: 19.575
# (Epoch 109 / 10000) Train_Loss: 103.004; Val_Loss: 94.646   Train_ACC: 12.380; Val_ACC: 25.000   Train_NMI: 0.617; Val_NMI: 19.065
# (Epoch 110 / 10000) Train_Loss: 102.797; Val_Loss: 94.693   Train_ACC: 12.676; Val_ACC: 25.000   Train_NMI: 0.674; Val_NMI: 19.640
# (Epoch 111 / 10000) Train_Loss: 102.234; Val_Loss: 96.516   Train_ACC: 12.750; Val_ACC: 24.000   Train_NMI: 0.699; Val_NMI: 19.691
# (Epoch 112 / 10000) Train_Loss: 101.387; Val_Loss: 94.278   Train_ACC: 12.861; Val_ACC: 24.000   Train_NMI: 0.765; Val_NMI: 21.372
# (Epoch 113 / 10000) Train_Loss: 101.398; Val_Loss: 92.932   Train_ACC: 12.528; Val_ACC: 24.000   Train_NMI: 0.633; Val_NMI: 20.275
# (Epoch 114 / 10000) Train_Loss: 100.451; Val_Loss: 95.708   Train_ACC: 12.824; Val_ACC: 23.000   Train_NMI: 0.709; Val_NMI: 19.177
# (Epoch 115 / 10000) Train_Loss: 100.671; Val_Loss: 92.710   Train_ACC: 12.713; Val_ACC: 26.000   Train_NMI: 0.661; Val_NMI: 21.578
# (Epoch 116 / 10000) Train_Loss: 100.889; Val_Loss: 92.562   Train_ACC: 12.565; Val_ACC: 26.000   Train_NMI: 0.620; Val_NMI: 21.733
# (Epoch 117 / 10000) Train_Loss: 100.622; Val_Loss: 95.610   Train_ACC: 12.713; Val_ACC: 26.000   Train_NMI: 0.678; Val_NMI: 21.859
# (Epoch 118 / 10000) Train_Loss: 100.100; Val_Loss: 94.803   Train_ACC: 12.824; Val_ACC: 25.000   Train_NMI: 0.685; Val_NMI: 21.851
# (Epoch 119 / 10000) Train_Loss: 99.607; Val_Loss: 91.996   Train_ACC: 12.454; Val_ACC: 25.000   Train_NMI: 0.565; Val_NMI: 21.597
# (Epoch 120 / 10000) Train_Loss: 98.274; Val_Loss: 91.265   Train_ACC: 12.639; Val_ACC: 26.000   Train_NMI: 0.596; Val_NMI: 22.111
# (Epoch 121 / 10000) Train_Loss: 97.806; Val_Loss: 89.974   Train_ACC: 12.936; Val_ACC: 25.000   Train_NMI: 0.699; Val_NMI: 20.413
# (Epoch 122 / 10000) Train_Loss: 96.892; Val_Loss: 90.198   Train_ACC: 12.824; Val_ACC: 25.000   Train_NMI: 0.664; Val_NMI: 21.710
# (Epoch 123 / 10000) Train_Loss: 96.973; Val_Loss: 90.016   Train_ACC: 12.750; Val_ACC: 25.000   Train_NMI: 0.659; Val_NMI: 22.005
# (Epoch 124 / 10000) Train_Loss: 96.193; Val_Loss: 90.717   Train_ACC: 12.676; Val_ACC: 26.000   Train_NMI: 0.698; Val_NMI: 23.280
# (Epoch 125 / 10000) Train_Loss: 97.370; Val_Loss: 87.859   Train_ACC: 12.380; Val_ACC: 25.000   Train_NMI: 0.625; Val_NMI: 21.704
# (Epoch 126 / 10000) Train_Loss: 94.819; Val_Loss: 86.937   Train_ACC: 12.639; Val_ACC: 25.000   Train_NMI: 0.518; Val_NMI: 20.984
# (Epoch 127 / 10000) Train_Loss: 94.732; Val_Loss: 87.909   Train_ACC: 12.676; Val_ACC: 25.000   Train_NMI: 0.617; Val_NMI: 21.916
# (Epoch 128 / 10000) Train_Loss: 94.427; Val_Loss: 85.514   Train_ACC: 12.639; Val_ACC: 26.000   Train_NMI: 0.621; Val_NMI: 22.793
# (Epoch 129 / 10000) Train_Loss: 93.249; Val_Loss: 89.597   Train_ACC: 12.565; Val_ACC: 26.000   Train_NMI: 0.588; Val_NMI: 22.238
# (Epoch 130 / 10000) Train_Loss: 93.481; Val_Loss: 87.481   Train_ACC: 12.824; Val_ACC: 26.000   Train_NMI: 0.650; Val_NMI: 23.354
# (Epoch 131 / 10000) Train_Loss: 93.178; Val_Loss: 87.956   Train_ACC: 12.602; Val_ACC: 24.000   Train_NMI: 0.589; Val_NMI: 20.677
# (Epoch 132 / 10000) Train_Loss: 92.813; Val_Loss: 84.844   Train_ACC: 12.750; Val_ACC: 25.000   Train_NMI: 0.620; Val_NMI: 23.213
# (Epoch 133 / 10000) Train_Loss: 91.453; Val_Loss: 83.551   Train_ACC: 12.973; Val_ACC: 25.000   Train_NMI: 0.730; Val_NMI: 20.985
# (Epoch 134 / 10000) Train_Loss: 91.265; Val_Loss: 86.342   Train_ACC: 12.602; Val_ACC: 25.000   Train_NMI: 0.643; Val_NMI: 21.206
# (Epoch 135 / 10000) Train_Loss: 91.971; Val_Loss: 85.634   Train_ACC: 12.824; Val_ACC: 26.000   Train_NMI: 0.619; Val_NMI: 23.989
# (Epoch 136 / 10000) Train_Loss: 89.605; Val_Loss: 82.471   Train_ACC: 12.713; Val_ACC: 25.000   Train_NMI: 0.659; Val_NMI: 20.925
# (Epoch 137 / 10000) Train_Loss: 89.053; Val_Loss: 82.668   Train_ACC: 12.713; Val_ACC: 25.000   Train_NMI: 0.674; Val_NMI: 21.173
# (Epoch 138 / 10000) Train_Loss: 89.262; Val_Loss: 82.102   Train_ACC: 12.713; Val_ACC: 24.000   Train_NMI: 0.645; Val_NMI: 19.903
# (Epoch 139 / 10000) Train_Loss: 88.549; Val_Loss: 83.905   Train_ACC: 12.713; Val_ACC: 27.000   Train_NMI: 0.571; Val_NMI: 22.407
# (Epoch 140 / 10000) Train_Loss: 89.800; Val_Loss: 85.223   Train_ACC: 12.936; Val_ACC: 24.000   Train_NMI: 0.688; Val_NMI: 21.534
# (Epoch 141 / 10000) Train_Loss: 90.544; Val_Loss: 82.267   Train_ACC: 12.602; Val_ACC: 26.000   Train_NMI: 0.620; Val_NMI: 23.430
# (Epoch 142 / 10000) Train_Loss: 89.373; Val_Loss: 81.383   Train_ACC: 12.676; Val_ACC: 26.000   Train_NMI: 0.606; Val_NMI: 22.565
# (Epoch 143 / 10000) Train_Loss: 87.180; Val_Loss: 81.680   Train_ACC: 13.047; Val_ACC: 24.000   Train_NMI: 0.808; Val_NMI: 22.624
# (Epoch 144 / 10000) Train_Loss: 87.807; Val_Loss: 81.910   Train_ACC: 12.342; Val_ACC: 25.000   Train_NMI: 0.600; Val_NMI: 19.788
# (Epoch 145 / 10000) Train_Loss: 87.093; Val_Loss: 81.599   Train_ACC: 12.565; Val_ACC: 26.000   Train_NMI: 0.685; Val_NMI: 21.770
# (Epoch 146 / 10000) Train_Loss: 87.087; Val_Loss: 77.919   Train_ACC: 12.861; Val_ACC: 24.000   Train_NMI: 0.658; Val_NMI: 19.850
# (Epoch 147 / 10000) Train_Loss: 86.446; Val_Loss: 80.536   Train_ACC: 12.491; Val_ACC: 26.000   Train_NMI: 0.583; Val_NMI: 21.204
# (Epoch 148 / 10000) Train_Loss: 86.283; Val_Loss: 79.221   Train_ACC: 12.936; Val_ACC: 25.000   Train_NMI: 0.759; Val_NMI: 23.346
# (Epoch 149 / 10000) Train_Loss: 83.935; Val_Loss: 78.612   Train_ACC: 12.824; Val_ACC: 25.000   Train_NMI: 0.757; Val_NMI: 23.328
# (Epoch 150 / 10000) Train_Loss: 83.262; Val_Loss: 78.073   Train_ACC: 12.861; Val_ACC: 25.000   Train_NMI: 0.724; Val_NMI: 20.965
# (Epoch 151 / 10000) Train_Loss: 84.921; Val_Loss: 76.606   Train_ACC: 12.602; Val_ACC: 26.000   Train_NMI: 0.689; Val_NMI: 22.109
# (Epoch 152 / 10000) Train_Loss: 86.858; Val_Loss: 76.328   Train_ACC: 12.380; Val_ACC: 25.000   Train_NMI: 0.645; Val_NMI: 21.317
# (Epoch 153 / 10000) Train_Loss: 84.482; Val_Loss: 77.812   Train_ACC: 12.676; Val_ACC: 25.000   Train_NMI: 0.668; Val_NMI: 19.885
# (Epoch 154 / 10000) Train_Loss: 83.913; Val_Loss: 80.044   Train_ACC: 12.861; Val_ACC: 23.000   Train_NMI: 0.635; Val_NMI: 19.200
# (Epoch 155 / 10000) Train_Loss: 82.245; Val_Loss: 75.537   Train_ACC: 13.010; Val_ACC: 25.000   Train_NMI: 0.677; Val_NMI: 21.080
# (Epoch 156 / 10000) Train_Loss: 82.445; Val_Loss: 76.953   Train_ACC: 12.602; Val_ACC: 25.000   Train_NMI: 0.544; Val_NMI: 20.940
# (Epoch 157 / 10000) Train_Loss: 83.922; Val_Loss: 76.216   Train_ACC: 12.565; Val_ACC: 25.000   Train_NMI: 0.658; Val_NMI: 19.886
# (Epoch 158 / 10000) Train_Loss: 82.137; Val_Loss: 79.324   Train_ACC: 12.417; Val_ACC: 25.000   Train_NMI: 0.618; Val_NMI: 20.870
# (Epoch 159 / 10000) Train_Loss: 82.202; Val_Loss: 76.555   Train_ACC: 12.602; Val_ACC: 24.000   Train_NMI: 0.599; Val_NMI: 20.485
# (Epoch 160 / 10000) Train_Loss: 81.313; Val_Loss: 73.944   Train_ACC: 12.602; Val_ACC: 25.000   Train_NMI: 0.710; Val_NMI: 18.841
# (Epoch 161 / 10000) Train_Loss: 82.427; Val_Loss: 74.863   Train_ACC: 12.639; Val_ACC: 26.000   Train_NMI: 0.615; Val_NMI: 22.945
# (Epoch 162 / 10000) Train_Loss: 80.047; Val_Loss: 74.216   Train_ACC: 12.898; Val_ACC: 25.000   Train_NMI: 0.645; Val_NMI: 19.366
# (Epoch 163 / 10000) Train_Loss: 79.918; Val_Loss: 75.849   Train_ACC: 12.824; Val_ACC: 25.000   Train_NMI: 0.730; Val_NMI: 21.555
# (Epoch 164 / 10000) Train_Loss: 79.944; Val_Loss: 75.073   Train_ACC: 12.713; Val_ACC: 25.000   Train_NMI: 0.585; Val_NMI: 20.711
# (Epoch 165 / 10000) Train_Loss: 79.213; Val_Loss: 73.719   Train_ACC: 12.824; Val_ACC: 25.000   Train_NMI: 0.604; Val_NMI: 22.465
# (Epoch 166 / 10000) Train_Loss: 79.069; Val_Loss: 75.329   Train_ACC: 12.787; Val_ACC: 26.000   Train_NMI: 0.639; Val_NMI: 21.848
# (Epoch 167 / 10000) Train_Loss: 79.942; Val_Loss: 76.129   Train_ACC: 12.750; Val_ACC: 26.000   Train_NMI: 0.677; Val_NMI: 20.576
# (Epoch 168 / 10000) Train_Loss: 80.053; Val_Loss: 72.227   Train_ACC: 12.639; Val_ACC: 25.000   Train_NMI: 0.673; Val_NMI: 21.674
# (Epoch 169 / 10000) Train_Loss: 77.382; Val_Loss: 74.047   Train_ACC: 12.898; Val_ACC: 26.000   Train_NMI: 0.734; Val_NMI: 23.274
# (Epoch 170 / 10000) Train_Loss: 77.835; Val_Loss: 72.880   Train_ACC: 12.676; Val_ACC: 25.000   Train_NMI: 0.673; Val_NMI: 21.697
# (Epoch 171 / 10000) Train_Loss: 77.968; Val_Loss: 70.883   Train_ACC: 12.750; Val_ACC: 26.000   Train_NMI: 0.699; Val_NMI: 22.498
# (Epoch 172 / 10000) Train_Loss: 80.431; Val_Loss: 74.976   Train_ACC: 12.824; Val_ACC: 25.000   Train_NMI: 0.607; Val_NMI: 19.502
# (Epoch 173 / 10000) Train_Loss: 77.484; Val_Loss: 73.326   Train_ACC: 13.084; Val_ACC: 25.000   Train_NMI: 0.646; Val_NMI: 19.890
# (Epoch 174 / 10000) Train_Loss: 76.273; Val_Loss: 73.786   Train_ACC: 12.787; Val_ACC: 25.000   Train_NMI: 0.643; Val_NMI: 21.294
# (Epoch 175 / 10000) Train_Loss: 78.428; Val_Loss: 74.751   Train_ACC: 12.861; Val_ACC: 24.000   Train_NMI: 0.622; Val_NMI: 19.657
# (Epoch 176 / 10000) Train_Loss: 76.666; Val_Loss: 70.099   Train_ACC: 13.084; Val_ACC: 24.000   Train_NMI: 0.752; Val_NMI: 20.335
# (Epoch 177 / 10000) Train_Loss: 74.670; Val_Loss: 70.007   Train_ACC: 12.713; Val_ACC: 27.000   Train_NMI: 0.664; Val_NMI: 24.422
# (Epoch 178 / 10000) Train_Loss: 74.496; Val_Loss: 70.779   Train_ACC: 12.973; Val_ACC: 26.000   Train_NMI: 0.675; Val_NMI: 21.989
# (Epoch 179 / 10000) Train_Loss: 76.685; Val_Loss: 67.818   Train_ACC: 12.898; Val_ACC: 26.000   Train_NMI: 0.757; Val_NMI: 21.351
# (Epoch 180 / 10000) Train_Loss: 75.696; Val_Loss: 67.956   Train_ACC: 12.861; Val_ACC: 25.000   Train_NMI: 0.606; Val_NMI: 21.712
# (Epoch 181 / 10000) Train_Loss: 73.298; Val_Loss: 68.389   Train_ACC: 12.750; Val_ACC: 25.000   Train_NMI: 0.707; Val_NMI: 22.480
# (Epoch 182 / 10000) Train_Loss: 72.690; Val_Loss: 66.919   Train_ACC: 12.787; Val_ACC: 27.000   Train_NMI: 0.642; Val_NMI: 24.865
# (Epoch 183 / 10000) Train_Loss: 74.089; Val_Loss: 68.514   Train_ACC: 12.861; Val_ACC: 26.000   Train_NMI: 0.736; Val_NMI: 22.034
# (Epoch 184 / 10000) Train_Loss: 75.365; Val_Loss: 67.746   Train_ACC: 12.787; Val_ACC: 26.000   Train_NMI: 0.697; Val_NMI: 20.499
# (Epoch 185 / 10000) Train_Loss: 73.295; Val_Loss: 65.774   Train_ACC: 12.787; Val_ACC: 25.000   Train_NMI: 0.690; Val_NMI: 21.183
# (Epoch 186 / 10000) Train_Loss: 73.862; Val_Loss: 67.840   Train_ACC: 12.676; Val_ACC: 25.000   Train_NMI: 0.623; Val_NMI: 20.482
# (Epoch 187 / 10000) Train_Loss: 72.113; Val_Loss: 64.751   Train_ACC: 12.750; Val_ACC: 26.000   Train_NMI: 0.627; Val_NMI: 24.540
# (Epoch 188 / 10000) Train_Loss: 73.077; Val_Loss: 67.873   Train_ACC: 12.676; Val_ACC: 25.000   Train_NMI: 0.699; Val_NMI: 22.954
# (Epoch 189 / 10000) Train_Loss: 73.500; Val_Loss: 68.295   Train_ACC: 12.713; Val_ACC: 25.000   Train_NMI: 0.570; Val_NMI: 23.521
# (Epoch 190 / 10000) Train_Loss: 73.642; Val_Loss: 64.897   Train_ACC: 12.528; Val_ACC: 26.000   Train_NMI: 0.615; Val_NMI: 21.398
# (Epoch 191 / 10000) Train_Loss: 71.342; Val_Loss: 65.559   Train_ACC: 12.639; Val_ACC: 26.000   Train_NMI: 0.580; Val_NMI: 20.318
# (Epoch 192 / 10000) Train_Loss: 70.894; Val_Loss: 66.048   Train_ACC: 12.936; Val_ACC: 26.000   Train_NMI: 0.716; Val_NMI: 22.524
# (Epoch 193 / 10000) Train_Loss: 71.647; Val_Loss: 68.041   Train_ACC: 12.750; Val_ACC: 26.000   Train_NMI: 0.598; Val_NMI: 21.938
# (Epoch 194 / 10000) Train_Loss: 71.667; Val_Loss: 64.690   Train_ACC: 12.824; Val_ACC: 25.000   Train_NMI: 0.634; Val_NMI: 20.778
# (Epoch 195 / 10000) Train_Loss: 69.855; Val_Loss: 63.532   Train_ACC: 12.936; Val_ACC: 26.000   Train_NMI: 0.670; Val_NMI: 22.941
# (Epoch 196 / 10000) Train_Loss: 69.459; Val_Loss: 63.375   Train_ACC: 12.824; Val_ACC: 26.000   Train_NMI: 0.681; Val_NMI: 20.779
# (Epoch 197 / 10000) Train_Loss: 69.674; Val_Loss: 64.502   Train_ACC: 12.713; Val_ACC: 26.000   Train_NMI: 0.691; Val_NMI: 22.358
# (Epoch 198 / 10000) Train_Loss: 70.767; Val_Loss: 64.027   Train_ACC: 12.824; Val_ACC: 26.000   Train_NMI: 0.676; Val_NMI: 20.556
# (Epoch 199 / 10000) Train_Loss: 69.712; Val_Loss: 64.862   Train_ACC: 12.936; Val_ACC: 24.000   Train_NMI: 0.647; Val_NMI: 21.091
# (Epoch 200 / 10000) Train_Loss: 69.584; Val_Loss: 62.951   Train_ACC: 12.713; Val_ACC: 25.000   Train_NMI: 0.684; Val_NMI: 19.777
# (Epoch 201 / 10000) Train_Loss: 69.333; Val_Loss: 65.694   Train_ACC: 12.861; Val_ACC: 25.000   Train_NMI: 0.719; Val_NMI: 22.622
# (Epoch 202 / 10000) Train_Loss: 69.127; Val_Loss: 63.507   Train_ACC: 12.861; Val_ACC: 24.000   Train_NMI: 0.722; Val_NMI: 19.283
# (Epoch 203 / 10000) Train_Loss: 67.630; Val_Loss: 62.772   Train_ACC: 12.676; Val_ACC: 25.000   Train_NMI: 0.642; Val_NMI: 21.314
# (Epoch 204 / 10000) Train_Loss: 68.287; Val_Loss: 62.759   Train_ACC: 13.010; Val_ACC: 23.000   Train_NMI: 0.735; Val_NMI: 21.055
# (Epoch 205 / 10000) Train_Loss: 69.211; Val_Loss: 66.342   Train_ACC: 12.639; Val_ACC: 26.000   Train_NMI: 0.670; Val_NMI: 21.475
# (Epoch 206 / 10000) Train_Loss: 68.303; Val_Loss: 60.536   Train_ACC: 13.084; Val_ACC: 25.000   Train_NMI: 0.672; Val_NMI: 21.609
# (Epoch 207 / 10000) Train_Loss: 68.238; Val_Loss: 64.554   Train_ACC: 12.898; Val_ACC: 25.000   Train_NMI: 0.715; Val_NMI: 20.385
# (Epoch 208 / 10000) Train_Loss: 68.330; Val_Loss: 64.278   Train_ACC: 13.010; Val_ACC: 26.000   Train_NMI: 0.680; Val_NMI: 20.349
# (Epoch 209 / 10000) Train_Loss: 69.651; Val_Loss: 63.466   Train_ACC: 13.158; Val_ACC: 26.000   Train_NMI: 0.821; Val_NMI: 20.995
# (Epoch 210 / 10000) Train_Loss: 70.348; Val_Loss: 65.152   Train_ACC: 13.195; Val_ACC: 24.000   Train_NMI: 0.748; Val_NMI: 20.932
# (Epoch 211 / 10000) Train_Loss: 73.998; Val_Loss: 65.399   Train_ACC: 13.121; Val_ACC: 25.000   Train_NMI: 0.764; Val_NMI: 21.013
# (Epoch 212 / 10000) Train_Loss: 68.638; Val_Loss: 65.723   Train_ACC: 13.343; Val_ACC: 27.000   Train_NMI: 0.793; Val_NMI: 21.343
# (Epoch 213 / 10000) Train_Loss: 67.136; Val_Loss: 60.849   Train_ACC: 13.158; Val_ACC: 25.000   Train_NMI: 0.712; Val_NMI: 22.722
# (Epoch 214 / 10000) Train_Loss: 65.720; Val_Loss: 60.106   Train_ACC: 12.676; Val_ACC: 25.000   Train_NMI: 0.619; Val_NMI: 20.577
# (Epoch 215 / 10000) Train_Loss: 65.095; Val_Loss: 59.749   Train_ACC: 12.750; Val_ACC: 26.000   Train_NMI: 0.642; Val_NMI: 23.228
# (Epoch 216 / 10000) Train_Loss: 67.026; Val_Loss: 61.701   Train_ACC: 12.973; Val_ACC: 24.000   Train_NMI: 0.747; Val_NMI: 22.221
# (Epoch 217 / 10000) Train_Loss: 66.831; Val_Loss: 61.329   Train_ACC: 13.010; Val_ACC: 27.000   Train_NMI: 0.743; Val_NMI: 21.607
# (Epoch 218 / 10000) Train_Loss: 65.889; Val_Loss: 58.849   Train_ACC: 12.750; Val_ACC: 25.000   Train_NMI: 0.783; Val_NMI: 20.248
# (Epoch 219 / 10000) Train_Loss: 65.407; Val_Loss: 61.580   Train_ACC: 12.787; Val_ACC: 26.000   Train_NMI: 0.672; Val_NMI: 22.521
# (Epoch 220 / 10000) Train_Loss: 66.142; Val_Loss: 58.996   Train_ACC: 12.973; Val_ACC: 25.000   Train_NMI: 0.711; Val_NMI: 20.267
# (Epoch 221 / 10000) Train_Loss: 66.822; Val_Loss: 59.767   Train_ACC: 12.973; Val_ACC: 25.000   Train_NMI: 0.673; Val_NMI: 23.217
# (Epoch 222 / 10000) Train_Loss: 66.309; Val_Loss: 61.177   Train_ACC: 12.936; Val_ACC: 27.000   Train_NMI: 0.763; Val_NMI: 21.849
# (Epoch 223 / 10000) Train_Loss: 65.110; Val_Loss: 58.743   Train_ACC: 12.936; Val_ACC: 24.000   Train_NMI: 0.724; Val_NMI: 21.447
# (Epoch 224 / 10000) Train_Loss: 64.004; Val_Loss: 61.108   Train_ACC: 13.010; Val_ACC: 26.000   Train_NMI: 0.682; Val_NMI: 22.636
# (Epoch 225 / 10000) Train_Loss: 64.183; Val_Loss: 60.668   Train_ACC: 12.787; Val_ACC: 26.000   Train_NMI: 0.687; Val_NMI: 22.573
# (Epoch 226 / 10000) Train_Loss: 63.667; Val_Loss: 56.955   Train_ACC: 13.306; Val_ACC: 26.000   Train_NMI: 0.820; Val_NMI: 22.604
# (Epoch 227 / 10000) Train_Loss: 65.990; Val_Loss: 60.883   Train_ACC: 12.973; Val_ACC: 26.000   Train_NMI: 0.729; Val_NMI: 21.933
# (Epoch 228 / 10000) Train_Loss: 64.165; Val_Loss: 58.863   Train_ACC: 13.010; Val_ACC: 26.000   Train_NMI: 0.711; Val_NMI: 21.718
# (Epoch 229 / 10000) Train_Loss: 62.646; Val_Loss: 59.183   Train_ACC: 12.898; Val_ACC: 25.000   Train_NMI: 0.680; Val_NMI: 21.328
# (Epoch 230 / 10000) Train_Loss: 62.853; Val_Loss: 55.357   Train_ACC: 12.713; Val_ACC: 25.000   Train_NMI: 0.659; Val_NMI: 21.567
# (Epoch 231 / 10000) Train_Loss: 62.280; Val_Loss: 57.248   Train_ACC: 13.084; Val_ACC: 25.000   Train_NMI: 0.671; Val_NMI: 20.942
# (Epoch 232 / 10000) Train_Loss: 62.330; Val_Loss: 58.230   Train_ACC: 13.010; Val_ACC: 24.000   Train_NMI: 0.730; Val_NMI: 19.330
# (Epoch 233 / 10000) Train_Loss: 62.298; Val_Loss: 55.280   Train_ACC: 12.861; Val_ACC: 27.000   Train_NMI: 0.721; Val_NMI: 22.451
# (Epoch 234 / 10000) Train_Loss: 61.640; Val_Loss: 60.231   Train_ACC: 12.713; Val_ACC: 24.000   Train_NMI: 0.712; Val_NMI: 20.373
# (Epoch 235 / 10000) Train_Loss: 62.850; Val_Loss: 56.315   Train_ACC: 12.973; Val_ACC: 24.000   Train_NMI: 0.742; Val_NMI: 21.037
# (Epoch 236 / 10000) Train_Loss: 61.695; Val_Loss: 61.712   Train_ACC: 12.936; Val_ACC: 24.000   Train_NMI: 0.728; Val_NMI: 19.717
# (Epoch 237 / 10000) Train_Loss: 64.233; Val_Loss: 60.416   Train_ACC: 12.824; Val_ACC: 26.000   Train_NMI: 0.703; Val_NMI: 22.957
# (Epoch 238 / 10000) Train_Loss: 63.945; Val_Loss: 59.659   Train_ACC: 12.936; Val_ACC: 26.000   Train_NMI: 0.731; Val_NMI: 20.438
# (Epoch 239 / 10000) Train_Loss: 62.867; Val_Loss: 56.703   Train_ACC: 12.936; Val_ACC: 24.000   Train_NMI: 0.667; Val_NMI: 19.525
# (Epoch 240 / 10000) Train_Loss: 62.108; Val_Loss: 59.069   Train_ACC: 12.861; Val_ACC: 26.000   Train_NMI: 0.670; Val_NMI: 20.372
# (Epoch 241 / 10000) Train_Loss: 62.430; Val_Loss: 61.553   Train_ACC: 12.861; Val_ACC: 26.000   Train_NMI: 0.616; Val_NMI: 22.324
# (Epoch 242 / 10000) Train_Loss: 62.139; Val_Loss: 58.928   Train_ACC: 13.047; Val_ACC: 26.000   Train_NMI: 0.713; Val_NMI: 22.435
# (Epoch 243 / 10000) Train_Loss: 61.945; Val_Loss: 54.065   Train_ACC: 13.121; Val_ACC: 25.000   Train_NMI: 0.817; Val_NMI: 20.655
# (Epoch 244 / 10000) Train_Loss: 61.536; Val_Loss: 58.493   Train_ACC: 12.824; Val_ACC: 25.000   Train_NMI: 0.676; Val_NMI: 20.112
# (Epoch 245 / 10000) Train_Loss: 61.448; Val_Loss: 55.810   Train_ACC: 13.047; Val_ACC: 25.000   Train_NMI: 0.700; Val_NMI: 20.715
# (Epoch 246 / 10000) Train_Loss: 61.544; Val_Loss: 56.309   Train_ACC: 12.713; Val_ACC: 26.000   Train_NMI: 0.776; Val_NMI: 22.530
# (Epoch 247 / 10000) Train_Loss: 61.729; Val_Loss: 54.757   Train_ACC: 13.047; Val_ACC: 26.000   Train_NMI: 0.773; Val_NMI: 20.392
# (Epoch 248 / 10000) Train_Loss: 61.235; Val_Loss: 55.612   Train_ACC: 12.787; Val_ACC: 25.000   Train_NMI: 0.759; Val_NMI: 19.988
# (Epoch 249 / 10000) Train_Loss: 59.160; Val_Loss: 54.184   Train_ACC: 12.787; Val_ACC: 25.000   Train_NMI: 0.615; Val_NMI: 18.794
# (Epoch 250 / 10000) Train_Loss: 58.394; Val_Loss: 53.486   Train_ACC: 12.639; Val_ACC: 24.000   Train_NMI: 0.637; Val_NMI: 21.203
# (Epoch 251 / 10000) Train_Loss: 58.856; Val_Loss: 55.206   Train_ACC: 12.750; Val_ACC: 24.000   Train_NMI: 0.649; Val_NMI: 20.797
# (Epoch 252 / 10000) Train_Loss: 59.105; Val_Loss: 56.407   Train_ACC: 12.602; Val_ACC: 25.000   Train_NMI: 0.636; Val_NMI: 21.617
# (Epoch 253 / 10000) Train_Loss: 61.213; Val_Loss: 55.295   Train_ACC: 12.676; Val_ACC: 24.000   Train_NMI: 0.638; Val_NMI: 19.494
# (Epoch 254 / 10000) Train_Loss: 59.397; Val_Loss: 54.952   Train_ACC: 12.861; Val_ACC: 24.000   Train_NMI: 0.712; Val_NMI: 20.482
# (Epoch 255 / 10000) Train_Loss: 58.966; Val_Loss: 51.738   Train_ACC: 12.973; Val_ACC: 24.000   Train_NMI: 0.667; Val_NMI: 20.284
# (Epoch 256 / 10000) Train_Loss: 59.419; Val_Loss: 53.850   Train_ACC: 12.787; Val_ACC: 26.000   Train_NMI: 0.729; Val_NMI: 22.826
# (Epoch 257 / 10000) Train_Loss: 62.699; Val_Loss: 61.046   Train_ACC: 12.602; Val_ACC: 24.000   Train_NMI: 0.670; Val_NMI: 21.870
# (Epoch 258 / 10000) Train_Loss: 63.259; Val_Loss: 56.385   Train_ACC: 12.898; Val_ACC: 25.000   Train_NMI: 0.669; Val_NMI: 22.174
# (Epoch 259 / 10000) Train_Loss: 61.160; Val_Loss: 54.877   Train_ACC: 12.861; Val_ACC: 26.000   Train_NMI: 0.679; Val_NMI: 22.575
# (Epoch 260 / 10000) Train_Loss: 60.562; Val_Loss: 54.722   Train_ACC: 12.861; Val_ACC: 24.000   Train_NMI: 0.621; Val_NMI: 20.591
# (Epoch 261 / 10000) Train_Loss: 58.715; Val_Loss: 54.005   Train_ACC: 13.232; Val_ACC: 25.000   Train_NMI: 0.775; Val_NMI: 21.107
# (Epoch 262 / 10000) Train_Loss: 58.354; Val_Loss: 55.742   Train_ACC: 12.824; Val_ACC: 26.000   Train_NMI: 0.688; Val_NMI: 21.961
# (Epoch 263 / 10000) Train_Loss: 59.503; Val_Loss: 51.339   Train_ACC: 12.973; Val_ACC: 25.000   Train_NMI: 0.699; Val_NMI: 20.916
# (Epoch 264 / 10000) Train_Loss: 56.999; Val_Loss: 52.011   Train_ACC: 12.898; Val_ACC: 24.000   Train_NMI: 0.714; Val_NMI: 19.945
# (Epoch 265 / 10000) Train_Loss: 55.941; Val_Loss: 50.791   Train_ACC: 13.084; Val_ACC: 25.000   Train_NMI: 0.782; Val_NMI: 21.467
# (Epoch 266 / 10000) Train_Loss: 55.381; Val_Loss: 54.091   Train_ACC: 12.973; Val_ACC: 25.000   Train_NMI: 0.758; Val_NMI: 22.454
# (Epoch 267 / 10000) Train_Loss: 57.516; Val_Loss: 51.394   Train_ACC: 12.898; Val_ACC: 25.000   Train_NMI: 0.745; Val_NMI: 20.927
# (Epoch 268 / 10000) Train_Loss: 57.257; Val_Loss: 52.130   Train_ACC: 12.936; Val_ACC: 24.000   Train_NMI: 0.776; Val_NMI: 21.575
# (Epoch 269 / 10000) Train_Loss: 58.770; Val_Loss: 53.547   Train_ACC: 13.047; Val_ACC: 25.000   Train_NMI: 0.669; Val_NMI: 19.775
# (Epoch 270 / 10000) Train_Loss: 57.178; Val_Loss: 52.953   Train_ACC: 12.824; Val_ACC: 25.000   Train_NMI: 0.751; Val_NMI: 21.311
# (Epoch 271 / 10000) Train_Loss: 57.766; Val_Loss: 52.698   Train_ACC: 13.195; Val_ACC: 25.000   Train_NMI: 0.867; Val_NMI: 21.085
# (Epoch 272 / 10000) Train_Loss: 58.169; Val_Loss: 53.125   Train_ACC: 12.973; Val_ACC: 26.000   Train_NMI: 0.751; Val_NMI: 23.452
# (Epoch 273 / 10000) Train_Loss: 57.246; Val_Loss: 54.422   Train_ACC: 13.010; Val_ACC: 25.000   Train_NMI: 0.804; Val_NMI: 21.435
# (Epoch 274 / 10000) Train_Loss: 56.502; Val_Loss: 54.005   Train_ACC: 13.084; Val_ACC: 26.000   Train_NMI: 0.807; Val_NMI: 21.012
# (Epoch 275 / 10000) Train_Loss: 55.840; Val_Loss: 55.137   Train_ACC: 13.084; Val_ACC: 26.000   Train_NMI: 0.782; Val_NMI: 23.176
# (Epoch 276 / 10000) Train_Loss: 55.545; Val_Loss: 50.452   Train_ACC: 12.824; Val_ACC: 26.000   Train_NMI: 0.648; Val_NMI: 23.341
# (Epoch 277 / 10000) Train_Loss: 56.121; Val_Loss: 50.401   Train_ACC: 12.898; Val_ACC: 26.000   Train_NMI: 0.693; Val_NMI: 20.413
# (Epoch 278 / 10000) Train_Loss: 56.261; Val_Loss: 52.593   Train_ACC: 13.084; Val_ACC: 26.000   Train_NMI: 0.737; Val_NMI: 21.251
# (Epoch 279 / 10000) Train_Loss: 55.495; Val_Loss: 53.157   Train_ACC: 13.417; Val_ACC: 26.000   Train_NMI: 0.778; Val_NMI: 22.380
# (Epoch 280 / 10000) Train_Loss: 58.171; Val_Loss: 55.693   Train_ACC: 12.787; Val_ACC: 26.000   Train_NMI: 0.733; Val_NMI: 23.876
# (Epoch 281 / 10000) Train_Loss: 56.762; Val_Loss: 50.967   Train_ACC: 13.047; Val_ACC: 24.000   Train_NMI: 0.712; Val_NMI: 21.665
# (Epoch 282 / 10000) Train_Loss: 55.247; Val_Loss: 48.381   Train_ACC: 12.824; Val_ACC: 24.000   Train_NMI: 0.647; Val_NMI: 21.500
# (Epoch 283 / 10000) Train_Loss: 55.155; Val_Loss: 50.293   Train_ACC: 12.824; Val_ACC: 26.000   Train_NMI: 0.710; Val_NMI: 23.016
# (Epoch 284 / 10000) Train_Loss: 56.554; Val_Loss: 53.767   Train_ACC: 12.713; Val_ACC: 24.000   Train_NMI: 0.706; Val_NMI: 21.163
# (Epoch 285 / 10000) Train_Loss: 56.599; Val_Loss: 51.865   Train_ACC: 13.232; Val_ACC: 25.000   Train_NMI: 0.750; Val_NMI: 20.579
# (Epoch 286 / 10000) Train_Loss: 54.277; Val_Loss: 50.141   Train_ACC: 12.713; Val_ACC: 26.000   Train_NMI: 0.641; Val_NMI: 21.589
# (Epoch 287 / 10000) Train_Loss: 53.287; Val_Loss: 51.910   Train_ACC: 12.750; Val_ACC: 25.000   Train_NMI: 0.723; Val_NMI: 22.446
# (Epoch 288 / 10000) Train_Loss: 55.232; Val_Loss: 51.255   Train_ACC: 12.898; Val_ACC: 24.000   Train_NMI: 0.698; Val_NMI: 21.351
# (Epoch 289 / 10000) Train_Loss: 56.904; Val_Loss: 66.226   Train_ACC: 12.824; Val_ACC: 24.000   Train_NMI: 0.631; Val_NMI: 20.896
# (Epoch 290 / 10000) Train_Loss: 66.377; Val_Loss: 59.077   Train_ACC: 12.750; Val_ACC: 24.000   Train_NMI: 0.696; Val_NMI: 19.956
# (Epoch 291 / 10000) Train_Loss: 61.303; Val_Loss: 53.161   Train_ACC: 12.602; Val_ACC: 26.000   Train_NMI: 0.628; Val_NMI: 21.959
# (Epoch 292 / 10000) Train_Loss: 56.401; Val_Loss: 50.640   Train_ACC: 12.861; Val_ACC: 24.000   Train_NMI: 0.688; Val_NMI: 19.786
# (Epoch 293 / 10000) Train_Loss: 53.213; Val_Loss: 49.155   Train_ACC: 13.121; Val_ACC: 25.000   Train_NMI: 0.661; Val_NMI: 22.760
# (Epoch 294 / 10000) Train_Loss: 53.867; Val_Loss: 48.726   Train_ACC: 13.010; Val_ACC: 25.000   Train_NMI: 0.658; Val_NMI: 20.438
# (Epoch 295 / 10000) Train_Loss: 52.217; Val_Loss: 48.354   Train_ACC: 13.010; Val_ACC: 25.000   Train_NMI: 0.702; Val_NMI: 22.760
# (Epoch 296 / 10000) Train_Loss: 52.082; Val_Loss: 47.746   Train_ACC: 13.010; Val_ACC: 26.000   Train_NMI: 0.693; Val_NMI: 22.774
# (Epoch 297 / 10000) Train_Loss: 51.554; Val_Loss: 46.056   Train_ACC: 12.528; Val_ACC: 26.000   Train_NMI: 0.617; Val_NMI: 22.480
# (Epoch 298 / 10000) Train_Loss: 51.467; Val_Loss: 48.417   Train_ACC: 12.861; Val_ACC: 25.000   Train_NMI: 0.677; Val_NMI: 22.479
# (Epoch 299 / 10000) Train_Loss: 52.703; Val_Loss: 48.557   Train_ACC: 13.084; Val_ACC: 26.000   Train_NMI: 0.733; Val_NMI: 23.555
# (Epoch 300 / 10000) Train_Loss: 52.257; Val_Loss: 46.863   Train_ACC: 12.824; Val_ACC: 26.000   Train_NMI: 0.638; Val_NMI: 19.311
# (Epoch 301 / 10000) Train_Loss: 51.772; Val_Loss: 47.114   Train_ACC: 13.195; Val_ACC: 25.000   Train_NMI: 0.767; Val_NMI: 21.153
# (Epoch 302 / 10000) Train_Loss: 52.576; Val_Loss: 47.926   Train_ACC: 13.084; Val_ACC: 26.000   Train_NMI: 0.742; Val_NMI: 21.112
# (Epoch 303 / 10000) Train_Loss: 51.348; Val_Loss: 47.129   Train_ACC: 13.084; Val_ACC: 25.000   Train_NMI: 0.806; Val_NMI: 20.229
# (Epoch 304 / 10000) Train_Loss: 51.467; Val_Loss: 47.931   Train_ACC: 12.676; Val_ACC: 26.000   Train_NMI: 0.720; Val_NMI: 21.333
# (Epoch 305 / 10000) Train_Loss: 52.681; Val_Loss: 48.052   Train_ACC: 13.010; Val_ACC: 25.000   Train_NMI: 0.766; Val_NMI: 21.153
# (Epoch 306 / 10000) Train_Loss: 58.325; Val_Loss: 52.364   Train_ACC: 12.861; Val_ACC: 26.000   Train_NMI: 0.701; Val_NMI: 23.337
# (Epoch 307 / 10000) Train_Loss: 56.750; Val_Loss: 53.196   Train_ACC: 13.010; Val_ACC: 25.000   Train_NMI: 0.786; Val_NMI: 20.584
# (Epoch 308 / 10000) Train_Loss: 54.360; Val_Loss: 49.720   Train_ACC: 13.121; Val_ACC: 25.000   Train_NMI: 0.748; Val_NMI: 21.128
# (Epoch 309 / 10000) Train_Loss: 52.812; Val_Loss: 48.446   Train_ACC: 13.343; Val_ACC: 25.000   Train_NMI: 0.768; Val_NMI: 21.043
# (Epoch 310 / 10000) Train_Loss: 54.003; Val_Loss: 50.142   Train_ACC: 13.158; Val_ACC: 27.000   Train_NMI: 0.772; Val_NMI: 22.750
# (Epoch 311 / 10000) Train_Loss: 52.683; Val_Loss: 48.110   Train_ACC: 13.158; Val_ACC: 25.000   Train_NMI: 0.824; Val_NMI: 20.644
# (Epoch 312 / 10000) Train_Loss: 52.494; Val_Loss: 47.858   Train_ACC: 12.861; Val_ACC: 26.000   Train_NMI: 0.816; Val_NMI: 22.189
# (Epoch 313 / 10000) Train_Loss: 53.146; Val_Loss: 49.434   Train_ACC: 13.047; Val_ACC: 25.000   Train_NMI: 0.728; Val_NMI: 20.549
# (Epoch 314 / 10000) Train_Loss: 52.518; Val_Loss: 47.381   Train_ACC: 13.121; Val_ACC: 24.000   Train_NMI: 0.759; Val_NMI: 19.610
# (Epoch 315 / 10000) Train_Loss: 50.526; Val_Loss: 45.958   Train_ACC: 13.121; Val_ACC: 25.000   Train_NMI: 0.724; Val_NMI: 20.265
# (Epoch 316 / 10000) Train_Loss: 51.163; Val_Loss: 46.925   Train_ACC: 13.121; Val_ACC: 25.000   Train_NMI: 0.740; Val_NMI: 21.286
# (Epoch 317 / 10000) Train_Loss: 50.555; Val_Loss: 48.886   Train_ACC: 12.787; Val_ACC: 24.000   Train_NMI: 0.667; Val_NMI: 20.398
# (Epoch 318 / 10000) Train_Loss: 50.513; Val_Loss: 47.730   Train_ACC: 12.824; Val_ACC: 25.000   Train_NMI: 0.686; Val_NMI: 20.680
# (Epoch 319 / 10000) Train_Loss: 51.136; Val_Loss: 49.077   Train_ACC: 12.676; Val_ACC: 24.000   Train_NMI: 0.672; Val_NMI: 19.464
# (Epoch 320 / 10000) Train_Loss: 52.638; Val_Loss: 46.370   Train_ACC: 12.787; Val_ACC: 24.000   Train_NMI: 0.674; Val_NMI: 20.382
# (Epoch 321 / 10000) Train_Loss: 54.168; Val_Loss: 47.702   Train_ACC: 12.861; Val_ACC: 26.000   Train_NMI: 0.648; Val_NMI: 20.517
# (Epoch 322 / 10000) Train_Loss: 54.636; Val_Loss: 48.915   Train_ACC: 12.787; Val_ACC: 26.000   Train_NMI: 0.686; Val_NMI: 20.025
# (Epoch 323 / 10000) Train_Loss: 52.054; Val_Loss: 46.046   Train_ACC: 13.084; Val_ACC: 25.000   Train_NMI: 0.724; Val_NMI: 20.809
# (Epoch 324 / 10000) Train_Loss: 51.892; Val_Loss: 48.868   Train_ACC: 12.639; Val_ACC: 24.000   Train_NMI: 0.689; Val_NMI: 19.205
# (Epoch 325 / 10000) Train_Loss: 52.183; Val_Loss: 47.299   Train_ACC: 12.713; Val_ACC: 26.000   Train_NMI: 0.674; Val_NMI: 24.095
# (Epoch 326 / 10000) Train_Loss: 50.663; Val_Loss: 46.248   Train_ACC: 12.787; Val_ACC: 26.000   Train_NMI: 0.749; Val_NMI: 22.457
# (Epoch 327 / 10000) Train_Loss: 52.759; Val_Loss: 49.044   Train_ACC: 12.861; Val_ACC: 27.000   Train_NMI: 0.725; Val_NMI: 22.403
# (Epoch 328 / 10000) Train_Loss: 52.484; Val_Loss: 45.906   Train_ACC: 13.232; Val_ACC: 24.000   Train_NMI: 0.732; Val_NMI: 19.135
# (Epoch 329 / 10000) Train_Loss: 49.721; Val_Loss: 43.702   Train_ACC: 12.898; Val_ACC: 26.000   Train_NMI: 0.699; Val_NMI: 19.474
# (Epoch 330 / 10000) Train_Loss: 50.055; Val_Loss: 47.277   Train_ACC: 13.047; Val_ACC: 26.000   Train_NMI: 0.622; Val_NMI: 22.729
# (Epoch 331 / 10000) Train_Loss: 49.728; Val_Loss: 45.853   Train_ACC: 13.121; Val_ACC: 23.000   Train_NMI: 0.763; Val_NMI: 19.614
# (Epoch 332 / 10000) Train_Loss: 53.835; Val_Loss: 48.985   Train_ACC: 12.639; Val_ACC: 24.000   Train_NMI: 0.636; Val_NMI: 20.544
# (Epoch 333 / 10000) Train_Loss: 52.070; Val_Loss: 45.435   Train_ACC: 12.750; Val_ACC: 24.000   Train_NMI: 0.610; Val_NMI: 20.711
# (Epoch 334 / 10000) Train_Loss: 50.197; Val_Loss: 47.013   Train_ACC: 13.010; Val_ACC: 25.000   Train_NMI: 0.718; Val_NMI: 21.588
# (Epoch 335 / 10000) Train_Loss: 49.051; Val_Loss: 46.661   Train_ACC: 12.750; Val_ACC: 25.000   Train_NMI: 0.652; Val_NMI: 21.177
# (Epoch 336 / 10000) Train_Loss: 51.100; Val_Loss: 45.107   Train_ACC: 12.713; Val_ACC: 25.000   Train_NMI: 0.695; Val_NMI: 20.713
# (Epoch 337 / 10000) Train_Loss: 50.065; Val_Loss: 45.225   Train_ACC: 12.676; Val_ACC: 24.000   Train_NMI: 0.678; Val_NMI: 18.656
# (Epoch 338 / 10000) Train_Loss: 48.438; Val_Loss: 44.910   Train_ACC: 13.010; Val_ACC: 26.000   Train_NMI: 0.722; Val_NMI: 20.835
# (Epoch 339 / 10000) Train_Loss: 48.803; Val_Loss: 45.395   Train_ACC: 12.528; Val_ACC: 24.000   Train_NMI: 0.704; Val_NMI: 19.595
# (Epoch 340 / 10000) Train_Loss: 49.089; Val_Loss: 45.333   Train_ACC: 12.861; Val_ACC: 24.000   Train_NMI: 0.704; Val_NMI: 19.927
# (Epoch 341 / 10000) Train_Loss: 49.752; Val_Loss: 46.056   Train_ACC: 12.750; Val_ACC: 24.000   Train_NMI: 0.701; Val_NMI: 20.292
# (Epoch 342 / 10000) Train_Loss: 48.996; Val_Loss: 43.994   Train_ACC: 12.861; Val_ACC: 25.000   Train_NMI: 0.671; Val_NMI: 20.212
# (Epoch 343 / 10000) Train_Loss: 48.731; Val_Loss: 43.819   Train_ACC: 13.232; Val_ACC: 26.000   Train_NMI: 0.756; Val_NMI: 22.596
# (Epoch 344 / 10000) Train_Loss: 48.444; Val_Loss: 45.958   Train_ACC: 12.750; Val_ACC: 26.000   Train_NMI: 0.687; Val_NMI: 21.492
# (Epoch 345 / 10000) Train_Loss: 48.051; Val_Loss: 42.516   Train_ACC: 12.824; Val_ACC: 26.000   Train_NMI: 0.691; Val_NMI: 21.223
# (Epoch 346 / 10000) Train_Loss: 46.820; Val_Loss: 44.757   Train_ACC: 12.824; Val_ACC: 25.000   Train_NMI: 0.689; Val_NMI: 19.561
# (Epoch 347 / 10000) Train_Loss: 48.028; Val_Loss: 43.824   Train_ACC: 12.602; Val_ACC: 25.000   Train_NMI: 0.714; Val_NMI: 22.508
# (Epoch 348 / 10000) Train_Loss: 47.423; Val_Loss: 43.385   Train_ACC: 12.936; Val_ACC: 26.000   Train_NMI: 0.663; Val_NMI: 22.373
# (Epoch 349 / 10000) Train_Loss: 48.418; Val_Loss: 41.875   Train_ACC: 12.750; Val_ACC: 26.000   Train_NMI: 0.768; Val_NMI: 22.801
# (Epoch 350 / 10000) Train_Loss: 49.139; Val_Loss: 49.443   Train_ACC: 12.861; Val_ACC: 26.000   Train_NMI: 0.729; Val_NMI: 22.748
# (Epoch 351 / 10000) Train_Loss: 49.770; Val_Loss: 44.645   Train_ACC: 12.973; Val_ACC: 24.000   Train_NMI: 0.726; Val_NMI: 20.369
# (Epoch 352 / 10000) Train_Loss: 47.959; Val_Loss: 45.517   Train_ACC: 12.787; Val_ACC: 26.000   Train_NMI: 0.597; Val_NMI: 22.519
# (Epoch 353 / 10000) Train_Loss: 47.982; Val_Loss: 47.802   Train_ACC: 12.936; Val_ACC: 25.000   Train_NMI: 0.699; Val_NMI: 21.367
# (Epoch 354 / 10000) Train_Loss: 47.807; Val_Loss: 46.958   Train_ACC: 13.195; Val_ACC: 24.000   Train_NMI: 0.721; Val_NMI: 21.845
# (Epoch 355 / 10000) Train_Loss: 54.710; Val_Loss: 48.739   Train_ACC: 13.158; Val_ACC: 25.000   Train_NMI: 0.766; Val_NMI: 22.319
# (Epoch 356 / 10000) Train_Loss: 54.428; Val_Loss: 48.964   Train_ACC: 13.232; Val_ACC: 26.000   Train_NMI: 0.726; Val_NMI: 21.477
# (Epoch 357 / 10000) Train_Loss: 50.648; Val_Loss: 48.829   Train_ACC: 12.973; Val_ACC: 26.000   Train_NMI: 0.709; Val_NMI: 23.918
# (Epoch 358 / 10000) Train_Loss: 51.164; Val_Loss: 46.994   Train_ACC: 12.861; Val_ACC: 27.000   Train_NMI: 0.690; Val_NMI: 22.795
# (Epoch 359 / 10000) Train_Loss: 50.499; Val_Loss: 47.040   Train_ACC: 12.936; Val_ACC: 23.000   Train_NMI: 0.620; Val_NMI: 19.939
# (Epoch 360 / 10000) Train_Loss: 48.450; Val_Loss: 43.886   Train_ACC: 12.639; Val_ACC: 24.000   Train_NMI: 0.618; Val_NMI: 20.949
# (Epoch 361 / 10000) Train_Loss: 47.940; Val_Loss: 43.610   Train_ACC: 12.602; Val_ACC: 24.000   Train_NMI: 0.712; Val_NMI: 20.323
# (Epoch 362 / 10000) Train_Loss: 47.917; Val_Loss: 44.578   Train_ACC: 12.713; Val_ACC: 24.000   Train_NMI: 0.721; Val_NMI: 20.483
# (Epoch 363 / 10000) Train_Loss: 47.063; Val_Loss: 44.178   Train_ACC: 12.898; Val_ACC: 24.000   Train_NMI: 0.741; Val_NMI: 20.167
# (Epoch 364 / 10000) Train_Loss: 47.808; Val_Loss: 43.052   Train_ACC: 12.861; Val_ACC: 24.000   Train_NMI: 0.742; Val_NMI: 21.133
# (Epoch 365 / 10000) Train_Loss: 48.389; Val_Loss: 43.698   Train_ACC: 13.010; Val_ACC: 24.000   Train_NMI: 0.729; Val_NMI: 20.717
# (Epoch 366 / 10000) Train_Loss: 46.650; Val_Loss: 43.522   Train_ACC: 12.936; Val_ACC: 24.000   Train_NMI: 0.718; Val_NMI: 19.143
# (Epoch 367 / 10000) Train_Loss: 47.081; Val_Loss: 41.627   Train_ACC: 12.713; Val_ACC: 25.000   Train_NMI: 0.667; Val_NMI: 19.117
# (Epoch 368 / 10000) Train_Loss: 46.991; Val_Loss: 44.221   Train_ACC: 12.973; Val_ACC: 24.000   Train_NMI: 0.727; Val_NMI: 19.964
# ...
# (Epoch 9159 / 10000) Train_Loss: 25.446; Val_Loss: 24.023   Train_ACC: 9.822; Val_ACC: 27.000   Train_NMI: 1.261; Val_NMI: 37.787
# (Epoch 9160 / 10000) Train_Loss: 27.348; Val_Loss: 25.137   Train_ACC: 9.785; Val_ACC: 27.000   Train_NMI: 1.294; Val_NMI: 37.559
# (Epoch 9161 / 10000) Train_Loss: 27.177; Val_Loss: 24.574   Train_ACC: 9.822; Val_ACC: 27.000   Train_NMI: 1.346; Val_NMI: 37.787
# (Epoch 9162 / 10000) Train_Loss: 25.767; Val_Loss: 23.574   Train_ACC: 9.859; Val_ACC: 27.000   Train_NMI: 1.308; Val_NMI: 37.260
# (Epoch 9163 / 10000) Train_Loss: 26.628; Val_Loss: 26.268   Train_ACC: 9.896; Val_ACC: 27.000   Train_NMI: 1.363; Val_NMI: 37.260
# (Epoch 9164 / 10000) Train_Loss: 26.277; Val_Loss: 24.540   Train_ACC: 9.859; Val_ACC: 27.000   Train_NMI: 1.332; Val_NMI: 37.260
# (Epoch 9165 / 10000) Train_Loss: 25.132; Val_Loss: 24.712   Train_ACC: 9.822; Val_ACC: 27.000   Train_NMI: 1.292; Val_NMI: 37.260
# (Epoch 9166 / 10000) Train_Loss: 26.330; Val_Loss: 25.633   Train_ACC: 9.896; Val_ACC: 27.000   Train_NMI: 1.314; Val_NMI: 37.395
# (Epoch 9167 / 10000) Train_Loss: 26.914; Val_Loss: 24.678   Train_ACC: 10.044; Val_ACC: 27.000   Train_NMI: 1.343; Val_NMI: 36.969
# (Epoch 9168 / 10000) Train_Loss: 28.067; Val_Loss: 24.850   Train_ACC: 9.896; Val_ACC: 27.000   Train_NMI: 1.291; Val_NMI: 37.787
# (Epoch 9169 / 10000) Train_Loss: 25.527; Val_Loss: 23.627   Train_ACC: 9.711; Val_ACC: 27.000   Train_NMI: 1.263; Val_NMI: 37.787
# (Epoch 9170 / 10000) Train_Loss: 26.130; Val_Loss: 27.388   Train_ACC: 9.637; Val_ACC: 27.000   Train_NMI: 1.219; Val_NMI: 37.787
# (Epoch 9171 / 10000) Train_Loss: 26.865; Val_Loss: 24.303   Train_ACC: 9.822; Val_ACC: 27.000   Train_NMI: 1.333; Val_NMI: 37.787
# (Epoch 9172 / 10000) Train_Loss: 25.117; Val_Loss: 23.621   Train_ACC: 9.785; Val_ACC: 27.000   Train_NMI: 1.294; Val_NMI: 36.969
# (Epoch 9173 / 10000) Train_Loss: 24.493; Val_Loss: 24.372   Train_ACC: 10.007; Val_ACC: 27.000   Train_NMI: 1.359; Val_NMI: 37.590
# (Epoch 9174 / 10000) Train_Loss: 24.477; Val_Loss: 23.877   Train_ACC: 9.822; Val_ACC: 27.000   Train_NMI: 1.317; Val_NMI: 37.260
# (Epoch 9175 / 10000) Train_Loss: 25.286; Val_Loss: 24.321   Train_ACC: 9.785; Val_ACC: 27.000   Train_NMI: 1.335; Val_NMI: 37.260
# (Epoch 9176 / 10000) Train_Loss: 25.489; Val_Loss: 23.811   Train_ACC: 9.822; Val_ACC: 27.000   Train_NMI: 1.309; Val_NMI: 37.260
# (Epoch 9177 / 10000) Train_Loss: 25.423; Val_Loss: 24.265   Train_ACC: 9.859; Val_ACC: 27.000   Train_NMI: 1.310; Val_NMI: 37.104
# (Epoch 9178 / 10000) Train_Loss: 24.737; Val_Loss: 23.854   Train_ACC: 10.007; Val_ACC: 27.000   Train_NMI: 1.315; Val_NMI: 36.969
# (Epoch 9179 / 10000) Train_Loss: 24.828; Val_Loss: 23.835   Train_ACC: 9.859; Val_ACC: 27.000   Train_NMI: 1.277; Val_NMI: 37.260
# (Epoch 9180 / 10000) Train_Loss: 25.838; Val_Loss: 24.688   Train_ACC: 9.822; Val_ACC: 27.000   Train_NMI: 1.250; Val_NMI: 37.260
# (Epoch 9181 / 10000) Train_Loss: 26.751; Val_Loss: 24.305   Train_ACC: 9.748; Val_ACC: 27.000   Train_NMI: 1.235; Val_NMI: 37.260
# (Epoch 9182 / 10000) Train_Loss: 26.035; Val_Loss: 24.566   Train_ACC: 9.933; Val_ACC: 27.000   Train_NMI: 1.299; Val_NMI: 37.260
# (Epoch 9183 / 10000) Train_Loss: 25.917; Val_Loss: 24.811   Train_ACC: 9.785; Val_ACC: 27.000   Train_NMI: 1.285; Val_NMI: 36.969
# (Epoch 9184 / 10000) Train_Loss: 25.452; Val_Loss: 28.373   Train_ACC: 9.859; Val_ACC: 27.000   Train_NMI: 1.353; Val_NMI: 37.260
# (Epoch 9185 / 10000) Train_Loss: 26.727; Val_Loss: 27.163   Train_ACC: 9.785; Val_ACC: 27.000   Train_NMI: 1.272; Val_NMI: 37.260
# (Epoch 9186 / 10000) Train_Loss: 26.021; Val_Loss: 24.668   Train_ACC: 9.933; Val_ACC: 27.000   Train_NMI: 1.339; Val_NMI: 36.969
# (Epoch 9187 / 10000) Train_Loss: 25.081; Val_Loss: 28.286   Train_ACC: 10.007; Val_ACC: 27.000   Train_NMI: 1.342; Val_NMI: 37.260
# (Epoch 9188 / 10000) Train_Loss: 27.067; Val_Loss: 26.214   Train_ACC: 9.896; Val_ACC: 27.000   Train_NMI: 1.327; Val_NMI: 37.260
# (Epoch 9189 / 10000) Train_Loss: 26.750; Val_Loss: 26.010   Train_ACC: 9.748; Val_ACC: 27.000   Train_NMI: 1.283; Val_NMI: 37.260
# (Epoch 9190 / 10000) Train_Loss: 27.454; Val_Loss: 24.966   Train_ACC: 9.785; Val_ACC: 27.000   Train_NMI: 1.351; Val_NMI: 37.260
# (Epoch 9191 / 10000) Train_Loss: 29.090; Val_Loss: 26.103   Train_ACC: 9.822; Val_ACC: 27.000   Train_NMI: 1.300; Val_NMI: 37.260
# (Epoch 9192 / 10000) Train_Loss: 30.860; Val_Loss: 24.488   Train_ACC: 9.896; Val_ACC: 27.000   Train_NMI: 1.325; Val_NMI: 37.260
# (Epoch 9193 / 10000) Train_Loss: 26.760; Val_Loss: 25.748   Train_ACC: 9.822; Val_ACC: 27.000   Train_NMI: 1.321; Val_NMI: 37.260
# (Epoch 9194 / 10000) Train_Loss: 25.572; Val_Loss: 30.074   Train_ACC: 9.822; Val_ACC: 27.000   Train_NMI: 1.347; Val_NMI: 37.146
# (Epoch 9195 / 10000) Train_Loss: 25.555; Val_Loss: 24.527   Train_ACC: 9.896; Val_ACC: 28.000   Train_NMI: 1.352; Val_NMI: 37.714
# (Epoch 9196 / 10000) Train_Loss: 27.698; Val_Loss: 25.039   Train_ACC: 9.748; Val_ACC: 27.000   Train_NMI: 1.341; Val_NMI: 37.260
# (Epoch 9197 / 10000) Train_Loss: 26.336; Val_Loss: 26.654   Train_ACC: 9.748; Val_ACC: 27.000   Train_NMI: 1.278; Val_NMI: 37.787
# (Epoch 9198 / 10000) Train_Loss: 25.684; Val_Loss: 23.938   Train_ACC: 9.785; Val_ACC: 27.000   Train_NMI: 1.316; Val_NMI: 37.260
# (Epoch 9199 / 10000) Train_Loss: 25.974; Val_Loss: 25.388   Train_ACC: 9.859; Val_ACC: 27.000   Train_NMI: 1.328; Val_NMI: 37.356
# (Epoch 9200 / 10000) Train_Loss: 27.226; Val_Loss: 26.130   Train_ACC: 9.896; Val_ACC: 28.000   Train_NMI: 1.396; Val_NMI: 38.179
# (Epoch 9201 / 10000) Train_Loss: 25.822; Val_Loss: 27.667   Train_ACC: 9.711; Val_ACC: 27.000   Train_NMI: 1.287; Val_NMI: 37.787
# (Epoch 9202 / 10000) Train_Loss: 26.653; Val_Loss: 25.014   Train_ACC: 9.637; Val_ACC: 27.000   Train_NMI: 1.239; Val_NMI: 36.969
# (Epoch 9203 / 10000) Train_Loss: 26.101; Val_Loss: 27.077   Train_ACC: 9.822; Val_ACC: 27.000   Train_NMI: 1.341; Val_NMI: 37.260
# (Epoch 9204 / 10000) Train_Loss: 28.228; Val_Loss: 25.803   Train_ACC: 9.822; Val_ACC: 27.000   Train_NMI: 1.321; Val_NMI: 37.260
# (Epoch 9205 / 10000) Train_Loss: 28.787; Val_Loss: 25.970   Train_ACC: 9.785; Val_ACC: 27.000   Train_NMI: 1.283; Val_NMI: 37.260
# (Epoch 9206 / 10000) Train_Loss: 26.760; Val_Loss: 25.439   Train_ACC: 9.822; Val_ACC: 27.000   Train_NMI: 1.314; Val_NMI: 37.787
# (Epoch 9207 / 10000) Train_Loss: 25.681; Val_Loss: 24.017   Train_ACC: 9.822; Val_ACC: 27.000   Train_NMI: 1.327; Val_NMI: 37.260
# (Epoch 9208 / 10000) Train_Loss: 25.272; Val_Loss: 24.049   Train_ACC: 9.896; Val_ACC: 28.000   Train_NMI: 1.309; Val_NMI: 38.241
# (Epoch 9209 / 10000) Train_Loss: 25.100; Val_Loss: 25.655   Train_ACC: 9.896; Val_ACC: 27.000   Train_NMI: 1.329; Val_NMI: 37.260
# (Epoch 9210 / 10000) Train_Loss: 26.531; Val_Loss: 27.781   Train_ACC: 9.785; Val_ACC: 27.000   Train_NMI: 1.291; Val_NMI: 37.260
# (Epoch 9211 / 10000) Train_Loss: 25.900; Val_Loss: 25.030   Train_ACC: 9.785; Val_ACC: 27.000   Train_NMI: 1.322; Val_NMI: 37.725
# (Epoch 9212 / 10000) Train_Loss: 26.456; Val_Loss: 25.020   Train_ACC: 9.859; Val_ACC: 27.000   Train_NMI: 1.331; Val_NMI: 37.787
# (Epoch 9213 / 10000) Train_Loss: 28.186; Val_Loss: 25.841   Train_ACC: 9.822; Val_ACC: 28.000   Train_NMI: 1.302; Val_NMI: 37.714
# (Epoch 9214 / 10000) Train_Loss: 28.053; Val_Loss: 26.639   Train_ACC: 9.822; Val_ACC: 27.000   Train_NMI: 1.305; Val_NMI: 37.260
# (Epoch 9215 / 10000) Train_Loss: 27.085; Val_Loss: 24.581   Train_ACC: 9.970; Val_ACC: 27.000   Train_NMI: 1.349; Val_NMI: 37.260
# (Epoch 9216 / 10000) Train_Loss: 27.200; Val_Loss: 25.055   Train_ACC: 9.896; Val_ACC: 27.000   Train_NMI: 1.356; Val_NMI: 37.260
# (Epoch 9217 / 10000) Train_Loss: 26.303; Val_Loss: 24.597   Train_ACC: 9.933; Val_ACC: 27.000   Train_NMI: 1.338; Val_NMI: 37.260
# (Epoch 9218 / 10000) Train_Loss: 30.911; Val_Loss: 28.578   Train_ACC: 9.785; Val_ACC: 27.000   Train_NMI: 1.301; Val_NMI: 37.787
# (Epoch 9219 / 10000) Train_Loss: 30.705; Val_Loss: 25.262   Train_ACC: 9.637; Val_ACC: 28.000   Train_NMI: 1.236; Val_NMI: 37.600
# (Epoch 9220 / 10000) Train_Loss: 29.052; Val_Loss: 25.643   Train_ACC: 9.637; Val_ACC: 27.000   Train_NMI: 1.236; Val_NMI: 37.146
# (Epoch 9221 / 10000) Train_Loss: 27.503; Val_Loss: 27.457   Train_ACC: 9.896; Val_ACC: 27.000   Train_NMI: 1.284; Val_NMI: 37.787
# (Epoch 9222 / 10000) Train_Loss: 29.942; Val_Loss: 27.066   Train_ACC: 9.859; Val_ACC: 27.000   Train_NMI: 1.352; Val_NMI: 37.260
# (Epoch 9223 / 10000) Train_Loss: 27.432; Val_Loss: 24.996   Train_ACC: 9.711; Val_ACC: 27.000   Train_NMI: 1.287; Val_NMI: 36.855
# (Epoch 9224 / 10000) Train_Loss: 27.325; Val_Loss: 28.442   Train_ACC: 9.822; Val_ACC: 27.000   Train_NMI: 1.299; Val_NMI: 37.260
# (Epoch 9225 / 10000) Train_Loss: 29.713; Val_Loss: 25.574   Train_ACC: 9.896; Val_ACC: 27.000   Train_NMI: 1.315; Val_NMI: 37.260
# (Epoch 9226 / 10000) Train_Loss: 30.312; Val_Loss: 24.346   Train_ACC: 10.007; Val_ACC: 27.000   Train_NMI: 1.361; Val_NMI: 37.395
# (Epoch 9227 / 10000) Train_Loss: 28.790; Val_Loss: 25.326   Train_ACC: 9.970; Val_ACC: 27.000   Train_NMI: 1.417; Val_NMI: 37.260
# (Epoch 9228 / 10000) Train_Loss: 25.870; Val_Loss: 23.450   Train_ACC: 9.933; Val_ACC: 27.000   Train_NMI: 1.333; Val_NMI: 37.146
# (Epoch 9229 / 10000) Train_Loss: 24.731; Val_Loss: 24.114   Train_ACC: 9.933; Val_ACC: 27.000   Train_NMI: 1.319; Val_NMI: 37.146
# (Epoch 9230 / 10000) Train_Loss: 25.447; Val_Loss: 23.834   Train_ACC: 10.007; Val_ACC: 27.000   Train_NMI: 1.387; Val_NMI: 37.260
# (Epoch 9231 / 10000) Train_Loss: 26.511; Val_Loss: 25.845   Train_ACC: 9.859; Val_ACC: 27.000   Train_NMI: 1.323; Val_NMI: 37.725
# (Epoch 9232 / 10000) Train_Loss: 26.248; Val_Loss: 25.042   Train_ACC: 9.896; Val_ACC: 27.000   Train_NMI: 1.334; Val_NMI: 37.725
# (Epoch 9233 / 10000) Train_Loss: 27.248; Val_Loss: 25.501   Train_ACC: 9.933; Val_ACC: 27.000   Train_NMI: 1.352; Val_NMI: 37.725
# (Epoch 9234 / 10000) Train_Loss: 25.160; Val_Loss: 23.575   Train_ACC: 9.785; Val_ACC: 27.000   Train_NMI: 1.311; Val_NMI: 37.725
# (Epoch 9235 / 10000) Train_Loss: 25.014; Val_Loss: 23.953   Train_ACC: 9.933; Val_ACC: 28.000   Train_NMI: 1.388; Val_NMI: 38.179
# (Epoch 9236 / 10000) Train_Loss: 24.669; Val_Loss: 23.618   Train_ACC: 9.785; Val_ACC: 27.000   Train_NMI: 1.355; Val_NMI: 37.725
# (Epoch 9237 / 10000) Train_Loss: 25.783; Val_Loss: 25.146   Train_ACC: 9.785; Val_ACC: 27.000   Train_NMI: 1.274; Val_NMI: 37.301
# (Epoch 9238 / 10000) Train_Loss: 25.275; Val_Loss: 23.729   Train_ACC: 9.711; Val_ACC: 27.000   Train_NMI: 1.279; Val_NMI: 37.787
# (Epoch 9239 / 10000) Train_Loss: 25.728; Val_Loss: 23.777   Train_ACC: 9.748; Val_ACC: 27.000   Train_NMI: 1.320; Val_NMI: 36.969
# (Epoch 9240 / 10000) Train_Loss: 25.623; Val_Loss: 27.451   Train_ACC: 9.896; Val_ACC: 27.000   Train_NMI: 1.354; Val_NMI: 37.260
# (Epoch 9241 / 10000) Train_Loss: 25.928; Val_Loss: 26.261   Train_ACC: 9.859; Val_ACC: 27.000   Train_NMI: 1.313; Val_NMI: 36.969
# (Epoch 9242 / 10000) Train_Loss: 25.737; Val_Loss: 24.976   Train_ACC: 10.082; Val_ACC: 27.000   Train_NMI: 1.367; Val_NMI: 37.787
# (Epoch 9243 / 10000) Train_Loss: 24.907; Val_Loss: 24.073   Train_ACC: 9.748; Val_ACC: 27.000   Train_NMI: 1.251; Val_NMI: 36.969
# (Epoch 9244 / 10000) Train_Loss: 24.653; Val_Loss: 24.875   Train_ACC: 9.933; Val_ACC: 27.000   Train_NMI: 1.336; Val_NMI: 37.260
# (Epoch 9245 / 10000) Train_Loss: 24.861; Val_Loss: 24.253   Train_ACC: 10.044; Val_ACC: 27.000   Train_NMI: 1.340; Val_NMI: 36.670
# (Epoch 9246 / 10000) Train_Loss: 26.599; Val_Loss: 29.779   Train_ACC: 9.859; Val_ACC: 27.000   Train_NMI: 1.322; Val_NMI: 36.969
# (Epoch 9247 / 10000) Train_Loss: 31.207; Val_Loss: 27.611   Train_ACC: 9.822; Val_ACC: 28.000   Train_NMI: 1.349; Val_NMI: 38.479
# (Epoch 9248 / 10000) Train_Loss: 31.194; Val_Loss: 26.962   Train_ACC: 9.859; Val_ACC: 27.000   Train_NMI: 1.343; Val_NMI: 37.921
# (Epoch 9249 / 10000) Train_Loss: 27.436; Val_Loss: 25.069   Train_ACC: 9.970; Val_ACC: 27.000   Train_NMI: 1.381; Val_NMI: 37.409
# (Epoch 9250 / 10000) Train_Loss: 27.039; Val_Loss: 23.978   Train_ACC: 9.859; Val_ACC: 27.000   Train_NMI: 1.324; Val_NMI: 37.787
# (Epoch 9251 / 10000) Train_Loss: 25.476; Val_Loss: 26.447   Train_ACC: 9.896; Val_ACC: 27.000   Train_NMI: 1.318; Val_NMI: 37.395
# (Epoch 9252 / 10000) Train_Loss: 25.093; Val_Loss: 23.835   Train_ACC: 9.859; Val_ACC: 27.000   Train_NMI: 1.342; Val_NMI: 37.260
# (Epoch 9253 / 10000) Train_Loss: 26.260; Val_Loss: 25.045   Train_ACC: 9.822; Val_ACC: 27.000   Train_NMI: 1.298; Val_NMI: 37.146
# (Epoch 9254 / 10000) Train_Loss: 25.369; Val_Loss: 23.706   Train_ACC: 9.785; Val_ACC: 27.000   Train_NMI: 1.351; Val_NMI: 37.260
# (Epoch 9255 / 10000) Train_Loss: 25.523; Val_Loss: 25.143   Train_ACC: 10.007; Val_ACC: 27.000   Train_NMI: 1.341; Val_NMI: 37.260
# (Epoch 9256 / 10000) Train_Loss: 24.919; Val_Loss: 23.533   Train_ACC: 9.822; Val_ACC: 27.000   Train_NMI: 1.355; Val_NMI: 37.395
# (Epoch 9257 / 10000) Train_Loss: 25.505; Val_Loss: 27.560   Train_ACC: 9.970; Val_ACC: 27.000   Train_NMI: 1.384; Val_NMI: 37.787
# (Epoch 9258 / 10000) Train_Loss: 24.742; Val_Loss: 23.442   Train_ACC: 9.859; Val_ACC: 27.000   Train_NMI: 1.376; Val_NMI: 37.787
# (Epoch 9259 / 10000) Train_Loss: 24.516; Val_Loss: 23.227   Train_ACC: 9.933; Val_ACC: 27.000   Train_NMI: 1.359; Val_NMI: 37.260
# (Epoch 9260 / 10000) Train_Loss: 25.506; Val_Loss: 26.423   Train_ACC: 9.822; Val_ACC: 27.000   Train_NMI: 1.314; Val_NMI: 37.787
# (Epoch 9261 / 10000) Train_Loss: 25.644; Val_Loss: 32.246   Train_ACC: 9.859; Val_ACC: 27.000   Train_NMI: 1.355; Val_NMI: 37.787
# (Epoch 9262 / 10000) Train_Loss: 32.739; Val_Loss: 27.555   Train_ACC: 9.785; Val_ACC: 27.000   Train_NMI: 1.278; Val_NMI: 37.787
# (Epoch 9263 / 10000) Train_Loss: 27.010; Val_Loss: 24.286   Train_ACC: 9.785; Val_ACC: 27.000   Train_NMI: 1.301; Val_NMI: 37.787
# (Epoch 9264 / 10000) Train_Loss: 25.313; Val_Loss: 25.530   Train_ACC: 9.896; Val_ACC: 27.000   Train_NMI: 1.359; Val_NMI: 37.787
# (Epoch 9265 / 10000) Train_Loss: 26.541; Val_Loss: 25.160   Train_ACC: 9.822; Val_ACC: 27.000   Train_NMI: 1.338; Val_NMI: 37.787
# (Epoch 9266 / 10000) Train_Loss: 26.127; Val_Loss: 24.115   Train_ACC: 9.970; Val_ACC: 27.000   Train_NMI: 1.338; Val_NMI: 37.260
# (Epoch 9267 / 10000) Train_Loss: 25.856; Val_Loss: 25.264   Train_ACC: 9.933; Val_ACC: 27.000   Train_NMI: 1.327; Val_NMI: 37.260
# (Epoch 9268 / 10000) Train_Loss: 27.162; Val_Loss: 24.457   Train_ACC: 9.785; Val_ACC: 27.000   Train_NMI: 1.279; Val_NMI: 37.260
# (Epoch 9269 / 10000) Train_Loss: 26.753; Val_Loss: 24.887   Train_ACC: 9.896; Val_ACC: 27.000   Train_NMI: 1.327; Val_NMI: 37.260
# (Epoch 9270 / 10000) Train_Loss: 26.066; Val_Loss: 26.308   Train_ACC: 9.748; Val_ACC: 27.000   Train_NMI: 1.265; Val_NMI: 37.260
# (Epoch 9271 / 10000) Train_Loss: 25.334; Val_Loss: 24.083   Train_ACC: 9.711; Val_ACC: 27.000   Train_NMI: 1.266; Val_NMI: 37.787
# (Epoch 9272 / 10000) Train_Loss: 25.229; Val_Loss: 24.334   Train_ACC: 9.859; Val_ACC: 28.000   Train_NMI: 1.343; Val_NMI: 38.120
# (Epoch 9273 / 10000) Train_Loss: 25.100; Val_Loss: 25.738   Train_ACC: 9.896; Val_ACC: 27.000   Train_NMI: 1.321; Val_NMI: 37.260
# (Epoch 9274 / 10000) Train_Loss: 27.407; Val_Loss: 25.638   Train_ACC: 9.896; Val_ACC: 27.000   Train_NMI: 1.361; Val_NMI: 37.260
# (Epoch 9275 / 10000) Train_Loss: 29.121; Val_Loss: 29.087   Train_ACC: 9.933; Val_ACC: 27.000   Train_NMI: 1.353; Val_NMI: 37.260
# (Epoch 9276 / 10000) Train_Loss: 26.272; Val_Loss: 24.279   Train_ACC: 9.822; Val_ACC: 27.000   Train_NMI: 1.312; Val_NMI: 37.260
# (Epoch 9277 / 10000) Train_Loss: 25.877; Val_Loss: 24.434   Train_ACC: 9.785; Val_ACC: 27.000   Train_NMI: 1.323; Val_NMI: 36.969
# (Epoch 9278 / 10000) Train_Loss: 26.453; Val_Loss: 25.236   Train_ACC: 9.859; Val_ACC: 27.000   Train_NMI: 1.350; Val_NMI: 36.969
# (Epoch 9279 / 10000) Train_Loss: 25.133; Val_Loss: 29.501   Train_ACC: 9.785; Val_ACC: 27.000   Train_NMI: 1.321; Val_NMI: 36.969
# (Epoch 9280 / 10000) Train_Loss: 27.124; Val_Loss: 25.967   Train_ACC: 9.896; Val_ACC: 27.000   Train_NMI: 1.336; Val_NMI: 36.969
# (Epoch 9281 / 10000) Train_Loss: 26.489; Val_Loss: 24.587   Train_ACC: 9.896; Val_ACC: 27.000   Train_NMI: 1.343; Val_NMI: 36.969

# %%
torch.save(gmvae.network.state_dict(), f'smba_gmvae_8_{num_epochs}.pth')

# %%
gmvae.network.load_state_dict(torch.load('smba_gmvae.pth'))
# Out:
# <All keys matched successfully>

# %%
# with open('training_history.json', 'w+') as json_f:
#     json.dump(history_loss, json_f)

# %% [markdown]
# ## Image Reconstruction

# %%
size_of_training_set = len(train_ds)
size_of_training_set
# Out:
# 2698

# %%
original, reconstructed = gmvae.reconstruct_data(train_dl, size_of_training_set)

# %%
original_int = original.reshape(size_of_training_set, 16, 16, 12).argmax(axis=-1)
reconstructed_int = reconstructed.reshape(size_of_training_set, 16, 16, 12).argmax(axis=-1)

# %%
errors = reconstructed_int != original_int

# %% [markdown]
# Number of errors per chunk:

# %%
np.sum(errors) / size_of_training_set
# Out:
# 3.0937731653076352

# %%
# the tile indexes that are incorrectly reconstructed
tile_idx_errors = original_int[errors]

# %%
char2int_smb = { 
    "X": 0,  # smb unpassable
    "S": 1,  # smb breakable
    "-": 2,
    "?": 3,  # smb question
    "Q": 4,  # smb question
    "E": 5,
    "<": 6,
    ">": 7,
    "[": 8,
    "]": 9,
    "o": 10,
    "P": 11,  # for smb path (from Anurag's email)
}

int2char_smb = {v:k for k, v in char2int_smb.items()}

# %% [markdown]
# Proportion of errors for each tile type:

# %%
plt.bar(np.unique(tile_idx_errors), np.bincount(tile_idx_errors) / np.bincount(original_int.flatten()))
plt.xticks(np.unique(tile_idx_errors), [int2char_smb[i] for i in np.unique(tile_idx_errors)])
plt.show()

# %%
def get_classes(chunks_int):
    classes = []
    for i in chunks_int:
        if i.max() == 6:
            classes.append('kia')
        else:
            classes.append('smba')
    return np.array(classes)

# %%
org_classes = get_classes(original_int)
rec_classes = get_classes(reconstructed_int)
assert np.sum(org_classes == rec_classes) == len(org_classes)

# %%
def get_images(chunks_int):
    images = []
    for game, chunk in zip(get_classes(chunks_int), chunks_int):
        images.append(vglc_with_path_encodings.array_to_image([chunk], game=game)[0])
    return images

# %%
org_images = get_images(original_int)
rec_images = get_images(reconstructed_int)
len(org_images), len(rec_images)
# Out:
# (2698, 2698)

# %%
fig, axes = plt.subplots(nrows=3, ncols=10, figsize=(24, 8))
axes = axes.flatten()
nrows, ncols = 3, 10

org_idxs = np.arange(0, 29, 2)
rec_idxs = org_idxs + 1

for idx in org_idxs:
        
    ax = axes[idx]

    ax.imshow(np.asarray(org_images[idx // 2]))
    ax.set_title(f'Org {idx // 2 + 1}')
    
    ax.axis('off')

for idx in rec_idxs:
        
    ax = axes[idx]

    ax.imshow(np.asarray(rec_images[idx // 2]))
    ax.set_title(f'Rec {idx // 2 + 1}')

    ax.axis('off')
    
plt.show()

# %% [markdown]
# ## Random Generation per Category

# %%
def display_random_generation(generated, num_classes, n=10):
    plt.figure(figsize=[24,24])
    for c in range(num_classes):
        for i in range(n):
            plt.subplot(num_classes, n, (c * n) + i + 1)
            chunk_int = generated[(c * n) + i].reshape(16, 16, 12).argmax(axis=-1)
            chunk_pix = vglc_with_path_encodings.array_to_image([chunk_int], game='smba')[0]
            plt.imshow(chunk_pix)
            plt.gray()
            plt.axis('off')
    plt.show()

elem_per_category = 8
generated = gmvae.random_generation(elem_per_category)
display_random_generation(generated, args.num_classes, elem_per_category)

# %%
elem_per_category = 10000 // 8
generated = gmvae.random_generation(elem_per_category)

# %%
generated_int = generated.reshape(-1, 16, 16, 12).argmax(axis=-1)

# %%
generated_int.shape
# Out:
# (10000, 16, 16)

# %%
# since this code chunk depends on random seed, it shouldn't be run again
with open(f'../smba_generations/smba_gmvae_8_{num_epochs}.json', 'w+') as json_f:
    json.dump(generated_int.tolist(), json_f)

# %% [markdown]
# ## Visualization of the feature latent space

# %%
# get feature representations
test_features, test_labels = gmvae.latent_features(train_dl, return_learned_labels=True)

# %%
np.bincount(test_labels)
# Out:
# array([329, 304, 330, 436, 199, 257, 272, 301])

# %%
# import TSNE from scikit-learn library
from sklearn.manifold import TSNE

# reduce dimensionality to 2D, we consider a subset of data because TSNE
# is a slow algorithm

first_n = 1000
tsne_features = TSNE(n_components=2).fit_transform(test_features[:first_n])

# %%
test_labels_subset = test_labels[:first_n]

# %%
X_, Y_ = np.s_[:,0], np.s_[:,1]

# %%
fig = plt.figure(figsize=(5, 5))

plt.scatter(tsne_features[X_], tsne_features[Y_], c=test_labels_subset, cmap='tab10')

plt.title('Projection from latent space to 2D')
plt.show()
