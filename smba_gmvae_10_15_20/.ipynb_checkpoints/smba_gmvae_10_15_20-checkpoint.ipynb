# %% [markdown]
# # GM-VAE for KI

# %%
num_epochs=10000
num_components=2  # only the starting number of components

# %% [markdown]
# ## Import Libraries

# %%
import json

import numpy as np
import argparse
import random
from torchvision import datasets, transforms
from torch.utils.data import TensorDataset, DataLoader
from torch.utils.data.sampler import SubsetRandomSampler
import torch.utils.data
from scipy.io import loadmat

import sys
sys.path.append('/home/yangz2/projects/gmvae_and_gmmvae/pytorch/')
sys.path.append('../../1906-pcgml/pcgml-gmmVae-exp/modules/')
import vglc_with_path_encodings

from model.GMVAE import *
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

import warnings
warnings.filterwarnings('ignore')

import sys
sys.path.append('/home/yangz2/projects/modules/')
from log_training_progress import email_training_progress

# %% [markdown]
# ## Load data

# %%
def open_json_as_nparray(json_fname):
    with open(json_fname, 'r') as json_f:
        return np.array(json.load(json_f))

# %%
chunks_int = open_json_as_nparray('/home/yangz2/projects/gmvae_and_gmmvae/data/kia_chunks_int.json')
chunks_onehot = np.eye(len(np.unique(chunks_int)))[chunks_int]
chunks_onehot.shape
# Out:
# (1142, 16, 16, 7)

# %%
chunks_onehot = chunks_onehot.reshape(
    chunks_onehot.shape[0], 
    chunks_onehot.shape[1] * chunks_onehot.shape[2] * chunks_onehot.shape[3]
)
chunks_onehot.shape
# Out:
# (1142, 1792)

# %%
def get_random_labels(num_components, size):
    return np.random.randint(num_components, size=size)

# %% [markdown]
# ## Input Parameters

# %%
num_components = 8

# %%
########################################################
## Input Parameters
#########################################################
parser = argparse.ArgumentParser(description='PyTorch Implementation of DGM Clustering')

## Used only in notebooks
parser.add_argument('-f', '--file',
                    help='Path for input file. First line should contain number of lines to search in')

## Dataset
parser.add_argument('--dataset', type=str, choices=['mnist'],
                    default='mnist', help='dataset (default: mnist)')
parser.add_argument('--seed', type=int, default=1, help='random seed (default: 1)')

## GPU
parser.add_argument('--cuda', type=int, default=1,
                    help='use of cuda (default: 1)')
parser.add_argument('--gpuID', type=int, default=0,
                    help='set gpu id to use (default: 0)')

## Training
parser.add_argument('--epochs', type=int, default=num_epochs,
                    help='number of total epochs to run (default: 200)')
parser.add_argument('--batch_size', default=64, type=int,
                    help='mini-batch size (default: 64)')
parser.add_argument('--batch_size_val', default=200, type=int,
                    help='mini-batch size of validation (default: 200)')
parser.add_argument('--learning_rate', default=1e-3, type=float,
                    help='learning rate (default: 0.001)')
parser.add_argument('--decay_epoch', default=-1, type=int, 
                    help='Reduces the learning rate every decay_epoch')
parser.add_argument('--lr_decay', default=0.5, type=float,
                    help='Learning rate decay for training (default: 0.5)')

## Architecture
parser.add_argument('--num_classes', type=int, default=num_components,
                    help='number of classes (default: 10)')  # edited for this task
parser.add_argument('--gaussian_size', default=64, type=int,
                    help='gaussian size (default: 64)')
parser.add_argument('--input_size', default=1792, type=int,
                    help='input size (default: 784)')  # edited for this task

## Partition parameters
parser.add_argument('--train_proportion', default=1, type=float,
                    help='proportion of examples to consider for training only (default: 1.0)')

## Gumbel parameters
parser.add_argument('--init_temp', default=1.0, type=float,
                    help='Initial temperature used in gumbel-softmax (recommended 0.5-1.0, default:1.0)')
parser.add_argument('--decay_temp', default=1, type=int, 
                    help='Set 1 to decay gumbel temperature at every epoch (default: 1)')
parser.add_argument('--hard_gumbel', default=0, type=int, 
                    help='Set 1 to use the hard version of gumbel-softmax (default: 1)')
parser.add_argument('--min_temp', default=0.5, type=float, 
                    help='Minimum temperature of gumbel-softmax after annealing (default: 0.5)' )
parser.add_argument('--decay_temp_rate', default=0.013862944, type=float,
                    help='Temperature decay rate at every epoch (default: 0.013862944)')

## Loss function parameters
parser.add_argument('--w_gauss', default=2, type=float,
                    help='weight of gaussian loss (default: 1)')
parser.add_argument('--w_categ', default=1, type=float,
                    help='weight of categorical loss (default: 1)')
parser.add_argument('--w_rec', default=1, type=float,
                    help='weight of reconstruction loss (default: 1)')
parser.add_argument('--rec_type', type=str, choices=['bce', 'mse'],
                    default='bce', help='desired reconstruction loss function (default: bce)')

## Others
parser.add_argument('--verbose', default=0, type=int,
                    help='print extra information at every epoch.(default: 0)')

args = parser.parse_args()

# %% [markdown]
# Set random seed in case it was specified in the parameters

# %%
## Random Seed
SEED = args.seed
np.random.seed(SEED)
random.seed(SEED)
torch.manual_seed(SEED)
if args.cuda:
    torch.cuda.manual_seed(SEED)

# %% [markdown]
# ## Data Partition

# %% [markdown]
# We split the training data into train and validation according to the *train_proportion* parameter:

# %%
def get_train_dl_and_valid_dl(chunks, labels):

    valid_indices = np.random.randint(len(chunks), size=100)
    train_chunks, valid_chunks = chunks, chunks[valid_indices]
    train_labels, valid_labels = labels, labels[valid_indices]

    train_ds = TensorDataset(torch.from_numpy(train_chunks).float(), torch.from_numpy(train_labels).long())
    valid_ds = TensorDataset(torch.from_numpy(valid_chunks).float(), torch.from_numpy(valid_labels).long())

    train_dl = DataLoader(train_ds, batch_size=args.batch_size, shuffle=True)
    valid_dl = DataLoader(valid_ds, batch_size=args.batch_size_val, shuffle=False)
    
    return train_dl, valid_dl

# %% [markdown]
# ## Train Model

# %%
for num_components in [2, 4, 6, 8]:
    
    args.num_classes = num_components
    gmvae = GMVAE(args)
    
    labels = get_random_labels(num_components, len(chunks_onehot))
    train_dl, valid_dl = get_train_dl_and_valid_dl(chunks_onehot, labels)
    gmvae.train(train_dl, valid_dl)
    
    torch.save(
        gmvae.network.state_dict(),
        f'../qualitative_clustering_analysis/kia_gmvae_{num_components}_{num_epochs}.pth'
    )
    
    email_training_progress(f'GM-VAE with {num_components} components has finished training!')
email_training_progress('Shutdown VM now!')
# Out:
# (Epoch 1 / 10000) Train_Loss: 670.368; Val_Loss: 456.772   Train_ACC: 50.963; Val_ACC: 51.000   Train_NMI: 0.000; Val_NMI: -0.000
# (Epoch 2 / 10000) Train_Loss: 452.215; Val_Loss: 444.853   Train_ACC: 51.401; Val_ACC: 52.000   Train_NMI: 0.028; Val_NMI: 0.187
# (Epoch 3 / 10000) Train_Loss: 445.586; Val_Loss: 442.764   Train_ACC: 51.489; Val_ACC: 55.000   Train_NMI: 0.014; Val_NMI: 0.887
# (Epoch 4 / 10000) Train_Loss: 444.683; Val_Loss: 440.403   Train_ACC: 52.102; Val_ACC: 55.000   Train_NMI: 0.075; Val_NMI: 0.804
# (Epoch 5 / 10000) Train_Loss: 444.238; Val_Loss: 440.175   Train_ACC: 52.014; Val_ACC: 52.000   Train_NMI: 0.066; Val_NMI: 0.174
# (Epoch 6 / 10000) Train_Loss: 440.631; Val_Loss: 431.760   Train_ACC: 52.102; Val_ACC: 53.000   Train_NMI: 0.040; Val_NMI: 0.287
# (Epoch 7 / 10000) Train_Loss: 430.552; Val_Loss: 423.779   Train_ACC: 50.613; Val_ACC: 53.000   Train_NMI: 0.002; Val_NMI: 0.313
# (Epoch 8 / 10000) Train_Loss: 427.819; Val_Loss: 423.584   Train_ACC: 50.613; Val_ACC: 54.000   Train_NMI: 0.014; Val_NMI: 1.359
# (Epoch 9 / 10000) Train_Loss: 426.112; Val_Loss: 422.902   Train_ACC: 51.138; Val_ACC: 55.000   Train_NMI: 0.014; Val_NMI: 0.706
# (Epoch 10 / 10000) Train_Loss: 425.657; Val_Loss: 421.288   Train_ACC: 52.102; Val_ACC: 51.000   Train_NMI: 0.182; Val_NMI: 0.058
# (Epoch 11 / 10000) Train_Loss: 424.267; Val_Loss: 422.424   Train_ACC: 51.051; Val_ACC: 56.000   Train_NMI: 0.053; Val_NMI: 1.021
# (Epoch 12 / 10000) Train_Loss: 422.161; Val_Loss: 418.859   Train_ACC: 50.876; Val_ACC: 56.000   Train_NMI: 0.039; Val_NMI: 1.035
# (Epoch 13 / 10000) Train_Loss: 420.477; Val_Loss: 417.502   Train_ACC: 51.926; Val_ACC: 56.000   Train_NMI: 0.111; Val_NMI: 1.026
# (Epoch 14 / 10000) Train_Loss: 419.602; Val_Loss: 415.098   Train_ACC: 51.489; Val_ACC: 55.000   Train_NMI: 0.073; Val_NMI: 0.702
# (Epoch 15 / 10000) Train_Loss: 418.608; Val_Loss: 416.031   Train_ACC: 52.102; Val_ACC: 54.000   Train_NMI: 0.144; Val_NMI: 0.451
# (Epoch 16 / 10000) Train_Loss: 418.157; Val_Loss: 414.306   Train_ACC: 52.189; Val_ACC: 53.000   Train_NMI: 0.146; Val_NMI: 0.276
# (Epoch 17 / 10000) Train_Loss: 416.859; Val_Loss: 412.203   Train_ACC: 51.751; Val_ACC: 54.000   Train_NMI: 0.093; Val_NMI: 0.479
# (Epoch 18 / 10000) Train_Loss: 415.502; Val_Loss: 413.417   Train_ACC: 51.751; Val_ACC: 54.000   Train_NMI: 0.095; Val_NMI: 0.467
# (Epoch 19 / 10000) Train_Loss: 413.695; Val_Loss: 408.882   Train_ACC: 51.839; Val_ACC: 57.000   Train_NMI: 0.104; Val_NMI: 1.406
# (Epoch 20 / 10000) Train_Loss: 410.371; Val_Loss: 407.095   Train_ACC: 51.664; Val_ACC: 56.000   Train_NMI: 0.089; Val_NMI: 1.049
# (Epoch 21 / 10000) Train_Loss: 407.978; Val_Loss: 407.924   Train_ACC: 52.189; Val_ACC: 55.000   Train_NMI: 0.137; Val_NMI: 0.774
# (Epoch 22 / 10000) Train_Loss: 405.637; Val_Loss: 402.468   Train_ACC: 51.313; Val_ACC: 57.000   Train_NMI: 0.069; Val_NMI: 1.398
# (Epoch 23 / 10000) Train_Loss: 403.089; Val_Loss: 402.316   Train_ACC: 51.226; Val_ACC: 58.000   Train_NMI: 0.031; Val_NMI: 1.836
# (Epoch 24 / 10000) Train_Loss: 400.661; Val_Loss: 398.746   Train_ACC: 50.613; Val_ACC: 56.000   Train_NMI: 0.003; Val_NMI: 1.048
# (Epoch 25 / 10000) Train_Loss: 399.947; Val_Loss: 400.621   Train_ACC: 50.701; Val_ACC: 54.000   Train_NMI: 0.020; Val_NMI: 0.451
# (Epoch 26 / 10000) Train_Loss: 397.093; Val_Loss: 395.855   Train_ACC: 50.438; Val_ACC: 55.000   Train_NMI: 0.007; Val_NMI: 0.704
# (Epoch 27 / 10000) Train_Loss: 395.958; Val_Loss: 396.722   Train_ACC: 50.525; Val_ACC: 58.000   Train_NMI: 0.002; Val_NMI: 1.910
# (Epoch 28 / 10000) Train_Loss: 393.908; Val_Loss: 394.138   Train_ACC: 50.613; Val_ACC: 57.000   Train_NMI: 0.032; Val_NMI: 1.465
# (Epoch 29 / 10000) Train_Loss: 390.668; Val_Loss: 389.885   Train_ACC: 50.613; Val_ACC: 58.000   Train_NMI: 0.019; Val_NMI: 1.866
# (Epoch 30 / 10000) Train_Loss: 387.334; Val_Loss: 388.757   Train_ACC: 50.525; Val_ACC: 57.000   Train_NMI: 0.000; Val_NMI: 1.465
# (Epoch 31 / 10000) Train_Loss: 385.758; Val_Loss: 386.585   Train_ACC: 51.138; Val_ACC: 59.000   Train_NMI: 0.011; Val_NMI: 2.416
# (Epoch 32 / 10000) Train_Loss: 384.058; Val_Loss: 383.543   Train_ACC: 51.051; Val_ACC: 60.000   Train_NMI: 0.059; Val_NMI: 2.887
# (Epoch 33 / 10000) Train_Loss: 382.038; Val_Loss: 383.012   Train_ACC: 50.175; Val_ACC: 59.000   Train_NMI: 0.002; Val_NMI: 2.378
# (Epoch 34 / 10000) Train_Loss: 379.716; Val_Loss: 379.566   Train_ACC: 50.350; Val_ACC: 58.000   Train_NMI: 0.000; Val_NMI: 1.854
# (Epoch 35 / 10000) Train_Loss: 378.624; Val_Loss: 376.588   Train_ACC: 50.175; Val_ACC: 56.000   Train_NMI: 0.005; Val_NMI: 1.025
# (Epoch 36 / 10000) Train_Loss: 377.659; Val_Loss: 375.037   Train_ACC: 50.175; Val_ACC: 54.000   Train_NMI: 0.013; Val_NMI: 0.442
# (Epoch 37 / 10000) Train_Loss: 376.242; Val_Loss: 373.072   Train_ACC: 50.438; Val_ACC: 56.000   Train_NMI: 0.000; Val_NMI: 1.025
# (Epoch 38 / 10000) Train_Loss: 374.531; Val_Loss: 375.241   Train_ACC: 50.350; Val_ACC: 56.000   Train_NMI: 0.001; Val_NMI: 1.021
# (Epoch 39 / 10000) Train_Loss: 374.287; Val_Loss: 373.714   Train_ACC: 51.051; Val_ACC: 56.000   Train_NMI: 0.062; Val_NMI: 1.025
# (Epoch 40 / 10000) Train_Loss: 372.788; Val_Loss: 371.720   Train_ACC: 50.963; Val_ACC: 58.000   Train_NMI: 0.005; Val_NMI: 1.847
# (Epoch 41 / 10000) Train_Loss: 371.190; Val_Loss: 369.354   Train_ACC: 50.438; Val_ACC: 55.000   Train_NMI: 0.000; Val_NMI: 0.702
# (Epoch 42 / 10000) Train_Loss: 369.727; Val_Loss: 369.507   Train_ACC: 50.175; Val_ACC: 56.000   Train_NMI: 0.006; Val_NMI: 1.025
# (Epoch 43 / 10000) Train_Loss: 369.086; Val_Loss: 367.254   Train_ACC: 50.088; Val_ACC: 56.000   Train_NMI: 0.012; Val_NMI: 1.025
# (Epoch 44 / 10000) Train_Loss: 366.691; Val_Loss: 367.577   Train_ACC: 50.263; Val_ACC: 55.000   Train_NMI: 0.016; Val_NMI: 0.702
# (Epoch 45 / 10000) Train_Loss: 365.718; Val_Loss: 363.610   Train_ACC: 50.175; Val_ACC: 53.000   Train_NMI: 0.015; Val_NMI: 0.248
# (Epoch 46 / 10000) Train_Loss: 363.942; Val_Loss: 362.821   Train_ACC: 50.088; Val_ACC: 53.000   Train_NMI: 0.009; Val_NMI: 0.244
# (Epoch 47 / 10000) Train_Loss: 362.811; Val_Loss: 363.313   Train_ACC: 50.525; Val_ACC: 55.000   Train_NMI: 0.030; Val_NMI: 0.719
# (Epoch 48 / 10000) Train_Loss: 361.536; Val_Loss: 361.924   Train_ACC: 50.438; Val_ACC: 56.000   Train_NMI: 0.028; Val_NMI: 1.021
# (Epoch 49 / 10000) Train_Loss: 360.410; Val_Loss: 360.858   Train_ACC: 50.701; Val_ACC: 54.000   Train_NMI: 0.003; Val_NMI: 0.446
# (Epoch 50 / 10000) Train_Loss: 359.500; Val_Loss: 359.342   Train_ACC: 51.401; Val_ACC: 55.000   Train_NMI: 0.037; Val_NMI: 0.706
# (Epoch 51 / 10000) Train_Loss: 358.566; Val_Loss: 362.014   Train_ACC: 50.263; Val_ACC: 55.000   Train_NMI: 0.000; Val_NMI: 0.702
# (Epoch 52 / 10000) Train_Loss: 357.979; Val_Loss: 359.625   Train_ACC: 50.701; Val_ACC: 55.000   Train_NMI: 0.004; Val_NMI: 0.704
# (Epoch 53 / 10000) Train_Loss: 356.528; Val_Loss: 356.533   Train_ACC: 50.963; Val_ACC: 57.000   Train_NMI: 0.044; Val_NMI: 1.403
# (Epoch 54 / 10000) Train_Loss: 354.595; Val_Loss: 353.409   Train_ACC: 50.263; Val_ACC: 54.000   Train_NMI: 0.011; Val_NMI: 0.446
# (Epoch 55 / 10000) Train_Loss: 353.453; Val_Loss: 354.069   Train_ACC: 51.576; Val_ACC: 59.000   Train_NMI: 0.056; Val_NMI: 2.376
# (Epoch 56 / 10000) Train_Loss: 351.947; Val_Loss: 353.679   Train_ACC: 50.701; Val_ACC: 55.000   Train_NMI: 0.035; Val_NMI: 0.706
# (Epoch 57 / 10000) Train_Loss: 350.848; Val_Loss: 351.810   Train_ACC: 50.175; Val_ACC: 56.000   Train_NMI: 0.001; Val_NMI: 1.021
# (Epoch 58 / 10000) Train_Loss: 349.390; Val_Loss: 348.749   Train_ACC: 50.613; Val_ACC: 55.000   Train_NMI: 0.001; Val_NMI: 0.702
# (Epoch 59 / 10000) Train_Loss: 348.296; Val_Loss: 350.969   Train_ACC: 50.613; Val_ACC: 53.000   Train_NMI: 0.007; Val_NMI: 0.248
# (Epoch 60 / 10000) Train_Loss: 347.122; Val_Loss: 348.866   Train_ACC: 50.175; Val_ACC: 54.000   Train_NMI: 0.000; Val_NMI: 0.451
# (Epoch 61 / 10000) Train_Loss: 345.796; Val_Loss: 348.735   Train_ACC: 50.788; Val_ACC: 58.000   Train_NMI: 0.006; Val_NMI: 1.877
# (Epoch 62 / 10000) Train_Loss: 345.739; Val_Loss: 346.386   Train_ACC: 51.313; Val_ACC: 54.000   Train_NMI: 0.040; Val_NMI: 0.458
# (Epoch 63 / 10000) Train_Loss: 343.862; Val_Loss: 346.493   Train_ACC: 51.401; Val_ACC: 52.000   Train_NMI: 0.040; Val_NMI: 0.109
# (Epoch 64 / 10000) Train_Loss: 343.048; Val_Loss: 346.330   Train_ACC: 50.963; Val_ACC: 52.000   Train_NMI: 0.023; Val_NMI: 0.113
# (Epoch 65 / 10000) Train_Loss: 341.308; Val_Loss: 344.521   Train_ACC: 51.226; Val_ACC: 54.000   Train_NMI: 0.033; Val_NMI: 0.446
# (Epoch 66 / 10000) Train_Loss: 340.279; Val_Loss: 343.346   Train_ACC: 51.839; Val_ACC: 55.000   Train_NMI: 0.067; Val_NMI: 0.706
# (Epoch 67 / 10000) Train_Loss: 339.570; Val_Loss: 344.072   Train_ACC: 51.138; Val_ACC: 55.000   Train_NMI: 0.020; Val_NMI: 0.702
# (Epoch 68 / 10000) Train_Loss: 338.287; Val_Loss: 342.154   Train_ACC: 51.489; Val_ACC: 53.000   Train_NMI: 0.046; Val_NMI: 0.248
# (Epoch 69 / 10000) Train_Loss: 336.881; Val_Loss: 341.785   Train_ACC: 50.701; Val_ACC: 55.000   Train_NMI: 0.006; Val_NMI: 0.713
# (Epoch 70 / 10000) Train_Loss: 336.257; Val_Loss: 342.275   Train_ACC: 51.839; Val_ACC: 54.000   Train_NMI: 0.077; Val_NMI: 0.458
# (Epoch 71 / 10000) Train_Loss: 335.504; Val_Loss: 340.535   Train_ACC: 50.876; Val_ACC: 54.000   Train_NMI: 0.018; Val_NMI: 0.458
# (Epoch 72 / 10000) Train_Loss: 333.713; Val_Loss: 336.980   Train_ACC: 51.051; Val_ACC: 55.000   Train_NMI: 0.026; Val_NMI: 0.713
# (Epoch 73 / 10000) Train_Loss: 333.329; Val_Loss: 337.312   Train_ACC: 51.401; Val_ACC: 55.000   Train_NMI: 0.047; Val_NMI: 0.713
# (Epoch 74 / 10000) Train_Loss: 331.384; Val_Loss: 335.781   Train_ACC: 51.226; Val_ACC: 54.000   Train_NMI: 0.033; Val_NMI: 0.446
# (Epoch 75 / 10000) Train_Loss: 330.105; Val_Loss: 335.622   Train_ACC: 51.138; Val_ACC: 55.000   Train_NMI: 0.022; Val_NMI: 0.706
# (Epoch 76 / 10000) Train_Loss: 329.273; Val_Loss: 333.030   Train_ACC: 51.401; Val_ACC: 53.000   Train_NMI: 0.038; Val_NMI: 0.254
# (Epoch 77 / 10000) Train_Loss: 327.425; Val_Loss: 330.448   Train_ACC: 51.751; Val_ACC: 58.000   Train_NMI: 0.081; Val_NMI: 1.894
# (Epoch 78 / 10000) Train_Loss: 326.108; Val_Loss: 333.063   Train_ACC: 50.701; Val_ACC: 55.000   Train_NMI: 0.008; Val_NMI: 0.723
# (Epoch 79 / 10000) Train_Loss: 325.783; Val_Loss: 333.749   Train_ACC: 51.751; Val_ACC: 55.000   Train_NMI: 0.071; Val_NMI: 0.713
# (Epoch 80 / 10000) Train_Loss: 324.621; Val_Loss: 329.118   Train_ACC: 51.138; Val_ACC: 55.000   Train_NMI: 0.024; Val_NMI: 0.723
# (Epoch 81 / 10000) Train_Loss: 322.991; Val_Loss: 327.400   Train_ACC: 51.926; Val_ACC: 55.000   Train_NMI: 0.086; Val_NMI: 0.713
# (Epoch 82 / 10000) Train_Loss: 320.770; Val_Loss: 327.296   Train_ACC: 51.138; Val_ACC: 57.000   Train_NMI: 0.026; Val_NMI: 1.398
# (Epoch 83 / 10000) Train_Loss: 320.277; Val_Loss: 326.434   Train_ACC: 50.788; Val_ACC: 57.000   Train_NMI: 0.008; Val_NMI: 1.419
# (Epoch 84 / 10000) Train_Loss: 318.803; Val_Loss: 325.858   Train_ACC: 50.613; Val_ACC: 57.000   Train_NMI: 0.008; Val_NMI: 1.465
# (Epoch 85 / 10000) Train_Loss: 317.731; Val_Loss: 324.601   Train_ACC: 50.701; Val_ACC: 55.000   Train_NMI: 0.006; Val_NMI: 0.702
# (Epoch 86 / 10000) Train_Loss: 318.214; Val_Loss: 325.235   Train_ACC: 50.701; Val_ACC: 57.000   Train_NMI: 0.006; Val_NMI: 1.399
# (Epoch 87 / 10000) Train_Loss: 317.117; Val_Loss: 321.498   Train_ACC: 50.525; Val_ACC: 57.000   Train_NMI: 0.004; Val_NMI: 1.399
# (Epoch 88 / 10000) Train_Loss: 315.754; Val_Loss: 320.659   Train_ACC: 51.138; Val_ACC: 56.000   Train_NMI: 0.026; Val_NMI: 1.026
# (Epoch 89 / 10000) Train_Loss: 313.652; Val_Loss: 320.331   Train_ACC: 51.051; Val_ACC: 56.000   Train_NMI: 0.021; Val_NMI: 1.035
# (Epoch 90 / 10000) Train_Loss: 312.074; Val_Loss: 318.807   Train_ACC: 50.876; Val_ACC: 55.000   Train_NMI: 0.013; Val_NMI: 0.713
# (Epoch 91 / 10000) Train_Loss: 309.979; Val_Loss: 316.616   Train_ACC: 50.788; Val_ACC: 56.000   Train_NMI: 0.011; Val_NMI: 1.026
# (Epoch 92 / 10000) Train_Loss: 308.147; Val_Loss: 312.976   Train_ACC: 51.226; Val_ACC: 55.000   Train_NMI: 0.032; Val_NMI: 0.706
# (Epoch 93 / 10000) Train_Loss: 307.321; Val_Loss: 311.995   Train_ACC: 50.613; Val_ACC: 57.000   Train_NMI: 0.005; Val_NMI: 1.540
# (Epoch 94 / 10000) Train_Loss: 306.248; Val_Loss: 313.954   Train_ACC: 51.576; Val_ACC: 60.000   Train_NMI: 0.053; Val_NMI: 2.920
# (Epoch 95 / 10000) Train_Loss: 307.880; Val_Loss: 309.017   Train_ACC: 52.102; Val_ACC: 55.000   Train_NMI: 0.120; Val_NMI: 0.702
# (Epoch 96 / 10000) Train_Loss: 305.139; Val_Loss: 307.436   Train_ACC: 50.876; Val_ACC: 56.000   Train_NMI: 0.008; Val_NMI: 1.021
# (Epoch 97 / 10000) Train_Loss: 302.887; Val_Loss: 309.095   Train_ACC: 51.576; Val_ACC: 57.000   Train_NMI: 0.050; Val_NMI: 1.399
# (Epoch 98 / 10000) Train_Loss: 301.166; Val_Loss: 305.234   Train_ACC: 51.576; Val_ACC: 54.000   Train_NMI: 0.054; Val_NMI: 0.446
# (Epoch 99 / 10000) Train_Loss: 300.412; Val_Loss: 306.874   Train_ACC: 51.138; Val_ACC: 58.000   Train_NMI: 0.022; Val_NMI: 1.847
# (Epoch 100 / 10000) Train_Loss: 299.026; Val_Loss: 305.436   Train_ACC: 52.364; Val_ACC: 54.000   Train_NMI: 0.140; Val_NMI: 0.441
# (Epoch 101 / 10000) Train_Loss: 298.747; Val_Loss: 300.613   Train_ACC: 52.452; Val_ACC: 57.000   Train_NMI: 0.155; Val_NMI: 1.499
# (Epoch 102 / 10000) Train_Loss: 297.641; Val_Loss: 301.929   Train_ACC: 51.926; Val_ACC: 54.000   Train_NMI: 0.081; Val_NMI: 0.442
# (Epoch 103 / 10000) Train_Loss: 296.124; Val_Loss: 298.347   Train_ACC: 51.576; Val_ACC: 60.000   Train_NMI: 0.047; Val_NMI: 2.920
# (Epoch 104 / 10000) Train_Loss: 295.190; Val_Loss: 299.230   Train_ACC: 51.489; Val_ACC: 59.000   Train_NMI: 0.050; Val_NMI: 2.416
# (Epoch 105 / 10000) Train_Loss: 293.194; Val_Loss: 296.904   Train_ACC: 51.051; Val_ACC: 56.000   Train_NMI: 0.018; Val_NMI: 1.026
# (Epoch 106 / 10000) Train_Loss: 290.987; Val_Loss: 294.092   Train_ACC: 51.401; Val_ACC: 57.000   Train_NMI: 0.042; Val_NMI: 1.399
# (Epoch 107 / 10000) Train_Loss: 291.093; Val_Loss: 295.341   Train_ACC: 51.401; Val_ACC: 55.000   Train_NMI: 0.036; Val_NMI: 0.702
# (Epoch 108 / 10000) Train_Loss: 290.832; Val_Loss: 294.216   Train_ACC: 50.788; Val_ACC: 57.000   Train_NMI: 0.012; Val_NMI: 1.406
# (Epoch 109 / 10000) Train_Loss: 287.656; Val_Loss: 289.290   Train_ACC: 51.138; Val_ACC: 56.000   Train_NMI: 0.023; Val_NMI: 1.021
# (Epoch 110 / 10000) Train_Loss: 287.559; Val_Loss: 293.667   Train_ACC: 51.751; Val_ACC: 56.000   Train_NMI: 0.062; Val_NMI: 1.026
# (Epoch 111 / 10000) Train_Loss: 286.971; Val_Loss: 288.198   Train_ACC: 51.051; Val_ACC: 56.000   Train_NMI: 0.020; Val_NMI: 1.026
# (Epoch 112 / 10000) Train_Loss: 284.602; Val_Loss: 287.168   Train_ACC: 51.226; Val_ACC: 56.000   Train_NMI: 0.030; Val_NMI: 1.021
# (Epoch 113 / 10000) Train_Loss: 283.281; Val_Loss: 288.896   Train_ACC: 51.839; Val_ACC: 54.000   Train_NMI: 0.075; Val_NMI: 0.451
# (Epoch 114 / 10000) Train_Loss: 282.403; Val_Loss: 285.087   Train_ACC: 50.876; Val_ACC: 55.000   Train_NMI: 0.012; Val_NMI: 0.702
# (Epoch 115 / 10000) Train_Loss: 281.379; Val_Loss: 287.395   Train_ACC: 51.489; Val_ACC: 56.000   Train_NMI: 0.041; Val_NMI: 1.026
# (Epoch 116 / 10000) Train_Loss: 280.803; Val_Loss: 282.568   Train_ACC: 50.788; Val_ACC: 58.000   Train_NMI: 0.010; Val_NMI: 1.847
# (Epoch 117 / 10000) Train_Loss: 279.555; Val_Loss: 278.758   Train_ACC: 50.876; Val_ACC: 60.000   Train_NMI: 0.017; Val_NMI: 2.920
# (Epoch 118 / 10000) Train_Loss: 278.172; Val_Loss: 281.714   Train_ACC: 50.963; Val_ACC: 57.000   Train_NMI: 0.021; Val_NMI: 1.406
# (Epoch 119 / 10000) Train_Loss: 276.602; Val_Loss: 281.284   Train_ACC: 50.963; Val_ACC: 57.000   Train_NMI: 0.016; Val_NMI: 1.419
# (Epoch 120 / 10000) Train_Loss: 276.652; Val_Loss: 276.373   Train_ACC: 51.138; Val_ACC: 58.000   Train_NMI: 0.027; Val_NMI: 1.847
# (Epoch 121 / 10000) Train_Loss: 274.496; Val_Loss: 277.395   Train_ACC: 51.051; Val_ACC: 58.000   Train_NMI: 0.021; Val_NMI: 1.847
# (Epoch 122 / 10000) Train_Loss: 272.504; Val_Loss: 272.833   Train_ACC: 51.401; Val_ACC: 58.000   Train_NMI: 0.042; Val_NMI: 1.847
# (Epoch 123 / 10000) Train_Loss: 271.850; Val_Loss: 270.515   Train_ACC: 51.576; Val_ACC: 58.000   Train_NMI: 0.057; Val_NMI: 1.847
# (Epoch 124 / 10000) Train_Loss: 269.569; Val_Loss: 273.343   Train_ACC: 51.839; Val_ACC: 57.000   Train_NMI: 0.079; Val_NMI: 1.406
# (Epoch 125 / 10000) Train_Loss: 268.769; Val_Loss: 270.932   Train_ACC: 52.014; Val_ACC: 54.000   Train_NMI: 0.094; Val_NMI: 0.446
# (Epoch 126 / 10000) Train_Loss: 267.356; Val_Loss: 271.463   Train_ACC: 51.839; Val_ACC: 55.000   Train_NMI: 0.072; Val_NMI: 0.702
# (Epoch 127 / 10000) Train_Loss: 266.344; Val_Loss: 266.033   Train_ACC: 51.138; Val_ACC: 56.000   Train_NMI: 0.024; Val_NMI: 1.049
# (Epoch 128 / 10000) Train_Loss: 264.543; Val_Loss: 265.353   Train_ACC: 51.489; Val_ACC: 57.000   Train_NMI: 0.045; Val_NMI: 1.419
# (Epoch 129 / 10000) Train_Loss: 264.305; Val_Loss: 263.007   Train_ACC: 51.401; Val_ACC: 58.000   Train_NMI: 0.047; Val_NMI: 1.866
# (Epoch 130 / 10000) Train_Loss: 263.298; Val_Loss: 261.225   Train_ACC: 50.613; Val_ACC: 59.000   Train_NMI: 0.006; Val_NMI: 2.351
# (Epoch 131 / 10000) Train_Loss: 262.815; Val_Loss: 261.169   Train_ACC: 51.489; Val_ACC: 58.000   Train_NMI: 0.046; Val_NMI: 1.847
# (Epoch 132 / 10000) Train_Loss: 260.138; Val_Loss: 259.483   Train_ACC: 50.876; Val_ACC: 57.000   Train_NMI: 0.014; Val_NMI: 1.419
# (Epoch 133 / 10000) Train_Loss: 258.453; Val_Loss: 260.585   Train_ACC: 50.350; Val_ACC: 57.000   Train_NMI: 0.000; Val_NMI: 1.419
# (Epoch 134 / 10000) Train_Loss: 258.229; Val_Loss: 255.777   Train_ACC: 50.613; Val_ACC: 56.000   Train_NMI: 0.005; Val_NMI: 1.035
# (Epoch 135 / 10000) Train_Loss: 256.984; Val_Loss: 259.020   Train_ACC: 51.313; Val_ACC: 54.000   Train_NMI: 0.030; Val_NMI: 0.451
# (Epoch 136 / 10000) Train_Loss: 256.144; Val_Loss: 257.450   Train_ACC: 50.263; Val_ACC: 57.000   Train_NMI: 0.000; Val_NMI: 1.419
# (Epoch 137 / 10000) Train_Loss: 254.615; Val_Loss: 254.370   Train_ACC: 50.876; Val_ACC: 53.000   Train_NMI: 0.012; Val_NMI: 0.248
# (Epoch 138 / 10000) Train_Loss: 253.930; Val_Loss: 252.180   Train_ACC: 50.963; Val_ACC: 54.000   Train_NMI: 0.013; Val_NMI: 0.446
# (Epoch 139 / 10000) Train_Loss: 251.779; Val_Loss: 253.317   Train_ACC: 50.701; Val_ACC: 60.000   Train_NMI: 0.006; Val_NMI: 3.009
# (Epoch 140 / 10000) Train_Loss: 250.482; Val_Loss: 251.589   Train_ACC: 50.701; Val_ACC: 57.000   Train_NMI: 0.012; Val_NMI: 1.419
# (Epoch 141 / 10000) Train_Loss: 250.907; Val_Loss: 250.420   Train_ACC: 50.876; Val_ACC: 56.000   Train_NMI: 0.009; Val_NMI: 1.021
# (Epoch 142 / 10000) Train_Loss: 247.904; Val_Loss: 246.492   Train_ACC: 50.876; Val_ACC: 57.000   Train_NMI: 0.011; Val_NMI: 1.419
# (Epoch 143 / 10000) Train_Loss: 246.909; Val_Loss: 245.822   Train_ACC: 50.876; Val_ACC: 55.000   Train_NMI: 0.013; Val_NMI: 0.706
# (Epoch 144 / 10000) Train_Loss: 248.272; Val_Loss: 251.528   Train_ACC: 51.226; Val_ACC: 58.000   Train_NMI: 0.027; Val_NMI: 1.847
# (Epoch 145 / 10000) Train_Loss: 246.936; Val_Loss: 247.481   Train_ACC: 50.613; Val_ACC: 58.000   Train_NMI: 0.004; Val_NMI: 1.847
# (Epoch 146 / 10000) Train_Loss: 244.504; Val_Loss: 244.548   Train_ACC: 50.350; Val_ACC: 55.000   Train_NMI: 0.001; Val_NMI: 0.713
# (Epoch 147 / 10000) Train_Loss: 242.079; Val_Loss: 245.011   Train_ACC: 51.051; Val_ACC: 55.000   Train_NMI: 0.021; Val_NMI: 0.713
# (Epoch 148 / 10000) Train_Loss: 241.149; Val_Loss: 240.455   Train_ACC: 51.138; Val_ACC: 60.000   Train_NMI: 0.024; Val_NMI: 2.920
# (Epoch 149 / 10000) Train_Loss: 239.769; Val_Loss: 241.535   Train_ACC: 50.613; Val_ACC: 58.000   Train_NMI: 0.006; Val_NMI: 1.894
# (Epoch 150 / 10000) Train_Loss: 238.161; Val_Loss: 237.484   Train_ACC: 50.876; Val_ACC: 56.000   Train_NMI: 0.014; Val_NMI: 1.026
# (Epoch 151 / 10000) Train_Loss: 237.082; Val_Loss: 237.688   Train_ACC: 50.963; Val_ACC: 58.000   Train_NMI: 0.014; Val_NMI: 1.847
# (Epoch 152 / 10000) Train_Loss: 235.760; Val_Loss: 236.554   Train_ACC: 51.051; Val_ACC: 58.000   Train_NMI: 0.021; Val_NMI: 1.847
# (Epoch 153 / 10000) Train_Loss: 236.520; Val_Loss: 232.750   Train_ACC: 50.876; Val_ACC: 55.000   Train_NMI: 0.012; Val_NMI: 0.713
# (Epoch 154 / 10000) Train_Loss: 237.485; Val_Loss: 240.929   Train_ACC: 50.701; Val_ACC: 58.000   Train_NMI: 0.008; Val_NMI: 1.894
# (Epoch 155 / 10000) Train_Loss: 236.436; Val_Loss: 234.285   Train_ACC: 50.438; Val_ACC: 57.000   Train_NMI: 0.003; Val_NMI: 1.419
# (Epoch 156 / 10000) Train_Loss: 233.344; Val_Loss: 231.994   Train_ACC: 50.701; Val_ACC: 57.000   Train_NMI: 0.009; Val_NMI: 1.419
# (Epoch 157 / 10000) Train_Loss: 232.095; Val_Loss: 229.865   Train_ACC: 51.226; Val_ACC: 56.000   Train_NMI: 0.026; Val_NMI: 1.026
# (Epoch 158 / 10000) Train_Loss: 231.009; Val_Loss: 231.453   Train_ACC: 50.525; Val_ACC: 57.000   Train_NMI: 0.003; Val_NMI: 1.439
# (Epoch 159 / 10000) Train_Loss: 228.771; Val_Loss: 227.704   Train_ACC: 50.350; Val_ACC: 57.000   Train_NMI: 0.002; Val_NMI: 1.439
# (Epoch 160 / 10000) Train_Loss: 228.157; Val_Loss: 227.018   Train_ACC: 51.138; Val_ACC: 57.000   Train_NMI: 0.030; Val_NMI: 1.439
# (Epoch 161 / 10000) Train_Loss: 228.224; Val_Loss: 225.871   Train_ACC: 50.438; Val_ACC: 55.000   Train_NMI: 0.002; Val_NMI: 0.706
# (Epoch 162 / 10000) Train_Loss: 227.882; Val_Loss: 228.237   Train_ACC: 50.525; Val_ACC: 56.000   Train_NMI: 0.001; Val_NMI: 1.035
# (Epoch 163 / 10000) Train_Loss: 227.847; Val_Loss: 225.266   Train_ACC: 50.963; Val_ACC: 57.000   Train_NMI: 0.015; Val_NMI: 1.406
# (Epoch 164 / 10000) Train_Loss: 225.845; Val_Loss: 223.286   Train_ACC: 51.051; Val_ACC: 58.000   Train_NMI: 0.019; Val_NMI: 1.894
# (Epoch 165 / 10000) Train_Loss: 223.426; Val_Loss: 224.347   Train_ACC: 50.963; Val_ACC: 58.000   Train_NMI: 0.020; Val_NMI: 1.866
# (Epoch 166 / 10000) Train_Loss: 222.711; Val_Loss: 222.516   Train_ACC: 51.051; Val_ACC: 56.000   Train_NMI: 0.018; Val_NMI: 1.021
# (Epoch 167 / 10000) Train_Loss: 222.622; Val_Loss: 217.615   Train_ACC: 51.051; Val_ACC: 57.000   Train_NMI: 0.018; Val_NMI: 1.406
# (Epoch 168 / 10000) Train_Loss: 221.435; Val_Loss: 216.345   Train_ACC: 50.613; Val_ACC: 57.000   Train_NMI: 0.005; Val_NMI: 1.439
# (Epoch 169 / 10000) Train_Loss: 219.253; Val_Loss: 218.186   Train_ACC: 50.701; Val_ACC: 55.000   Train_NMI: 0.008; Val_NMI: 0.713
# (Epoch 170 / 10000) Train_Loss: 217.596; Val_Loss: 217.935   Train_ACC: 51.051; Val_ACC: 58.000   Train_NMI: 0.019; Val_NMI: 1.847
# (Epoch 171 / 10000) Train_Loss: 215.443; Val_Loss: 215.651   Train_ACC: 50.963; Val_ACC: 58.000   Train_NMI: 0.016; Val_NMI: 1.847
# (Epoch 172 / 10000) Train_Loss: 216.706; Val_Loss: 214.325   Train_ACC: 50.438; Val_ACC: 57.000   Train_NMI: 0.002; Val_NMI: 1.465
# (Epoch 173 / 10000) Train_Loss: 216.243; Val_Loss: 215.694   Train_ACC: 51.051; Val_ACC: 57.000   Train_NMI: 0.022; Val_NMI: 1.399
# (Epoch 174 / 10000) Train_Loss: 214.418; Val_Loss: 210.580   Train_ACC: 51.138; Val_ACC: 58.000   Train_NMI: 0.021; Val_NMI: 1.836
# (Epoch 175 / 10000) Train_Loss: 214.134; Val_Loss: 211.466   Train_ACC: 51.226; Val_ACC: 59.000   Train_NMI: 0.029; Val_NMI: 2.378
# (Epoch 176 / 10000) Train_Loss: 214.590; Val_Loss: 212.598   Train_ACC: 51.401; Val_ACC: 56.000   Train_NMI: 0.038; Val_NMI: 1.026
# (Epoch 177 / 10000) Train_Loss: 212.992; Val_Loss: 209.339   Train_ACC: 50.963; Val_ACC: 57.000   Train_NMI: 0.022; Val_NMI: 1.465
# (Epoch 178 / 10000) Train_Loss: 211.994; Val_Loss: 211.305   Train_ACC: 51.226; Val_ACC: 57.000   Train_NMI: 0.034; Val_NMI: 1.439
# (Epoch 179 / 10000) Train_Loss: 211.034; Val_Loss: 209.480   Train_ACC: 50.788; Val_ACC: 57.000   Train_NMI: 0.012; Val_NMI: 1.465
# (Epoch 180 / 10000) Train_Loss: 210.462; Val_Loss: 209.965   Train_ACC: 50.613; Val_ACC: 56.000   Train_NMI: 0.006; Val_NMI: 1.049
# (Epoch 181 / 10000) Train_Loss: 208.275; Val_Loss: 201.954   Train_ACC: 51.576; Val_ACC: 56.000   Train_NMI: 0.056; Val_NMI: 1.049
# (Epoch 182 / 10000) Train_Loss: 207.301; Val_Loss: 203.127   Train_ACC: 51.226; Val_ACC: 56.000   Train_NMI: 0.030; Val_NMI: 1.035
# (Epoch 183 / 10000) Train_Loss: 206.696; Val_Loss: 208.240   Train_ACC: 51.313; Val_ACC: 55.000   Train_NMI: 0.033; Val_NMI: 0.723
# (Epoch 184 / 10000) Train_Loss: 209.656; Val_Loss: 208.129   Train_ACC: 51.664; Val_ACC: 56.000   Train_NMI: 0.063; Val_NMI: 1.068
# (Epoch 185 / 10000) Train_Loss: 208.445; Val_Loss: 205.061   Train_ACC: 50.701; Val_ACC: 56.000   Train_NMI: 0.011; Val_NMI: 1.068
# (Epoch 186 / 10000) Train_Loss: 207.116; Val_Loss: 205.679   Train_ACC: 50.350; Val_ACC: 57.000   Train_NMI: 0.002; Val_NMI: 1.465
# (Epoch 187 / 10000) Train_Loss: 204.121; Val_Loss: 198.629   Train_ACC: 51.138; Val_ACC: 55.000   Train_NMI: 0.028; Val_NMI: 0.723
# (Epoch 188 / 10000) Train_Loss: 200.616; Val_Loss: 198.951   Train_ACC: 51.313; Val_ACC: 55.000   Train_NMI: 0.034; Val_NMI: 0.723
# (Epoch 189 / 10000) Train_Loss: 200.447; Val_Loss: 199.707   Train_ACC: 51.226; Val_ACC: 56.000   Train_NMI: 0.033; Val_NMI: 1.068
# (Epoch 190 / 10000) Train_Loss: 200.410; Val_Loss: 196.532   Train_ACC: 51.138; Val_ACC: 58.000   Train_NMI: 0.028; Val_NMI: 1.866
# (Epoch 191 / 10000) Train_Loss: 199.576; Val_Loss: 196.598   Train_ACC: 51.401; Val_ACC: 58.000   Train_NMI: 0.043; Val_NMI: 1.866
# (Epoch 192 / 10000) Train_Loss: 199.817; Val_Loss: 196.757   Train_ACC: 51.051; Val_ACC: 56.000   Train_NMI: 0.023; Val_NMI: 1.068
# (Epoch 193 / 10000) Train_Loss: 199.625; Val_Loss: 196.051   Train_ACC: 51.313; Val_ACC: 56.000   Train_NMI: 0.040; Val_NMI: 1.068
# (Epoch 194 / 10000) Train_Loss: 197.682; Val_Loss: 194.547   Train_ACC: 51.489; Val_ACC: 54.000   Train_NMI: 0.053; Val_NMI: 0.479
# (Epoch 195 / 10000) Train_Loss: 197.255; Val_Loss: 195.973   Train_ACC: 51.051; Val_ACC: 55.000   Train_NMI: 0.021; Val_NMI: 0.713
# (Epoch 196 / 10000) Train_Loss: 195.861; Val_Loss: 190.593   Train_ACC: 50.963; Val_ACC: 57.000   Train_NMI: 0.015; Val_NMI: 1.419
# (Epoch 197 / 10000) Train_Loss: 194.402; Val_Loss: 191.941   Train_ACC: 50.876; Val_ACC: 58.000   Train_NMI: 0.013; Val_NMI: 1.894
# (Epoch 198 / 10000) Train_Loss: 195.075; Val_Loss: 192.079   Train_ACC: 50.701; Val_ACC: 57.000   Train_NMI: 0.011; Val_NMI: 1.465
# (Epoch 199 / 10000) Train_Loss: 193.987; Val_Loss: 192.081   Train_ACC: 50.701; Val_ACC: 57.000   Train_NMI: 0.011; Val_NMI: 1.465
# (Epoch 200 / 10000) Train_Loss: 193.565; Val_Loss: 189.459   Train_ACC: 51.051; Val_ACC: 56.000   Train_NMI: 0.024; Val_NMI: 1.035
# (Epoch 201 / 10000) Train_Loss: 191.053; Val_Loss: 187.799   Train_ACC: 51.313; Val_ACC: 56.000   Train_NMI: 0.035; Val_NMI: 1.049
# (Epoch 202 / 10000) Train_Loss: 190.774; Val_Loss: 188.872   Train_ACC: 50.963; Val_ACC: 55.000   Train_NMI: 0.016; Val_NMI: 0.713
# (Epoch 203 / 10000) Train_Loss: 191.812; Val_Loss: 188.194   Train_ACC: 51.751; Val_ACC: 55.000   Train_NMI: 0.065; Val_NMI: 0.713
# (Epoch 204 / 10000) Train_Loss: 192.080; Val_Loss: 187.120   Train_ACC: 50.438; Val_ACC: 57.000   Train_NMI: 0.003; Val_NMI: 1.465
# (Epoch 205 / 10000) Train_Loss: 190.916; Val_Loss: 187.047   Train_ACC: 50.525; Val_ACC: 56.000   Train_NMI: 0.004; Val_NMI: 1.026
# (Epoch 206 / 10000) Train_Loss: 190.574; Val_Loss: 188.294   Train_ACC: 51.926; Val_ACC: 57.000   Train_NMI: 0.086; Val_NMI: 1.419
# (Epoch 207 / 10000) Train_Loss: 188.166; Val_Loss: 182.005   Train_ACC: 51.401; Val_ACC: 56.000   Train_NMI: 0.041; Val_NMI: 1.035
# (Epoch 208 / 10000) Train_Loss: 186.967; Val_Loss: 183.989   Train_ACC: 51.489; Val_ACC: 56.000   Train_NMI: 0.046; Val_NMI: 1.035
# (Epoch 209 / 10000) Train_Loss: 187.401; Val_Loss: 181.441   Train_ACC: 50.788; Val_ACC: 58.000   Train_NMI: 0.012; Val_NMI: 1.930
# (Epoch 210 / 10000) Train_Loss: 184.594; Val_Loss: 180.978   Train_ACC: 50.438; Val_ACC: 56.000   Train_NMI: 0.005; Val_NMI: 1.092
# (Epoch 212 / 10000) Train_Loss: 182.303; Val_Loss: 176.961   Train_ACC: 51.489; Val_ACC: 55.000   Train_NMI: 0.047; Val_NMI: 0.706
# (Epoch 213 / 10000) Train_Loss: 180.692; Val_Loss: 178.860   Train_ACC: 50.525; Val_ACC: 56.000   Train_NMI: 0.006; Val_NMI: 1.092
# (Epoch 214 / 10000) Train_Loss: 179.205; Val_Loss: 173.295   Train_ACC: 50.438; Val_ACC: 58.000   Train_NMI: 0.003; Val_NMI: 1.866
# (Epoch 215 / 10000) Train_Loss: 179.162; Val_Loss: 179.967   Train_ACC: 50.613; Val_ACC: 56.000   Train_NMI: 0.005; Val_NMI: 1.035
# (Epoch 216 / 10000) Train_Loss: 184.107; Val_Loss: 179.003   Train_ACC: 51.051; Val_ACC: 57.000   Train_NMI: 0.020; Val_NMI: 1.419
# (Epoch 217 / 10000) Train_Loss: 181.663; Val_Loss: 179.254   Train_ACC: 50.525; Val_ACC: 58.000   Train_NMI: 0.005; Val_NMI: 1.930
# (Epoch 218 / 10000) Train_Loss: 180.409; Val_Loss: 179.899   Train_ACC: 50.263; Val_ACC: 58.000   Train_NMI: 0.002; Val_NMI: 1.930
# (Epoch 219 / 10000) Train_Loss: 180.093; Val_Loss: 176.786   Train_ACC: 50.613; Val_ACC: 55.000   Train_NMI: 0.004; Val_NMI: 0.706
# (Epoch 220 / 10000) Train_Loss: 178.362; Val_Loss: 173.894   Train_ACC: 50.701; Val_ACC: 56.000   Train_NMI: 0.004; Val_NMI: 1.035
# (Epoch 221 / 10000) Train_Loss: 176.030; Val_Loss: 171.879   Train_ACC: 50.963; Val_ACC: 57.000   Train_NMI: 0.016; Val_NMI: 1.419
# (Epoch 222 / 10000) Train_Loss: 174.336; Val_Loss: 170.779   Train_ACC: 50.525; Val_ACC: 57.000   Train_NMI: 0.004; Val_NMI: 1.439
# (Epoch 223 / 10000) Train_Loss: 173.470; Val_Loss: 172.347   Train_ACC: 50.613; Val_ACC: 56.000   Train_NMI: 0.005; Val_NMI: 1.035
# (Epoch 224 / 10000) Train_Loss: 173.876; Val_Loss: 170.957   Train_ACC: 51.051; Val_ACC: 57.000   Train_NMI: 0.021; Val_NMI: 1.465
# (Epoch 225 / 10000) Train_Loss: 171.896; Val_Loss: 165.418   Train_ACC: 50.263; Val_ACC: 57.000   Train_NMI: 0.002; Val_NMI: 1.465
# (Epoch 226 / 10000) Train_Loss: 172.612; Val_Loss: 170.479   Train_ACC: 50.613; Val_ACC: 57.000   Train_NMI: 0.009; Val_NMI: 1.465
# (Epoch 227 / 10000) Train_Loss: 172.559; Val_Loss: 165.809   Train_ACC: 50.525; Val_ACC: 56.000   Train_NMI: 0.007; Val_NMI: 1.092
# (Epoch 228 / 10000) Train_Loss: 171.009; Val_Loss: 169.564   Train_ACC: 50.613; Val_ACC: 58.000   Train_NMI: 0.008; Val_NMI: 1.894
# (Epoch 229 / 10000) Train_Loss: 170.879; Val_Loss: 167.535   Train_ACC: 50.438; Val_ACC: 58.000   Train_NMI: 0.004; Val_NMI: 1.894
# (Epoch 230 / 10000) Train_Loss: 170.284; Val_Loss: 164.418   Train_ACC: 50.613; Val_ACC: 58.000   Train_NMI: 0.007; Val_NMI: 1.894
# (Epoch 231 / 10000) Train_Loss: 171.526; Val_Loss: 168.493   Train_ACC: 50.350; Val_ACC: 57.000   Train_NMI: 0.002; Val_NMI: 1.439
# (Epoch 232 / 10000) Train_Loss: 170.083; Val_Loss: 169.005   Train_ACC: 51.401; Val_ACC: 56.000   Train_NMI: 0.045; Val_NMI: 1.049
# (Epoch 233 / 10000) Train_Loss: 167.994; Val_Loss: 167.174   Train_ACC: 50.788; Val_ACC: 58.000   Train_NMI: 0.011; Val_NMI: 1.894
# (Epoch 234 / 10000) Train_Loss: 167.728; Val_Loss: 162.410   Train_ACC: 50.000; Val_ACC: 59.000   Train_NMI: 0.000; Val_NMI: 2.416
# (Epoch 235 / 10000) Train_Loss: 168.564; Val_Loss: 163.621   Train_ACC: 50.263; Val_ACC: 58.000   Train_NMI: 0.001; Val_NMI: 1.894
# (Epoch 236 / 10000) Train_Loss: 171.176; Val_Loss: 170.175   Train_ACC: 50.876; Val_ACC: 58.000   Train_NMI: 0.017; Val_NMI: 1.894
# (Epoch 237 / 10000) Train_Loss: 169.998; Val_Loss: 166.122   Train_ACC: 50.788; Val_ACC: 56.000   Train_NMI: 0.013; Val_NMI: 1.049
# (Epoch 238 / 10000) Train_Loss: 169.671; Val_Loss: 163.007   Train_ACC: 50.876; Val_ACC: 58.000   Train_NMI: 0.015; Val_NMI: 1.866
# (Epoch 239 / 10000) Train_Loss: 166.230; Val_Loss: 161.231   Train_ACC: 51.138; Val_ACC: 57.000   Train_NMI: 0.028; Val_NMI: 1.439
# (Epoch 240 / 10000) Train_Loss: 165.105; Val_Loss: 161.594   Train_ACC: 50.701; Val_ACC: 55.000   Train_NMI: 0.010; Val_NMI: 0.736
# (Epoch 241 / 10000) Train_Loss: 164.451; Val_Loss: 158.775   Train_ACC: 50.963; Val_ACC: 57.000   Train_NMI: 0.018; Val_NMI: 1.439
# (Epoch 242 / 10000) Train_Loss: 162.799; Val_Loss: 157.457   Train_ACC: 51.138; Val_ACC: 58.000   Train_NMI: 0.027; Val_NMI: 1.894
# (Epoch 243 / 10000) Train_Loss: 161.626; Val_Loss: 161.035   Train_ACC: 50.788; Val_ACC: 58.000   Train_NMI: 0.013; Val_NMI: 1.894
# (Epoch 244 / 10000) Train_Loss: 162.372; Val_Loss: 157.017   Train_ACC: 50.525; Val_ACC: 59.000   Train_NMI: 0.006; Val_NMI: 2.416
# (Epoch 245 / 10000) Train_Loss: 160.978; Val_Loss: 156.853   Train_ACC: 50.613; Val_ACC: 57.000   Train_NMI: 0.008; Val_NMI: 1.439
# (Epoch 246 / 10000) Train_Loss: 161.175; Val_Loss: 155.716   Train_ACC: 51.226; Val_ACC: 57.000   Train_NMI: 0.032; Val_NMI: 1.439
# (Epoch 247 / 10000) Train_Loss: 159.461; Val_Loss: 151.322   Train_ACC: 51.138; Val_ACC: 57.000   Train_NMI: 0.025; Val_NMI: 1.439
# (Epoch 248 / 10000) Train_Loss: 157.382; Val_Loss: 152.540   Train_ACC: 50.701; Val_ACC: 58.000   Train_NMI: 0.010; Val_NMI: 1.894
# (Epoch 249 / 10000) Train_Loss: 158.813; Val_Loss: 156.507   Train_ACC: 50.788; Val_ACC: 56.000   Train_NMI: 0.013; Val_NMI: 1.049
# (Epoch 250 / 10000) Train_Loss: 159.296; Val_Loss: 154.289   Train_ACC: 50.175; Val_ACC: 59.000   Train_NMI: 0.000; Val_NMI: 2.416
# (Epoch 251 / 10000) Train_Loss: 156.780; Val_Loss: 153.148   Train_ACC: 50.088; Val_ACC: 58.000   Train_NMI: 0.000; Val_NMI: 1.894
# (Epoch 252 / 10000) Train_Loss: 155.761; Val_Loss: 154.130   Train_ACC: 50.701; Val_ACC: 59.000   Train_NMI: 0.010; Val_NMI: 2.416
# (Epoch 253 / 10000) Train_Loss: 155.965; Val_Loss: 150.236   Train_ACC: 50.088; Val_ACC: 59.000   Train_NMI: 0.000; Val_NMI: 2.416
# (Epoch 254 / 10000) Train_Loss: 154.583; Val_Loss: 149.750   Train_ACC: 50.263; Val_ACC: 57.000   Train_NMI: 0.003; Val_NMI: 1.439
# (Epoch 255 / 10000) Train_Loss: 154.798; Val_Loss: 150.337   Train_ACC: 50.350; Val_ACC: 59.000   Train_NMI: 0.002; Val_NMI: 2.416
# (Epoch 256 / 10000) Train_Loss: 155.884; Val_Loss: 152.051   Train_ACC: 50.350; Val_ACC: 57.000   Train_NMI: 0.005; Val_NMI: 1.439
# (Epoch 257 / 10000) Train_Loss: 155.046; Val_Loss: 150.362   Train_ACC: 50.088; Val_ACC: 57.000   Train_NMI: 0.000; Val_NMI: 1.419
# (Epoch 258 / 10000) Train_Loss: 154.221; Val_Loss: 150.324   Train_ACC: 51.226; Val_ACC: 54.000   Train_NMI: 0.031; Val_NMI: 0.451
# (Epoch 259 / 10000) Train_Loss: 154.521; Val_Loss: 150.369   Train_ACC: 50.876; Val_ACC: 56.000   Train_NMI: 0.012; Val_NMI: 1.068
# (Epoch 260 / 10000) Train_Loss: 154.413; Val_Loss: 153.200   Train_ACC: 50.613; Val_ACC: 55.000   Train_NMI: 0.010; Val_NMI: 0.723
# (Epoch 261 / 10000) Train_Loss: 152.873; Val_Loss: 149.939   Train_ACC: 51.751; Val_ACC: 56.000   Train_NMI: 0.065; Val_NMI: 1.021
# (Epoch 262 / 10000) Train_Loss: 152.601; Val_Loss: 150.698   Train_ACC: 51.576; Val_ACC: 57.000   Train_NMI: 0.047; Val_NMI: 1.399
# (Epoch 263 / 10000) Train_Loss: 152.516; Val_Loss: 146.863   Train_ACC: 50.876; Val_ACC: 56.000   Train_NMI: 0.013; Val_NMI: 1.049
# (Epoch 264 / 10000) Train_Loss: 151.483; Val_Loss: 152.617   Train_ACC: 50.525; Val_ACC: 54.000   Train_NMI: 0.004; Val_NMI: 0.458
# (Epoch 265 / 10000) Train_Loss: 151.020; Val_Loss: 145.575   Train_ACC: 51.576; Val_ACC: 56.000   Train_NMI: 0.053; Val_NMI: 1.026
# (Epoch 266 / 10000) Train_Loss: 151.336; Val_Loss: 148.284   Train_ACC: 51.226; Val_ACC: 56.000   Train_NMI: 0.026; Val_NMI: 1.049
# (Epoch 267 / 10000) Train_Loss: 147.595; Val_Loss: 142.817   Train_ACC: 50.613; Val_ACC: 56.000   Train_NMI: 0.006; Val_NMI: 1.049
# (Epoch 268 / 10000) Train_Loss: 147.626; Val_Loss: 141.522   Train_ACC: 50.175; Val_ACC: 58.000   Train_NMI: 0.000; Val_NMI: 1.894
# (Epoch 269 / 10000) Train_Loss: 146.828; Val_Loss: 145.517   Train_ACC: 50.701; Val_ACC: 54.000   Train_NMI: 0.011; Val_NMI: 0.458
# (Epoch 270 / 10000) Train_Loss: 145.106; Val_Loss: 143.839   Train_ACC: 51.051; Val_ACC: 55.000   Train_NMI: 0.021; Val_NMI: 0.723
# (Epoch 271 / 10000) Train_Loss: 145.052; Val_Loss: 144.374   Train_ACC: 50.963; Val_ACC: 56.000   Train_NMI: 0.020; Val_NMI: 1.049
# (Epoch 272 / 10000) Train_Loss: 145.355; Val_Loss: 140.230   Train_ACC: 51.401; Val_ACC: 56.000   Train_NMI: 0.047; Val_NMI: 1.049
# (Epoch 273 / 10000) Train_Loss: 145.672; Val_Loss: 143.201   Train_ACC: 51.051; Val_ACC: 56.000   Train_NMI: 0.025; Val_NMI: 1.035
# (Epoch 274 / 10000) Train_Loss: 145.519; Val_Loss: 140.691   Train_ACC: 51.576; Val_ACC: 56.000   Train_NMI: 0.054; Val_NMI: 1.035
# (Epoch 275 / 10000) Train_Loss: 145.310; Val_Loss: 146.475   Train_ACC: 51.751; Val_ACC: 56.000   Train_NMI: 0.069; Val_NMI: 1.049
# (Epoch 276 / 10000) Train_Loss: 145.556; Val_Loss: 138.357   Train_ACC: 51.751; Val_ACC: 55.000   Train_NMI: 0.070; Val_NMI: 0.713
# (Epoch 277 / 10000) Train_Loss: 143.055; Val_Loss: 143.278   Train_ACC: 51.576; Val_ACC: 56.000   Train_NMI: 0.055; Val_NMI: 1.049
# (Epoch 278 / 10000) Train_Loss: 141.476; Val_Loss: 138.368   Train_ACC: 50.613; Val_ACC: 55.000   Train_NMI: 0.007; Val_NMI: 0.723
# (Epoch 279 / 10000) Train_Loss: 141.207; Val_Loss: 138.896   Train_ACC: 51.489; Val_ACC: 56.000   Train_NMI: 0.047; Val_NMI: 1.049
# (Epoch 280 / 10000) Train_Loss: 140.004; Val_Loss: 134.165   Train_ACC: 50.175; Val_ACC: 56.000   Train_NMI: 0.001; Val_NMI: 1.092
# (Epoch 281 / 10000) Train_Loss: 139.396; Val_Loss: 134.948   Train_ACC: 50.788; Val_ACC: 55.000   Train_NMI: 0.014; Val_NMI: 0.723
# (Epoch 282 / 10000) Train_Loss: 138.487; Val_Loss: 137.120   Train_ACC: 51.313; Val_ACC: 57.000   Train_NMI: 0.038; Val_NMI: 1.439
# (Epoch 283 / 10000) Train_Loss: 139.257; Val_Loss: 138.845   Train_ACC: 51.051; Val_ACC: 57.000   Train_NMI: 0.024; Val_NMI: 1.439
# (Epoch 284 / 10000) Train_Loss: 140.384; Val_Loss: 133.047   Train_ACC: 51.226; Val_ACC: 56.000   Train_NMI: 0.033; Val_NMI: 1.035
# (Epoch 285 / 10000) Train_Loss: 140.432; Val_Loss: 138.973   Train_ACC: 50.613; Val_ACC: 57.000   Train_NMI: 0.007; Val_NMI: 1.499
# (Epoch 286 / 10000) Train_Loss: 140.391; Val_Loss: 135.379   Train_ACC: 50.350; Val_ACC: 58.000   Train_NMI: 0.004; Val_NMI: 1.930
# (Epoch 287 / 10000) Train_Loss: 138.904; Val_Loss: 132.363   Train_ACC: 50.963; Val_ACC: 56.000   Train_NMI: 0.019; Val_NMI: 1.049
# (Epoch 288 / 10000) Train_Loss: 139.100; Val_Loss: 137.113   Train_ACC: 51.051; Val_ACC: 56.000   Train_NMI: 0.026; Val_NMI: 1.049
# (Epoch 289 / 10000) Train_Loss: 141.265; Val_Loss: 142.294   Train_ACC: 51.751; Val_ACC: 55.000   Train_NMI: 0.070; Val_NMI: 0.713
# (Epoch 290 / 10000) Train_Loss: 142.905; Val_Loss: 136.525   Train_ACC: 51.751; Val_ACC: 55.000   Train_NMI: 0.071; Val_NMI: 0.723
# (Epoch 291 / 10000) Train_Loss: 139.744; Val_Loss: 134.138   Train_ACC: 50.788; Val_ACC: 57.000   Train_NMI: 0.014; Val_NMI: 1.439
# (Epoch 292 / 10000) Train_Loss: 138.708; Val_Loss: 133.907   Train_ACC: 50.525; Val_ACC: 54.000   Train_NMI: 0.005; Val_NMI: 0.451
# (Epoch 293 / 10000) Train_Loss: 139.682; Val_Loss: 135.443   Train_ACC: 50.788; Val_ACC: 56.000   Train_NMI: 0.013; Val_NMI: 1.092
# (Epoch 294 / 10000) Train_Loss: 138.902; Val_Loss: 134.999   Train_ACC: 50.525; Val_ACC: 57.000   Train_NMI: 0.006; Val_NMI: 1.439
# (Epoch 295 / 10000) Train_Loss: 140.057; Val_Loss: 135.405   Train_ACC: 51.051; Val_ACC: 56.000   Train_NMI: 0.028; Val_NMI: 1.068
# (Epoch 296 / 10000) Train_Loss: 141.987; Val_Loss: 134.633   Train_ACC: 50.088; Val_ACC: 56.000   Train_NMI: 0.000; Val_NMI: 1.068
# (Epoch 297 / 10000) Train_Loss: 138.577; Val_Loss: 132.175   Train_ACC: 50.088; Val_ACC: 56.000   Train_NMI: 0.000; Val_NMI: 1.035
# (Epoch 298 / 10000) Train_Loss: 135.700; Val_Loss: 132.200   Train_ACC: 51.051; Val_ACC: 55.000   Train_NMI: 0.025; Val_NMI: 0.736
# (Epoch 299 / 10000) Train_Loss: 132.563; Val_Loss: 128.784   Train_ACC: 51.489; Val_ACC: 56.000   Train_NMI: 0.050; Val_NMI: 1.049
# (Epoch 300 / 10000) Train_Loss: 130.894; Val_Loss: 126.147   Train_ACC: 50.788; Val_ACC: 57.000   Train_NMI: 0.014; Val_NMI: 1.465
# (Epoch 301 / 10000) Train_Loss: 130.577; Val_Loss: 125.236   Train_ACC: 50.263; Val_ACC: 57.000   Train_NMI: 0.001; Val_NMI: 1.465
# (Epoch 302 / 10000) Train_Loss: 129.309; Val_Loss: 126.654   Train_ACC: 50.350; Val_ACC: 58.000   Train_NMI: 0.003; Val_NMI: 1.894
# (Epoch 303 / 10000) Train_Loss: 128.598; Val_Loss: 126.386   Train_ACC: 50.701; Val_ACC: 57.000   Train_NMI: 0.013; Val_NMI: 1.439
# (Epoch 304 / 10000) Train_Loss: 129.395; Val_Loss: 127.109   Train_ACC: 51.051; Val_ACC: 56.000   Train_NMI: 0.021; Val_NMI: 1.035
# (Epoch 305 / 10000) Train_Loss: 128.602; Val_Loss: 123.249   Train_ACC: 51.313; Val_ACC: 57.000   Train_NMI: 0.039; Val_NMI: 1.439
# (Epoch 306 / 10000) Train_Loss: 126.590; Val_Loss: 122.596   Train_ACC: 50.876; Val_ACC: 58.000   Train_NMI: 0.020; Val_NMI: 1.894
# (Epoch 307 / 10000) Train_Loss: 125.832; Val_Loss: 120.927   Train_ACC: 50.525; Val_ACC: 56.000   Train_NMI: 0.006; Val_NMI: 1.049
# (Epoch 308 / 10000) Train_Loss: 125.470; Val_Loss: 121.090   Train_ACC: 51.138; Val_ACC: 56.000   Train_NMI: 0.030; Val_NMI: 1.049
# (Epoch 309 / 10000) Train_Loss: 123.723; Val_Loss: 120.688   Train_ACC: 50.525; Val_ACC: 58.000   Train_NMI: 0.006; Val_NMI: 1.930
# (Epoch 310 / 10000) Train_Loss: 123.059; Val_Loss: 123.313   Train_ACC: 50.088; Val_ACC: 56.000   Train_NMI: 0.000; Val_NMI: 1.049
# (Epoch 311 / 10000) Train_Loss: 124.730; Val_Loss: 124.692   Train_ACC: 51.313; Val_ACC: 55.000   Train_NMI: 0.039; Val_NMI: 0.723

# %%
torch.save(gmvae.network.state_dict(), f'smba_gmvae_8_{num_epochs}.pth')

# %%
gmvae.network.load_state_dict(torch.load('smba_gmvae.pth'))
# Out:
# <All keys matched successfully>

# %%
# with open('training_history.json', 'w+') as json_f:
#     json.dump(history_loss, json_f)

# %% [markdown]
# ## Image Reconstruction

# %%
size_of_training_set = len(train_ds)
size_of_training_set
# Out:
# 2698

# %%
original, reconstructed = gmvae.reconstruct_data(train_dl, size_of_training_set)

# %%
original_int = original.reshape(size_of_training_set, 16, 16, 12).argmax(axis=-1)
reconstructed_int = reconstructed.reshape(size_of_training_set, 16, 16, 12).argmax(axis=-1)

# %%
errors = reconstructed_int != original_int

# %% [markdown]
# Number of errors per chunk:

# %%
np.sum(errors) / size_of_training_set
# Out:
# 3.0937731653076352

# %%
# the tile indexes that are incorrectly reconstructed
tile_idx_errors = original_int[errors]

# %%
char2int_smb = { 
    "X": 0,  # smb unpassable
    "S": 1,  # smb breakable
    "-": 2,
    "?": 3,  # smb question
    "Q": 4,  # smb question
    "E": 5,
    "<": 6,
    ">": 7,
    "[": 8,
    "]": 9,
    "o": 10,
    "P": 11,  # for smb path (from Anurag's email)
}

int2char_smb = {v:k for k, v in char2int_smb.items()}

# %% [markdown]
# Proportion of errors for each tile type:

# %%
plt.bar(np.unique(tile_idx_errors), np.bincount(tile_idx_errors) / np.bincount(original_int.flatten()))
plt.xticks(np.unique(tile_idx_errors), [int2char_smb[i] for i in np.unique(tile_idx_errors)])
plt.show()

# %%
def get_classes(chunks_int):
    classes = []
    for i in chunks_int:
        if i.max() == 6:
            classes.append('kia')
        else:
            classes.append('smba')
    return np.array(classes)

# %%
org_classes = get_classes(original_int)
rec_classes = get_classes(reconstructed_int)
assert np.sum(org_classes == rec_classes) == len(org_classes)

# %%
def get_images(chunks_int):
    images = []
    for game, chunk in zip(get_classes(chunks_int), chunks_int):
        images.append(vglc_with_path_encodings.array_to_image([chunk], game=game)[0])
    return images

# %%
org_images = get_images(original_int)
rec_images = get_images(reconstructed_int)
len(org_images), len(rec_images)
# Out:
# (2698, 2698)

# %%
fig, axes = plt.subplots(nrows=3, ncols=10, figsize=(24, 8))
axes = axes.flatten()
nrows, ncols = 3, 10

org_idxs = np.arange(0, 29, 2)
rec_idxs = org_idxs + 1

for idx in org_idxs:
        
    ax = axes[idx]

    ax.imshow(np.asarray(org_images[idx // 2]))
    ax.set_title(f'Org {idx // 2 + 1}')
    
    ax.axis('off')

for idx in rec_idxs:
        
    ax = axes[idx]

    ax.imshow(np.asarray(rec_images[idx // 2]))
    ax.set_title(f'Rec {idx // 2 + 1}')

    ax.axis('off')
    
plt.show()

# %% [markdown]
# ## Random Generation per Category

# %%
def display_random_generation(generated, num_classes, n=10):
    plt.figure(figsize=[24,24])
    for c in range(num_classes):
        for i in range(n):
            plt.subplot(num_classes, n, (c * n) + i + 1)
            chunk_int = generated[(c * n) + i].reshape(16, 16, 12).argmax(axis=-1)
            chunk_pix = vglc_with_path_encodings.array_to_image([chunk_int], game='smba')[0]
            plt.imshow(chunk_pix)
            plt.gray()
            plt.axis('off')
    plt.show()

elem_per_category = 8
generated = gmvae.random_generation(elem_per_category)
display_random_generation(generated, args.num_classes, elem_per_category)

# %%
elem_per_category = 10000 // 8
generated = gmvae.random_generation(elem_per_category)

# %%
generated_int = generated.reshape(-1, 16, 16, 12).argmax(axis=-1)

# %%
generated_int.shape
# Out:
# (10000, 16, 16)

# %%
# since this code chunk depends on random seed, it shouldn't be run again
with open(f'../smba_generations/smba_gmvae_8_{num_epochs}.json', 'w+') as json_f:
    json.dump(generated_int.tolist(), json_f)

# %% [markdown]
# ## Visualization of the feature latent space

# %%
# get feature representations
test_features, test_labels = gmvae.latent_features(train_dl, return_learned_labels=True)

# %%
np.bincount(test_labels)
# Out:
# array([329, 304, 330, 436, 199, 257, 272, 301])

# %%
# import TSNE from scikit-learn library
from sklearn.manifold import TSNE

# reduce dimensionality to 2D, we consider a subset of data because TSNE
# is a slow algorithm

first_n = 1000
tsne_features = TSNE(n_components=2).fit_transform(test_features[:first_n])

# %%
test_labels_subset = test_labels[:first_n]

# %%
X_, Y_ = np.s_[:,0], np.s_[:,1]

# %%
fig = plt.figure(figsize=(5, 5))

plt.scatter(tsne_features[X_], tsne_features[Y_], c=test_labels_subset, cmap='tab10')

plt.title('Projection from latent space to 2D')
plt.show()
