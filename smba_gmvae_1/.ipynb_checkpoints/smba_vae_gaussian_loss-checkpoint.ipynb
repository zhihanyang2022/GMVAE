# %% [markdown]
# # VAE for SMBA
#
# This VAE is adapted from the GM-VAE implementation.

# %%
# %reload_ext autoreload
# %autoreload 2

# %%
num_epochs=10000

# %% [markdown]
# ## Import Libraries

# %%
import json

import numpy as np
import argparse
import random
from torchvision import datasets, transforms
from torch.utils.data.sampler import SubsetRandomSampler
import torch.utils.data
from scipy.io import loadmat
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

import warnings
warnings.filterwarnings('ignore')

import sys

sys.path.append('../pytorch')
from model.VAE import *

sys.path.append('../../1906-pcgml/pcgml-gmmVae-exp/modules/')
import vglc_with_path_encodings

# %% [markdown]
# ## Load data

# %%
def open_json_as_nparray(json_fname):
    with open(json_fname, 'r') as json_f:
        return np.array(json.load(json_f))

# %% [markdown]
# Load SMB.

# %%
smb_int = open_json_as_nparray('smbWithPath-allLevels-chunks-int.json')

# %%
smb_onehot = np.eye(len(np.unique(smb_int)))[smb_int]
smb_onehot.shape
# Out:
# (2698, 16, 16, 12)

# %%
smb_onehot = smb_onehot.reshape(
    smb_onehot.shape[0], 
    smb_onehot.shape[1] * smb_onehot.shape[2] * smb_onehot.shape[3]
)
smb_onehot.shape
# Out:
# (2698, 3072)

# %%
chunks = smb_onehot

# %% [markdown]
# ## Input Parameters

# %%
########################################################
## Input Parameters
#########################################################
parser = argparse.ArgumentParser(description='PyTorch Implementation of DGM Clustering')

## Used only in notebooks
parser.add_argument('-f', '--file',
                    help='Path for input file. First line should contain number of lines to search in')

## Dataset
parser.add_argument('--dataset', type=str, choices=['mnist'],
                    default='mnist', help='dataset (default: mnist)')
parser.add_argument('--seed', type=int, default=1, help='random seed (default: 1)')

## GPU
parser.add_argument('--cuda', type=int, default=1,
                    help='use of cuda (default: 1)')
parser.add_argument('--gpuID', type=int, default=0,
                    help='set gpu id to use (default: 0)')

## Training
parser.add_argument('--epochs', type=int, default=num_epochs,
                    help='number of total epochs to run (default: 200)')
parser.add_argument('--batch_size', default=64, type=int,
                    help='mini-batch size (default: 64)')
parser.add_argument('--batch_size_val', default=200, type=int,
                    help='mini-batch size of validation (default: 200)')
parser.add_argument('--learning_rate', default=1e-3, type=float,
                    help='learning rate (default: 0.001)')
parser.add_argument('--decay_epoch', default=-1, type=int, 
                    help='Reduces the learning rate every decay_epoch')
parser.add_argument('--lr_decay', default=0.5, type=float,
                    help='Learning rate decay for training (default: 0.5)')

## Architecture
parser.add_argument('--gaussian_size', default=64, type=int,
                    help='gaussian size (default: 64)')
parser.add_argument('--input_size', default=3072, type=int,
                    help='input size (default: 784)')  # edited for this task

## Partition parameters
parser.add_argument('--train_proportion', default=0.9, type=float,
                    help='proportion of examples to consider for training only (default: 1.0)')

## Loss function parameters
parser.add_argument('--w_gauss', default=2, type=float,
                    help='weight of gaussian loss (default: 1)')
parser.add_argument('--w_categ', default=1, type=float,
                    help='weight of categorical loss (default: 1)')
parser.add_argument('--w_rec', default=1, type=float,
                    help='weight of reconstruction loss (default: 1)')
parser.add_argument('--rec_type', type=str, choices=['bce', 'mse'],
                    default='bce', help='desired reconstruction loss function (default: bce)')

## Others
parser.add_argument('--verbose', default=0, type=int,
                    help='print extra information at every epoch.(default: 0)')

args = parser.parse_args()

# %% [markdown]
# Set random seed in case it was specified in the parameters

# %%
## Random Seed
SEED = args.seed
np.random.seed(SEED)
random.seed(SEED)
torch.manual_seed(SEED)
if args.cuda:
    torch.cuda.manual_seed(SEED)

# %% [markdown]
# ## Data Partition

# %% [markdown]
# We split the training data into train and validation according to the *train_proportion* parameter:

# %%
from torch.utils.data import TensorDataset, DataLoader

# %%
assert args.train_proportion != 1

# %%
def partition_dataset(n, proportion=1):
   train_num = int(n * proportion)
   indices = np.random.permutation(n)
   train_indices, val_indices = indices[:train_num], indices[train_num:]
   return train_indices, val_indices

train_indices, val_indices = partition_dataset(len(chunks), args.train_proportion)
train_ds = TensorDataset(torch.from_numpy(chunks).float())
train_dl = DataLoader(train_ds, batch_size=args.batch_size, sampler=SubsetRandomSampler(train_indices))
valid_dl = DataLoader(train_ds, batch_size=args.batch_size_val, sampler=SubsetRandomSampler(val_indices))

# %% [markdown]
# ## Train Model

# %%
# Model Initialization
vae = VAE(args)

# %%
history_loss = vae.train(train_dl, valid_dl)
# Out:
# Epoch     1 / 10000 | Total loss:  471.42 | Recon loss:  442.93 | Gauss loss:   14.25
# Epoch     2 / 10000 | Total loss:  229.95 | Recon loss:  227.65 | Gauss loss:    1.15
# Epoch     3 / 10000 | Total loss:  226.16 | Recon loss:  223.27 | Gauss loss:    1.44
# Epoch     4 / 10000 | Total loss:  221.32 | Recon loss:  217.46 | Gauss loss:    1.93
# Epoch     5 / 10000 | Total loss:  214.62 | Recon loss:  209.72 | Gauss loss:    2.45
# Epoch     6 / 10000 | Total loss:  211.15 | Recon loss:  205.49 | Gauss loss:    2.83
# Epoch     7 / 10000 | Total loss:  207.52 | Recon loss:  200.93 | Gauss loss:    3.29
# Epoch     8 / 10000 | Total loss:  205.03 | Recon loss:  197.82 | Gauss loss:     3.6
# Epoch     9 / 10000 | Total loss:  202.78 | Recon loss:  195.61 | Gauss loss:    3.59
# Epoch    10 / 10000 | Total loss:  200.02 | Recon loss:  192.77 | Gauss loss:    3.63
# Epoch    11 / 10000 | Total loss:  196.46 | Recon loss:  189.42 | Gauss loss:    3.52
# Epoch    12 / 10000 | Total loss:  193.31 | Recon loss:  186.34 | Gauss loss:    3.48
# Epoch    13 / 10000 | Total loss:  190.16 | Recon loss:  183.07 | Gauss loss:    3.54
# Epoch    14 / 10000 | Total loss:  188.83 | Recon loss:  181.35 | Gauss loss:    3.74
# Epoch    15 / 10000 | Total loss:  186.56 | Recon loss:  178.73 | Gauss loss:    3.91
# Epoch    16 / 10000 | Total loss:  183.66 | Recon loss:  175.47 | Gauss loss:     4.1
# Epoch    17 / 10000 | Total loss:  181.96 | Recon loss:  173.28 | Gauss loss:    4.34
# Epoch    18 / 10000 | Total loss:  179.46 | Recon loss:  170.59 | Gauss loss:    4.43
# Epoch    19 / 10000 | Total loss:  178.19 | Recon loss:  169.14 | Gauss loss:    4.52
# Epoch    20 / 10000 | Total loss:   176.8 | Recon loss:  167.71 | Gauss loss:    4.55
# Epoch    21 / 10000 | Total loss:  174.58 | Recon loss:  165.33 | Gauss loss:    4.63
# Epoch    22 / 10000 | Total loss:  172.74 | Recon loss:  163.57 | Gauss loss:    4.59
# Epoch    23 / 10000 | Total loss:   172.2 | Recon loss:  163.08 | Gauss loss:    4.56
# Epoch    24 / 10000 | Total loss:  171.47 | Recon loss:  162.31 | Gauss loss:    4.58
# Epoch    25 / 10000 | Total loss:   170.2 | Recon loss:  160.87 | Gauss loss:    4.66
# Epoch    26 / 10000 | Total loss:   169.4 | Recon loss:  160.12 | Gauss loss:    4.64
# Epoch    27 / 10000 | Total loss:  168.54 | Recon loss:  159.02 | Gauss loss:    4.76
# Epoch    28 / 10000 | Total loss:  168.08 | Recon loss:  158.35 | Gauss loss:    4.86
# Epoch    29 / 10000 | Total loss:  167.56 | Recon loss:  157.58 | Gauss loss:    4.99
# Epoch    30 / 10000 | Total loss:  167.24 | Recon loss:  157.14 | Gauss loss:    5.05
# Epoch    31 / 10000 | Total loss:   165.1 | Recon loss:   154.6 | Gauss loss:    5.25
# Epoch    32 / 10000 | Total loss:  164.34 | Recon loss:  153.52 | Gauss loss:    5.41
# Epoch    33 / 10000 | Total loss:  163.27 | Recon loss:   152.2 | Gauss loss:    5.53
# Epoch    34 / 10000 | Total loss:  162.05 | Recon loss:  150.59 | Gauss loss:    5.73
# Epoch    35 / 10000 | Total loss:  161.42 | Recon loss:  150.03 | Gauss loss:     5.7
# Epoch    36 / 10000 | Total loss:  160.26 | Recon loss:  148.77 | Gauss loss:    5.75
# Epoch    37 / 10000 | Total loss:  159.31 | Recon loss:  147.72 | Gauss loss:    5.79
# Epoch    38 / 10000 | Total loss:  158.97 | Recon loss:  147.32 | Gauss loss:    5.82
# Epoch    39 / 10000 | Total loss:  157.32 | Recon loss:  145.31 | Gauss loss:     6.0
# Epoch    40 / 10000 | Total loss:  155.93 | Recon loss:  143.94 | Gauss loss:    5.99
# Epoch    41 / 10000 | Total loss:  155.68 | Recon loss:  143.54 | Gauss loss:    6.07
# Epoch    42 / 10000 | Total loss:  154.46 | Recon loss:  142.07 | Gauss loss:    6.19
# Epoch    43 / 10000 | Total loss:  153.63 | Recon loss:  140.97 | Gauss loss:    6.33
# Epoch    44 / 10000 | Total loss:  152.68 | Recon loss:  139.93 | Gauss loss:    6.37
# Epoch    45 / 10000 | Total loss:   152.2 | Recon loss:  139.47 | Gauss loss:    6.36
# Epoch    46 / 10000 | Total loss:   151.8 | Recon loss:  138.86 | Gauss loss:    6.47
# Epoch    47 / 10000 | Total loss:  150.41 | Recon loss:  137.38 | Gauss loss:    6.51
# Epoch    48 / 10000 | Total loss:   149.9 | Recon loss:   136.7 | Gauss loss:     6.6
# Epoch    49 / 10000 | Total loss:  148.71 | Recon loss:   135.4 | Gauss loss:    6.65
# Epoch    50 / 10000 | Total loss:   148.0 | Recon loss:  134.65 | Gauss loss:    6.67
# Epoch    51 / 10000 | Total loss:  147.19 | Recon loss:  133.81 | Gauss loss:    6.69
# Epoch    52 / 10000 | Total loss:  147.02 | Recon loss:  133.42 | Gauss loss:     6.8
# Epoch    53 / 10000 | Total loss:  146.12 | Recon loss:  132.44 | Gauss loss:    6.84
# Epoch    54 / 10000 | Total loss:  145.29 | Recon loss:  131.57 | Gauss loss:    6.86
# Epoch    55 / 10000 | Total loss:  144.39 | Recon loss:  130.51 | Gauss loss:    6.94
# Epoch    56 / 10000 | Total loss:  143.94 | Recon loss:  129.89 | Gauss loss:    7.03
# Epoch    57 / 10000 | Total loss:  143.87 | Recon loss:  129.96 | Gauss loss:    6.96
# Epoch    58 / 10000 | Total loss:  142.09 | Recon loss:  127.95 | Gauss loss:    7.07
# Epoch    59 / 10000 | Total loss:  141.47 | Recon loss:  127.43 | Gauss loss:    7.02
# Epoch    60 / 10000 | Total loss:  141.02 | Recon loss:  126.77 | Gauss loss:    7.13
# Epoch    61 / 10000 | Total loss:  140.47 | Recon loss:  125.97 | Gauss loss:    7.25
# Epoch    62 / 10000 | Total loss:  140.56 | Recon loss:  126.12 | Gauss loss:    7.22
# Epoch    63 / 10000 | Total loss:  139.43 | Recon loss:  124.83 | Gauss loss:     7.3
# Epoch    64 / 10000 | Total loss:  138.02 | Recon loss:  123.51 | Gauss loss:    7.26
# Epoch    65 / 10000 | Total loss:  138.62 | Recon loss:  124.02 | Gauss loss:     7.3
# Epoch    66 / 10000 | Total loss:  138.24 | Recon loss:  123.38 | Gauss loss:    7.43
# Epoch    67 / 10000 | Total loss:  136.26 | Recon loss:  121.45 | Gauss loss:    7.41
# Epoch    68 / 10000 | Total loss:  136.18 | Recon loss:  121.27 | Gauss loss:    7.46
# Epoch    69 / 10000 | Total loss:  136.06 | Recon loss:  121.04 | Gauss loss:    7.51
# Epoch    70 / 10000 | Total loss:  135.86 | Recon loss:  120.53 | Gauss loss:    7.67
# Epoch    71 / 10000 | Total loss:  135.08 | Recon loss:  120.04 | Gauss loss:    7.52
# Epoch    72 / 10000 | Total loss:   134.8 | Recon loss:  119.51 | Gauss loss:    7.65
# Epoch    73 / 10000 | Total loss:  133.95 | Recon loss:  118.62 | Gauss loss:    7.67
# Epoch    74 / 10000 | Total loss:  133.63 | Recon loss:  118.29 | Gauss loss:    7.67
# Epoch    75 / 10000 | Total loss:  133.09 | Recon loss:  117.69 | Gauss loss:     7.7
# Epoch    76 / 10000 | Total loss:  132.61 | Recon loss:  117.23 | Gauss loss:    7.69
# Epoch    77 / 10000 | Total loss:  131.64 | Recon loss:  116.11 | Gauss loss:    7.76
# Epoch    78 / 10000 | Total loss:  131.28 | Recon loss:  115.76 | Gauss loss:    7.76
# Epoch    79 / 10000 | Total loss:  130.83 | Recon loss:  115.31 | Gauss loss:    7.76
# Epoch    80 / 10000 | Total loss:   130.1 | Recon loss:  114.52 | Gauss loss:    7.79
# Epoch    81 / 10000 | Total loss:  129.72 | Recon loss:  114.25 | Gauss loss:    7.74
# Epoch    82 / 10000 | Total loss:   129.2 | Recon loss:  113.29 | Gauss loss:    7.96
# Epoch    83 / 10000 | Total loss:  129.26 | Recon loss:   113.4 | Gauss loss:    7.93
# Epoch    84 / 10000 | Total loss:  128.23 | Recon loss:  112.37 | Gauss loss:    7.93
# Epoch    85 / 10000 | Total loss:  127.92 | Recon loss:   112.0 | Gauss loss:    7.96
# Epoch    86 / 10000 | Total loss:  127.82 | Recon loss:  111.67 | Gauss loss:    8.07
# Epoch    87 / 10000 | Total loss:  127.07 | Recon loss:  111.04 | Gauss loss:    8.02
# Epoch    88 / 10000 | Total loss:  126.98 | Recon loss:  110.76 | Gauss loss:    8.11
# Epoch    89 / 10000 | Total loss:  126.12 | Recon loss:  109.95 | Gauss loss:    8.09
# Epoch    90 / 10000 | Total loss:  125.42 | Recon loss:  109.19 | Gauss loss:    8.11
# Epoch    91 / 10000 | Total loss:  124.85 | Recon loss:  108.63 | Gauss loss:    8.11
# Epoch    92 / 10000 | Total loss:  124.99 | Recon loss:  108.69 | Gauss loss:    8.15
# Epoch    93 / 10000 | Total loss:  124.88 | Recon loss:  108.48 | Gauss loss:     8.2
# Epoch    94 / 10000 | Total loss:   124.9 | Recon loss:  108.42 | Gauss loss:    8.24
# Epoch    95 / 10000 | Total loss:  123.72 | Recon loss:  107.29 | Gauss loss:    8.22
# Epoch    96 / 10000 | Total loss:  124.57 | Recon loss:  107.99 | Gauss loss:    8.29
# Epoch    97 / 10000 | Total loss:   122.9 | Recon loss:   106.4 | Gauss loss:    8.25
# Epoch    98 / 10000 | Total loss:  122.16 | Recon loss:  105.47 | Gauss loss:    8.34
# Epoch    99 / 10000 | Total loss:  122.67 | Recon loss:  106.15 | Gauss loss:    8.26
# Epoch   100 / 10000 | Total loss:   122.4 | Recon loss:  105.67 | Gauss loss:    8.37
# Epoch   101 / 10000 | Total loss:  121.22 | Recon loss:  104.55 | Gauss loss:    8.34
# Epoch   102 / 10000 | Total loss:  120.89 | Recon loss:  104.05 | Gauss loss:    8.42
# Epoch   103 / 10000 | Total loss:  121.47 | Recon loss:   104.7 | Gauss loss:    8.38
# Epoch   104 / 10000 | Total loss:  120.61 | Recon loss:  103.67 | Gauss loss:    8.47
# Epoch   105 / 10000 | Total loss:  120.66 | Recon loss:  103.71 | Gauss loss:    8.47
# Epoch   106 / 10000 | Total loss:  119.79 | Recon loss:  102.73 | Gauss loss:    8.53
# Epoch   107 / 10000 | Total loss:  118.04 | Recon loss:  101.02 | Gauss loss:    8.51
# Epoch   108 / 10000 | Total loss:  117.69 | Recon loss:  100.66 | Gauss loss:    8.52
# Epoch   109 / 10000 | Total loss:  117.92 | Recon loss:  100.73 | Gauss loss:    8.59
# Epoch   110 / 10000 | Total loss:  117.64 | Recon loss:  100.45 | Gauss loss:    8.59
# Epoch   111 / 10000 | Total loss:  116.76 | Recon loss:    99.5 | Gauss loss:    8.63
# Epoch   112 / 10000 | Total loss:   116.0 | Recon loss:   98.63 | Gauss loss:    8.69
# Epoch   113 / 10000 | Total loss:  116.83 | Recon loss:   99.64 | Gauss loss:    8.59
# Epoch   114 / 10000 | Total loss:  116.72 | Recon loss:    99.6 | Gauss loss:    8.56
# Epoch   115 / 10000 | Total loss:  115.98 | Recon loss:    98.6 | Gauss loss:    8.69
# Epoch   116 / 10000 | Total loss:   115.0 | Recon loss:   97.55 | Gauss loss:    8.73
# Epoch   117 / 10000 | Total loss:  114.17 | Recon loss:    96.6 | Gauss loss:    8.79
# Epoch   118 / 10000 | Total loss:  114.38 | Recon loss:   96.83 | Gauss loss:    8.78
# Epoch   119 / 10000 | Total loss:  113.58 | Recon loss:    96.0 | Gauss loss:    8.79
# Epoch   120 / 10000 | Total loss:  113.18 | Recon loss:   95.62 | Gauss loss:    8.78
# Epoch   121 / 10000 | Total loss:  114.37 | Recon loss:   96.85 | Gauss loss:    8.76
# Epoch   122 / 10000 | Total loss:  114.53 | Recon loss:   96.75 | Gauss loss:    8.89
# Epoch   123 / 10000 | Total loss:  112.53 | Recon loss:   94.83 | Gauss loss:    8.85
# Epoch   124 / 10000 | Total loss:  111.89 | Recon loss:   94.03 | Gauss loss:    8.93
# Epoch   125 / 10000 | Total loss:  113.37 | Recon loss:    95.5 | Gauss loss:    8.93
# Epoch   126 / 10000 | Total loss:  112.86 | Recon loss:   95.02 | Gauss loss:    8.92
# Epoch   127 / 10000 | Total loss:  112.55 | Recon loss:    94.7 | Gauss loss:    8.92
# Epoch   128 / 10000 | Total loss:  111.55 | Recon loss:   93.67 | Gauss loss:    8.94
# Epoch   129 / 10000 | Total loss:  112.55 | Recon loss:    94.6 | Gauss loss:    8.98
# Epoch   130 / 10000 | Total loss:  111.23 | Recon loss:   93.28 | Gauss loss:    8.97
# Epoch   131 / 10000 | Total loss:  111.41 | Recon loss:   93.25 | Gauss loss:    9.08
# Epoch   132 / 10000 | Total loss:  109.61 | Recon loss:   91.53 | Gauss loss:    9.04
# Epoch   133 / 10000 | Total loss:  108.41 | Recon loss:   90.32 | Gauss loss:    9.04
# Epoch   134 / 10000 | Total loss:  108.87 | Recon loss:   90.66 | Gauss loss:     9.1
# Epoch   135 / 10000 | Total loss:  108.32 | Recon loss:   90.05 | Gauss loss:    9.13
# Epoch   136 / 10000 | Total loss:   108.6 | Recon loss:   90.43 | Gauss loss:    9.08
# Epoch   137 / 10000 | Total loss:  107.44 | Recon loss:   89.05 | Gauss loss:     9.2
# Epoch   138 / 10000 | Total loss:  107.46 | Recon loss:   89.16 | Gauss loss:    9.15
# Epoch   139 / 10000 | Total loss:  107.01 | Recon loss:   88.84 | Gauss loss:    9.09
# Epoch   140 / 10000 | Total loss:  106.87 | Recon loss:    88.5 | Gauss loss:    9.18
# Epoch   141 / 10000 | Total loss:  106.13 | Recon loss:   87.72 | Gauss loss:    9.21
# Epoch   142 / 10000 | Total loss:  105.52 | Recon loss:    87.1 | Gauss loss:    9.21
# Epoch   143 / 10000 | Total loss:  105.68 | Recon loss:   87.15 | Gauss loss:    9.26
# Epoch   144 / 10000 | Total loss:  105.86 | Recon loss:   87.34 | Gauss loss:    9.26
# Epoch   145 / 10000 | Total loss:  105.07 | Recon loss:   86.35 | Gauss loss:    9.36
# Epoch   146 / 10000 | Total loss:  106.43 | Recon loss:   88.08 | Gauss loss:    9.17
# Epoch   147 / 10000 | Total loss:  105.11 | Recon loss:   86.48 | Gauss loss:    9.31
# Epoch   148 / 10000 | Total loss:   104.1 | Recon loss:    85.4 | Gauss loss:    9.35
# Epoch   149 / 10000 | Total loss:  103.75 | Recon loss:   85.24 | Gauss loss:    9.25
# Epoch   150 / 10000 | Total loss:  103.19 | Recon loss:   84.45 | Gauss loss:    9.37
# Epoch   151 / 10000 | Total loss:  103.01 | Recon loss:   84.16 | Gauss loss:    9.43
# Epoch   152 / 10000 | Total loss:  103.25 | Recon loss:   84.41 | Gauss loss:    9.42
# Epoch   153 / 10000 | Total loss:  103.95 | Recon loss:   85.21 | Gauss loss:    9.37
# Epoch   154 / 10000 | Total loss:  103.18 | Recon loss:   84.42 | Gauss loss:    9.38
# Epoch   155 / 10000 | Total loss:  103.06 | Recon loss:   84.35 | Gauss loss:    9.36
# Epoch   156 / 10000 | Total loss:  103.04 | Recon loss:   84.12 | Gauss loss:    9.46
# Epoch   157 / 10000 | Total loss:   101.8 | Recon loss:   82.74 | Gauss loss:    9.53
# Epoch   158 / 10000 | Total loss:  101.15 | Recon loss:   82.07 | Gauss loss:    9.54
# Epoch   159 / 10000 | Total loss:  100.44 | Recon loss:   81.59 | Gauss loss:    9.42
# Epoch   160 / 10000 | Total loss:  100.19 | Recon loss:   81.02 | Gauss loss:    9.59
# Epoch   161 / 10000 | Total loss:  100.56 | Recon loss:   81.68 | Gauss loss:    9.44
# Epoch   162 / 10000 | Total loss:  100.32 | Recon loss:   81.16 | Gauss loss:    9.58
# Epoch   163 / 10000 | Total loss:  100.71 | Recon loss:   81.69 | Gauss loss:    9.51
# Epoch   164 / 10000 | Total loss:  100.93 | Recon loss:   81.77 | Gauss loss:    9.58
# Epoch   165 / 10000 | Total loss:   99.44 | Recon loss:    80.3 | Gauss loss:    9.57
# Epoch   166 / 10000 | Total loss:    98.0 | Recon loss:   78.85 | Gauss loss:    9.57
# Epoch   167 / 10000 | Total loss:   97.59 | Recon loss:   78.22 | Gauss loss:    9.68
# Epoch   168 / 10000 | Total loss:    97.7 | Recon loss:   78.43 | Gauss loss:    9.63
# Epoch   169 / 10000 | Total loss:   98.95 | Recon loss:   79.61 | Gauss loss:    9.67
# Epoch   170 / 10000 | Total loss:   99.04 | Recon loss:   79.75 | Gauss loss:    9.65
# Epoch   171 / 10000 | Total loss:   98.57 | Recon loss:   79.48 | Gauss loss:    9.54
# Epoch   172 / 10000 | Total loss:   97.87 | Recon loss:   78.43 | Gauss loss:    9.72
# Epoch   173 / 10000 | Total loss:   96.99 | Recon loss:   77.63 | Gauss loss:    9.68
# Epoch   174 / 10000 | Total loss:   97.16 | Recon loss:   77.76 | Gauss loss:     9.7
# Epoch   175 / 10000 | Total loss:   97.01 | Recon loss:   77.72 | Gauss loss:    9.65
# Epoch   176 / 10000 | Total loss:   97.85 | Recon loss:   78.57 | Gauss loss:    9.64
# Epoch   177 / 10000 | Total loss:   96.88 | Recon loss:   77.35 | Gauss loss:    9.77
# Epoch   178 / 10000 | Total loss:   95.11 | Recon loss:   75.59 | Gauss loss:    9.76
# Epoch   179 / 10000 | Total loss:    95.1 | Recon loss:   75.45 | Gauss loss:    9.83
# Epoch   180 / 10000 | Total loss:   94.75 | Recon loss:   75.22 | Gauss loss:    9.77
# Epoch   181 / 10000 | Total loss:   94.99 | Recon loss:    75.4 | Gauss loss:    9.79
# Epoch   182 / 10000 | Total loss:    94.0 | Recon loss:   74.38 | Gauss loss:    9.81
# Epoch   183 / 10000 | Total loss:   94.48 | Recon loss:   74.83 | Gauss loss:    9.83
# Epoch   184 / 10000 | Total loss:    94.9 | Recon loss:   75.17 | Gauss loss:    9.87
# Epoch   185 / 10000 | Total loss:   93.58 | Recon loss:   73.82 | Gauss loss:    9.88
# Epoch   186 / 10000 | Total loss:   93.66 | Recon loss:   74.01 | Gauss loss:    9.82
# Epoch   187 / 10000 | Total loss:   93.33 | Recon loss:   73.44 | Gauss loss:    9.95
# Epoch   188 / 10000 | Total loss:   93.67 | Recon loss:   74.07 | Gauss loss:     9.8
# Epoch   189 / 10000 | Total loss:   93.09 | Recon loss:   73.42 | Gauss loss:    9.83
# Epoch   190 / 10000 | Total loss:   92.29 | Recon loss:   72.44 | Gauss loss:    9.93
# Epoch   191 / 10000 | Total loss:   92.02 | Recon loss:    72.1 | Gauss loss:    9.96
# Epoch   192 / 10000 | Total loss:   92.18 | Recon loss:   72.28 | Gauss loss:    9.95
# Epoch   193 / 10000 | Total loss:   91.89 | Recon loss:    72.2 | Gauss loss:    9.84
# Epoch   194 / 10000 | Total loss:   92.68 | Recon loss:   72.63 | Gauss loss:   10.03
# Epoch   195 / 10000 | Total loss:   92.19 | Recon loss:    72.2 | Gauss loss:    10.0
# Epoch   196 / 10000 | Total loss:   91.65 | Recon loss:   71.64 | Gauss loss:    10.0
# Epoch   197 / 10000 | Total loss:   91.57 | Recon loss:   71.75 | Gauss loss:    9.91
# Epoch   198 / 10000 | Total loss:   90.96 | Recon loss:   70.92 | Gauss loss:   10.02
# Epoch   199 / 10000 | Total loss:   91.07 | Recon loss:   71.11 | Gauss loss:    9.98
# Epoch   200 / 10000 | Total loss:   90.53 | Recon loss:   70.59 | Gauss loss:    9.97
# Epoch   201 / 10000 | Total loss:   89.78 | Recon loss:   69.87 | Gauss loss:    9.95
# Epoch   202 / 10000 | Total loss:   90.87 | Recon loss:   70.73 | Gauss loss:   10.07
# Epoch   203 / 10000 | Total loss:   92.37 | Recon loss:   72.25 | Gauss loss:   10.06
# Epoch   204 / 10000 | Total loss:   91.64 | Recon loss:   71.61 | Gauss loss:   10.02
# Epoch   205 / 10000 | Total loss:   90.43 | Recon loss:   70.45 | Gauss loss:    9.99
# Epoch   206 / 10000 | Total loss:   89.66 | Recon loss:   69.45 | Gauss loss:    10.1
# Epoch   207 / 10000 | Total loss:   89.66 | Recon loss:   69.44 | Gauss loss:   10.11
# Epoch   208 / 10000 | Total loss:   88.55 | Recon loss:   68.38 | Gauss loss:   10.08
# Epoch   209 / 10000 | Total loss:   88.16 | Recon loss:   67.91 | Gauss loss:   10.13
# Epoch   210 / 10000 | Total loss:   88.23 | Recon loss:   67.92 | Gauss loss:   10.16
# Epoch   211 / 10000 | Total loss:   87.74 | Recon loss:   67.53 | Gauss loss:    10.1
# Epoch   212 / 10000 | Total loss:   88.31 | Recon loss:   68.14 | Gauss loss:   10.08
# Epoch   213 / 10000 | Total loss:   87.92 | Recon loss:   67.67 | Gauss loss:   10.12
# Epoch   214 / 10000 | Total loss:   88.99 | Recon loss:   68.63 | Gauss loss:   10.18
# Epoch   215 / 10000 | Total loss:   87.95 | Recon loss:   67.46 | Gauss loss:   10.24
# Epoch   216 / 10000 | Total loss:    86.3 | Recon loss:   66.09 | Gauss loss:    10.1
# Epoch   217 / 10000 | Total loss:    86.4 | Recon loss:   66.05 | Gauss loss:   10.18
# Epoch   218 / 10000 | Total loss:   85.97 | Recon loss:   65.67 | Gauss loss:   10.15
# Epoch   219 / 10000 | Total loss:   86.45 | Recon loss:   66.16 | Gauss loss:   10.15
# Epoch   220 / 10000 | Total loss:   86.15 | Recon loss:   65.64 | Gauss loss:   10.25
# Epoch   221 / 10000 | Total loss:   85.28 | Recon loss:   64.92 | Gauss loss:   10.18
# Epoch   222 / 10000 | Total loss:   85.29 | Recon loss:   64.79 | Gauss loss:   10.25
# Epoch   223 / 10000 | Total loss:   86.52 | Recon loss:   66.06 | Gauss loss:   10.23
# Epoch   224 / 10000 | Total loss:   86.23 | Recon loss:   65.95 | Gauss loss:   10.14
# Epoch   225 / 10000 | Total loss:   87.33 | Recon loss:   66.83 | Gauss loss:   10.25
# Epoch   226 / 10000 | Total loss:   86.86 | Recon loss:   66.37 | Gauss loss:   10.24
# Epoch   227 / 10000 | Total loss:   86.01 | Recon loss:   65.46 | Gauss loss:   10.27
# Epoch   228 / 10000 | Total loss:   84.73 | Recon loss:   64.31 | Gauss loss:   10.21
# Epoch   229 / 10000 | Total loss:   84.86 | Recon loss:   64.22 | Gauss loss:   10.32
# Epoch   230 / 10000 | Total loss:   84.74 | Recon loss:   63.91 | Gauss loss:   10.42
# Epoch   231 / 10000 | Total loss:   84.61 | Recon loss:   64.04 | Gauss loss:   10.29
# Epoch   232 / 10000 | Total loss:   83.84 | Recon loss:   63.35 | Gauss loss:   10.25
# Epoch   233 / 10000 | Total loss:   83.93 | Recon loss:   63.26 | Gauss loss:   10.33
# Epoch   234 / 10000 | Total loss:   84.64 | Recon loss:   64.13 | Gauss loss:   10.26
# Epoch   235 / 10000 | Total loss:   83.18 | Recon loss:   62.54 | Gauss loss:   10.32
# Epoch   236 / 10000 | Total loss:   83.92 | Recon loss:   63.25 | Gauss loss:   10.33
# Epoch   237 / 10000 | Total loss:   83.33 | Recon loss:   62.52 | Gauss loss:   10.41
# Epoch   238 / 10000 | Total loss:   82.91 | Recon loss:   62.31 | Gauss loss:    10.3
# Epoch   239 / 10000 | Total loss:   82.91 | Recon loss:   62.03 | Gauss loss:   10.44
# Epoch   240 / 10000 | Total loss:   84.05 | Recon loss:   63.29 | Gauss loss:   10.38
# Epoch   241 / 10000 | Total loss:   83.25 | Recon loss:   62.53 | Gauss loss:   10.36
# Epoch   242 / 10000 | Total loss:   82.53 | Recon loss:   61.72 | Gauss loss:    10.4
# Epoch   243 / 10000 | Total loss:   81.61 | Recon loss:   60.94 | Gauss loss:   10.34
# Epoch   244 / 10000 | Total loss:    81.7 | Recon loss:   60.85 | Gauss loss:   10.43
# Epoch   245 / 10000 | Total loss:   83.08 | Recon loss:   62.34 | Gauss loss:   10.37
# Epoch   246 / 10000 | Total loss:   82.09 | Recon loss:   61.33 | Gauss loss:   10.38
# Epoch   247 / 10000 | Total loss:   82.26 | Recon loss:    61.5 | Gauss loss:   10.38
# Epoch   248 / 10000 | Total loss:   81.83 | Recon loss:   61.06 | Gauss loss:   10.38
# Epoch   249 / 10000 | Total loss:    81.2 | Recon loss:    60.4 | Gauss loss:    10.4
# Epoch   250 / 10000 | Total loss:   81.26 | Recon loss:   60.42 | Gauss loss:   10.42
# Epoch   251 / 10000 | Total loss:   79.82 | Recon loss:   58.94 | Gauss loss:   10.44
# Epoch   252 / 10000 | Total loss:   80.56 | Recon loss:   59.51 | Gauss loss:   10.53
# Epoch   253 / 10000 | Total loss:   80.24 | Recon loss:   59.39 | Gauss loss:   10.43
# Epoch   254 / 10000 | Total loss:    80.0 | Recon loss:   59.11 | Gauss loss:   10.45
# Epoch   255 / 10000 | Total loss:   80.65 | Recon loss:   59.71 | Gauss loss:   10.47
# Epoch   256 / 10000 | Total loss:   79.21 | Recon loss:    58.2 | Gauss loss:    10.5
# Epoch   257 / 10000 | Total loss:   78.66 | Recon loss:   57.65 | Gauss loss:   10.51
# Epoch   258 / 10000 | Total loss:   79.59 | Recon loss:   58.65 | Gauss loss:   10.47
# Epoch   259 / 10000 | Total loss:   79.52 | Recon loss:   58.56 | Gauss loss:   10.48
# Epoch   260 / 10000 | Total loss:   81.72 | Recon loss:   60.84 | Gauss loss:   10.44
# Epoch   261 / 10000 | Total loss:   82.26 | Recon loss:   61.17 | Gauss loss:   10.54
# Epoch   262 / 10000 | Total loss:   80.01 | Recon loss:   58.91 | Gauss loss:   10.55
# Epoch   263 / 10000 | Total loss:   79.77 | Recon loss:   58.57 | Gauss loss:    10.6
# Epoch   264 / 10000 | Total loss:   78.51 | Recon loss:    57.4 | Gauss loss:   10.55
# Epoch   265 / 10000 | Total loss:   78.77 | Recon loss:   57.76 | Gauss loss:    10.5
# Epoch   266 / 10000 | Total loss:    78.6 | Recon loss:   57.57 | Gauss loss:   10.51
# Epoch   267 / 10000 | Total loss:   80.06 | Recon loss:   58.91 | Gauss loss:   10.57
# Epoch   268 / 10000 | Total loss:   78.79 | Recon loss:   57.66 | Gauss loss:   10.56
# Epoch   269 / 10000 | Total loss:   78.47 | Recon loss:   57.45 | Gauss loss:   10.51
# Epoch   270 / 10000 | Total loss:   78.78 | Recon loss:   57.56 | Gauss loss:   10.61
# Epoch   271 / 10000 | Total loss:   77.84 | Recon loss:   56.75 | Gauss loss:   10.54
# Epoch   272 / 10000 | Total loss:   76.97 | Recon loss:   55.84 | Gauss loss:   10.56
# Epoch   273 / 10000 | Total loss:   77.04 | Recon loss:   55.91 | Gauss loss:   10.57
# Epoch   274 / 10000 | Total loss:   76.99 | Recon loss:   55.88 | Gauss loss:   10.55
# Epoch   275 / 10000 | Total loss:   75.42 | Recon loss:   54.48 | Gauss loss:   10.47
# Epoch   276 / 10000 | Total loss:   76.96 | Recon loss:   55.81 | Gauss loss:   10.58
# Epoch   277 / 10000 | Total loss:   76.46 | Recon loss:   55.29 | Gauss loss:   10.59
# Epoch   278 / 10000 | Total loss:   76.23 | Recon loss:   55.12 | Gauss loss:   10.55
# Epoch   279 / 10000 | Total loss:   76.52 | Recon loss:   55.13 | Gauss loss:   10.69
# Epoch   280 / 10000 | Total loss:   77.49 | Recon loss:   55.96 | Gauss loss:   10.76
# Epoch   281 / 10000 | Total loss:   79.22 | Recon loss:   57.84 | Gauss loss:   10.69
# Epoch   282 / 10000 | Total loss:   78.08 | Recon loss:   56.84 | Gauss loss:   10.62
# Epoch   283 / 10000 | Total loss:   77.49 | Recon loss:   56.27 | Gauss loss:   10.61
# Epoch   284 / 10000 | Total loss:   75.82 | Recon loss:    54.6 | Gauss loss:   10.61
# Epoch   285 / 10000 | Total loss:    75.9 | Recon loss:   54.61 | Gauss loss:   10.65
# Epoch   286 / 10000 | Total loss:   74.78 | Recon loss:   53.53 | Gauss loss:   10.62
# Epoch   287 / 10000 | Total loss:   74.17 | Recon loss:   52.82 | Gauss loss:   10.68
# Epoch   288 / 10000 | Total loss:   74.49 | Recon loss:   53.21 | Gauss loss:   10.64
# Epoch   289 / 10000 | Total loss:   74.38 | Recon loss:   53.03 | Gauss loss:   10.67
# Epoch   290 / 10000 | Total loss:   75.08 | Recon loss:   53.83 | Gauss loss:   10.62
# Epoch   291 / 10000 | Total loss:   75.91 | Recon loss:   54.42 | Gauss loss:   10.74
# Epoch   292 / 10000 | Total loss:   74.49 | Recon loss:   53.04 | Gauss loss:   10.72
# Epoch   293 / 10000 | Total loss:   73.37 | Recon loss:   52.07 | Gauss loss:   10.65
# Epoch   294 / 10000 | Total loss:   74.17 | Recon loss:   52.77 | Gauss loss:    10.7
# Epoch   295 / 10000 | Total loss:   75.06 | Recon loss:   53.74 | Gauss loss:   10.66
# Epoch   296 / 10000 | Total loss:   74.36 | Recon loss:   52.84 | Gauss loss:   10.76
# Epoch   297 / 10000 | Total loss:   74.07 | Recon loss:   52.57 | Gauss loss:   10.75
# Epoch   298 / 10000 | Total loss:   75.07 | Recon loss:   53.37 | Gauss loss:   10.85
# Epoch   299 / 10000 | Total loss:   75.59 | Recon loss:   54.27 | Gauss loss:   10.66
# Epoch   300 / 10000 | Total loss:   75.58 | Recon loss:   54.11 | Gauss loss:   10.73
# Epoch   301 / 10000 | Total loss:   74.73 | Recon loss:   53.08 | Gauss loss:   10.83
# Epoch   302 / 10000 | Total loss:   73.77 | Recon loss:   52.21 | Gauss loss:   10.78
# Epoch   303 / 10000 | Total loss:   73.24 | Recon loss:   51.56 | Gauss loss:   10.84
# Epoch   304 / 10000 | Total loss:    73.3 | Recon loss:   51.81 | Gauss loss:   10.74
# Epoch   305 / 10000 | Total loss:   73.71 | Recon loss:   52.01 | Gauss loss:   10.85
# Epoch   306 / 10000 | Total loss:   73.58 | Recon loss:   52.09 | Gauss loss:   10.75
# Epoch   307 / 10000 | Total loss:   72.51 | Recon loss:   51.02 | Gauss loss:   10.74
# Epoch   308 / 10000 | Total loss:   73.48 | Recon loss:   51.86 | Gauss loss:   10.81
# Epoch   309 / 10000 | Total loss:   73.06 | Recon loss:   51.57 | Gauss loss:   10.74
# Epoch   310 / 10000 | Total loss:   73.58 | Recon loss:    52.0 | Gauss loss:   10.79
# Epoch   311 / 10000 | Total loss:   73.05 | Recon loss:   51.41 | Gauss loss:   10.82
# Epoch   312 / 10000 | Total loss:   74.45 | Recon loss:   52.87 | Gauss loss:   10.79
# Epoch   313 / 10000 | Total loss:   74.22 | Recon loss:   52.52 | Gauss loss:   10.85
# Epoch   314 / 10000 | Total loss:   72.87 | Recon loss:   51.36 | Gauss loss:   10.76
# Epoch   315 / 10000 | Total loss:   70.91 | Recon loss:   49.34 | Gauss loss:   10.78
# Epoch   316 / 10000 | Total loss:   70.75 | Recon loss:   49.12 | Gauss loss:   10.82
# Epoch   317 / 10000 | Total loss:   70.63 | Recon loss:   49.07 | Gauss loss:   10.78
# Epoch   318 / 10000 | Total loss:   69.96 | Recon loss:    48.3 | Gauss loss:   10.83
# Epoch   319 / 10000 | Total loss:   71.68 | Recon loss:   50.05 | Gauss loss:   10.82
# Epoch   320 / 10000 | Total loss:   72.86 | Recon loss:   51.21 | Gauss loss:   10.83
# Epoch   321 / 10000 | Total loss:   72.68 | Recon loss:   50.98 | Gauss loss:   10.85
# Epoch   322 / 10000 | Total loss:   73.54 | Recon loss:    51.8 | Gauss loss:   10.87
# Epoch   323 / 10000 | Total loss:   71.46 | Recon loss:   49.84 | Gauss loss:   10.81
# Epoch   324 / 10000 | Total loss:   71.28 | Recon loss:   49.51 | Gauss loss:   10.89
# Epoch   325 / 10000 | Total loss:   70.76 | Recon loss:   49.08 | Gauss loss:   10.84
# Epoch   326 / 10000 | Total loss:   71.22 | Recon loss:   49.28 | Gauss loss:   10.97
# Epoch   327 / 10000 | Total loss:   70.17 | Recon loss:   48.48 | Gauss loss:   10.84
# Epoch   328 / 10000 | Total loss:   70.14 | Recon loss:   48.37 | Gauss loss:   10.88
# Epoch   329 / 10000 | Total loss:   70.04 | Recon loss:    48.4 | Gauss loss:   10.82
# Epoch   330 / 10000 | Total loss:   70.68 | Recon loss:   48.85 | Gauss loss:   10.92
# Epoch   331 / 10000 | Total loss:   70.77 | Recon loss:   49.01 | Gauss loss:   10.88
# Epoch   332 / 10000 | Total loss:   69.12 | Recon loss:   47.36 | Gauss loss:   10.88
# Epoch   333 / 10000 | Total loss:   69.04 | Recon loss:   47.37 | Gauss loss:   10.83
# Epoch   334 / 10000 | Total loss:   68.44 | Recon loss:    46.7 | Gauss loss:   10.87
# Epoch   335 / 10000 | Total loss:   69.16 | Recon loss:   47.55 | Gauss loss:    10.8
# Epoch   336 / 10000 | Total loss:   68.72 | Recon loss:   46.81 | Gauss loss:   10.96
# Epoch   337 / 10000 | Total loss:   69.31 | Recon loss:    47.5 | Gauss loss:   10.91
# Epoch   338 / 10000 | Total loss:   69.52 | Recon loss:   47.65 | Gauss loss:   10.93
# Epoch   339 / 10000 | Total loss:   69.69 | Recon loss:   47.73 | Gauss loss:   10.98
# Epoch   340 / 10000 | Total loss:   69.45 | Recon loss:   47.65 | Gauss loss:    10.9
# Epoch   341 / 10000 | Total loss:   67.77 | Recon loss:   46.01 | Gauss loss:   10.88
# Epoch   342 / 10000 | Total loss:   67.69 | Recon loss:    45.9 | Gauss loss:   10.89
# Epoch   343 / 10000 | Total loss:   69.01 | Recon loss:   47.05 | Gauss loss:   10.98
# Epoch   344 / 10000 | Total loss:   69.71 | Recon loss:   47.77 | Gauss loss:   10.97
# Epoch   345 / 10000 | Total loss:   71.51 | Recon loss:   49.56 | Gauss loss:   10.97
# Epoch   346 / 10000 | Total loss:   69.78 | Recon loss:   47.74 | Gauss loss:   11.02
# Epoch   347 / 10000 | Total loss:   69.22 | Recon loss:   47.29 | Gauss loss:   10.97
# Epoch   348 / 10000 | Total loss:   69.96 | Recon loss:   47.92 | Gauss loss:   11.02
# Epoch   349 / 10000 | Total loss:    69.5 | Recon loss:   47.57 | Gauss loss:   10.96
# Epoch   350 / 10000 | Total loss:    68.6 | Recon loss:   46.69 | Gauss loss:   10.96
# Epoch   351 / 10000 | Total loss:   68.19 | Recon loss:    46.3 | Gauss loss:   10.94
# Epoch   352 / 10000 | Total loss:   69.22 | Recon loss:   47.38 | Gauss loss:   10.92
# Epoch   353 / 10000 | Total loss:   68.57 | Recon loss:   46.46 | Gauss loss:   11.06
# Epoch   354 / 10000 | Total loss:   68.92 | Recon loss:   46.91 | Gauss loss:   11.01
# Epoch   355 / 10000 | Total loss:   67.44 | Recon loss:   45.36 | Gauss loss:   11.04
# Epoch   356 / 10000 | Total loss:   67.02 | Recon loss:   45.09 | Gauss loss:   10.96
# Epoch   357 / 10000 | Total loss:   66.94 | Recon loss:   44.98 | Gauss loss:   10.98
# Epoch   358 / 10000 | Total loss:   65.59 | Recon loss:   43.52 | Gauss loss:   11.03
# Epoch   359 / 10000 | Total loss:   67.54 | Recon loss:   45.41 | Gauss loss:   11.07
# Epoch   360 / 10000 | Total loss:   68.08 | Recon loss:   46.14 | Gauss loss:   10.97
# Epoch   361 / 10000 | Total loss:   67.46 | Recon loss:   45.47 | Gauss loss:    11.0
# Epoch   362 / 10000 | Total loss:   69.07 | Recon loss:   46.98 | Gauss loss:   11.04
# Epoch   363 / 10000 | Total loss:    66.9 | Recon loss:   45.03 | Gauss loss:   10.94
# Epoch   364 / 10000 | Total loss:    67.1 | Recon loss:   45.07 | Gauss loss:   11.02
# Epoch   365 / 10000 | Total loss:   67.17 | Recon loss:   45.17 | Gauss loss:    11.0
# Epoch   366 / 10000 | Total loss:   67.14 | Recon loss:   44.99 | Gauss loss:   11.08
# Epoch   367 / 10000 | Total loss:   65.97 | Recon loss:   44.05 | Gauss loss:   10.96
# Epoch   368 / 10000 | Total loss:    66.9 | Recon loss:   44.71 | Gauss loss:   11.09
# Epoch   369 / 10000 | Total loss:   67.47 | Recon loss:   45.44 | Gauss loss:   11.01
# Epoch   370 / 10000 | Total loss:   65.77 | Recon loss:    43.8 | Gauss loss:   10.99
# Epoch   371 / 10000 | Total loss:    66.4 | Recon loss:   44.25 | Gauss loss:   11.07
# Epoch   372 / 10000 | Total loss:   66.43 | Recon loss:   44.42 | Gauss loss:    11.0
# Epoch   373 / 10000 | Total loss:   67.04 | Recon loss:   44.98 | Gauss loss:   11.03
# Epoch   374 / 10000 | Total loss:   67.46 | Recon loss:   45.33 | Gauss loss:   11.07
# Epoch   375 / 10000 | Total loss:   66.23 | Recon loss:   44.09 | Gauss loss:   11.07
# Epoch   376 / 10000 | Total loss:   67.26 | Recon loss:   45.06 | Gauss loss:    11.1
# Epoch   377 / 10000 | Total loss:   66.34 | Recon loss:   44.24 | Gauss loss:   11.05
# Epoch   378 / 10000 | Total loss:   65.12 | Recon loss:   43.12 | Gauss loss:    11.0
# Epoch   379 / 10000 | Total loss:   66.27 | Recon loss:   44.14 | Gauss loss:   11.07
# Epoch   380 / 10000 | Total loss:   68.42 | Recon loss:    46.2 | Gauss loss:   11.11
# Epoch   381 / 10000 | Total loss:   67.57 | Recon loss:   45.41 | Gauss loss:   11.08
# Epoch   382 / 10000 | Total loss:   68.21 | Recon loss:    46.0 | Gauss loss:    11.1
# Epoch   383 / 10000 | Total loss:   66.26 | Recon loss:   44.12 | Gauss loss:   11.07
# Epoch   384 / 10000 | Total loss:   65.16 | Recon loss:   43.04 | Gauss loss:   11.06
# Epoch   385 / 10000 | Total loss:   66.48 | Recon loss:   44.34 | Gauss loss:   11.07
# Epoch   386 / 10000 | Total loss:    64.0 | Recon loss:   41.85 | Gauss loss:   11.07
# Epoch   387 / 10000 | Total loss:   63.63 | Recon loss:   41.47 | Gauss loss:   11.08
# Epoch   388 / 10000 | Total loss:   63.33 | Recon loss:   41.23 | Gauss loss:   11.05
# Epoch   389 / 10000 | Total loss:   64.34 | Recon loss:   42.13 | Gauss loss:   11.11
# Epoch   390 / 10000 | Total loss:   63.77 | Recon loss:   41.77 | Gauss loss:    11.0
# Epoch   391 / 10000 | Total loss:   64.56 | Recon loss:    42.3 | Gauss loss:   11.13
# Epoch   392 / 10000 | Total loss:   63.84 | Recon loss:   41.67 | Gauss loss:   11.09
# Epoch   393 / 10000 | Total loss:   62.51 | Recon loss:   40.51 | Gauss loss:    11.0
# Epoch   394 / 10000 | Total loss:   62.56 | Recon loss:   40.37 | Gauss loss:    11.1
# Epoch   395 / 10000 | Total loss:   61.89 | Recon loss:   39.74 | Gauss loss:   11.08
# Epoch   396 / 10000 | Total loss:   64.21 | Recon loss:   42.07 | Gauss loss:   11.07
# Epoch   397 / 10000 | Total loss:   65.85 | Recon loss:   43.69 | Gauss loss:   11.08
# Epoch   398 / 10000 | Total loss:    64.6 | Recon loss:   42.24 | Gauss loss:   11.18
# Epoch   399 / 10000 | Total loss:   65.23 | Recon loss:   42.86 | Gauss loss:   11.19
# Epoch   400 / 10000 | Total loss:   66.31 | Recon loss:   43.87 | Gauss loss:   11.22
# Epoch   401 / 10000 | Total loss:   67.92 | Recon loss:   45.65 | Gauss loss:   11.14
# Epoch   402 / 10000 | Total loss:   69.49 | Recon loss:   46.77 | Gauss loss:   11.36
# Epoch   403 / 10000 | Total loss:   65.38 | Recon loss:   43.13 | Gauss loss:   11.13
# Epoch   404 / 10000 | Total loss:   65.51 | Recon loss:   43.12 | Gauss loss:   11.19
# Epoch   405 / 10000 | Total loss:   66.65 | Recon loss:    44.4 | Gauss loss:   11.12
# Epoch   406 / 10000 | Total loss:    67.0 | Recon loss:   44.59 | Gauss loss:    11.2
# Epoch   407 / 10000 | Total loss:   64.65 | Recon loss:   42.04 | Gauss loss:    11.3
# Epoch   408 / 10000 | Total loss:    63.1 | Recon loss:   40.77 | Gauss loss:   11.17
# Epoch   409 / 10000 | Total loss:   61.08 | Recon loss:   39.03 | Gauss loss:   11.02
# Epoch   410 / 10000 | Total loss:   60.78 | Recon loss:   38.65 | Gauss loss:   11.07
# Epoch   411 / 10000 | Total loss:   59.67 | Recon loss:   37.63 | Gauss loss:   11.02
# Epoch   412 / 10000 | Total loss:   60.55 | Recon loss:   38.43 | Gauss loss:   11.06
# Epoch   413 / 10000 | Total loss:   61.83 | Recon loss:    39.5 | Gauss loss:   11.17
# Epoch   414 / 10000 | Total loss:   62.04 | Recon loss:   39.55 | Gauss loss:   11.25
# Epoch   415 / 10000 | Total loss:   61.38 | Recon loss:   39.24 | Gauss loss:   11.07
# Epoch   416 / 10000 | Total loss:   60.59 | Recon loss:   38.16 | Gauss loss:   11.22
# Epoch   417 / 10000 | Total loss:    60.9 | Recon loss:    38.8 | Gauss loss:   11.05
# Epoch   418 / 10000 | Total loss:   62.02 | Recon loss:   39.48 | Gauss loss:   11.27
# Epoch   419 / 10000 | Total loss:    62.3 | Recon loss:   40.03 | Gauss loss:   11.13
# Epoch   420 / 10000 | Total loss:   60.69 | Recon loss:   38.64 | Gauss loss:   11.03
# Epoch   421 / 10000 | Total loss:   60.16 | Recon loss:   38.09 | Gauss loss:   11.03
# Epoch   422 / 10000 | Total loss:   59.81 | Recon loss:   37.43 | Gauss loss:   11.19
# Epoch   423 / 10000 | Total loss:    60.8 | Recon loss:   38.37 | Gauss loss:   11.22
# Epoch   424 / 10000 | Total loss:   61.37 | Recon loss:   38.95 | Gauss loss:   11.21
# Epoch   425 / 10000 | Total loss:   60.64 | Recon loss:   38.27 | Gauss loss:   11.19
# Epoch   426 / 10000 | Total loss:   60.29 | Recon loss:   38.15 | Gauss loss:   11.07
# Epoch   427 / 10000 | Total loss:   59.45 | Recon loss:   37.29 | Gauss loss:   11.08
# Epoch   428 / 10000 | Total loss:   60.59 | Recon loss:   38.24 | Gauss loss:   11.17
# Epoch   429 / 10000 | Total loss:   61.61 | Recon loss:   39.11 | Gauss loss:   11.25
# Epoch   430 / 10000 | Total loss:   61.61 | Recon loss:   39.15 | Gauss loss:   11.23
# Epoch   431 / 10000 | Total loss:   63.63 | Recon loss:   41.19 | Gauss loss:   11.22
# Epoch   432 / 10000 | Total loss:    64.1 | Recon loss:   41.47 | Gauss loss:   11.31
# Epoch   433 / 10000 | Total loss:   63.13 | Recon loss:   40.53 | Gauss loss:    11.3
# Epoch   434 / 10000 | Total loss:   62.51 | Recon loss:   40.29 | Gauss loss:   11.11
# Epoch   435 / 10000 | Total loss:   65.38 | Recon loss:   42.92 | Gauss loss:   11.23
# Epoch   436 / 10000 | Total loss:   64.04 | Recon loss:   41.61 | Gauss loss:   11.22
# Epoch   437 / 10000 | Total loss:   62.34 | Recon loss:    39.7 | Gauss loss:   11.32
# Epoch   438 / 10000 | Total loss:   60.94 | Recon loss:   38.33 | Gauss loss:    11.3
# Epoch   439 / 10000 | Total loss:   59.61 | Recon loss:   37.38 | Gauss loss:   11.12
# Epoch   440 / 10000 | Total loss:   58.88 | Recon loss:   36.43 | Gauss loss:   11.22
# Epoch   441 / 10000 | Total loss:   59.32 | Recon loss:   37.08 | Gauss loss:   11.12
# Epoch   442 / 10000 | Total loss:   61.82 | Recon loss:   39.47 | Gauss loss:   11.17
# Epoch   443 / 10000 | Total loss:   61.35 | Recon loss:   38.76 | Gauss loss:    11.3
# Epoch   444 / 10000 | Total loss:    59.7 | Recon loss:   37.52 | Gauss loss:   11.09
# Epoch   445 / 10000 | Total loss:   59.82 | Recon loss:   37.23 | Gauss loss:   11.29
# Epoch   446 / 10000 | Total loss:   58.58 | Recon loss:   36.15 | Gauss loss:   11.21
# Epoch   447 / 10000 | Total loss:   60.62 | Recon loss:   38.27 | Gauss loss:   11.17
# Epoch   448 / 10000 | Total loss:   60.68 | Recon loss:   38.26 | Gauss loss:   11.21
# Epoch   449 / 10000 | Total loss:   58.99 | Recon loss:   36.52 | Gauss loss:   11.23
# Epoch   450 / 10000 | Total loss:   59.59 | Recon loss:   37.16 | Gauss loss:   11.22
# Epoch   451 / 10000 | Total loss:   60.78 | Recon loss:   38.26 | Gauss loss:   11.26
# Epoch   452 / 10000 | Total loss:   61.35 | Recon loss:   38.66 | Gauss loss:   11.34
# Epoch   453 / 10000 | Total loss:   59.56 | Recon loss:   37.27 | Gauss loss:   11.14
# Epoch   454 / 10000 | Total loss:   61.33 | Recon loss:   38.77 | Gauss loss:   11.28
# Epoch   455 / 10000 | Total loss:   60.27 | Recon loss:    37.6 | Gauss loss:   11.34
# Epoch   456 / 10000 | Total loss:   59.23 | Recon loss:   36.84 | Gauss loss:    11.2
# Epoch   457 / 10000 | Total loss:   58.85 | Recon loss:   36.48 | Gauss loss:   11.19
# Epoch   458 / 10000 | Total loss:   57.67 | Recon loss:   35.29 | Gauss loss:   11.19
# Epoch   459 / 10000 | Total loss:   58.94 | Recon loss:   36.51 | Gauss loss:   11.22
# Epoch   460 / 10000 | Total loss:   59.19 | Recon loss:   36.69 | Gauss loss:   11.25
# Epoch   461 / 10000 | Total loss:   58.46 | Recon loss:   35.84 | Gauss loss:   11.31
# Epoch   462 / 10000 | Total loss:    57.1 | Recon loss:   34.69 | Gauss loss:   11.21
# Epoch   463 / 10000 | Total loss:   57.99 | Recon loss:   35.56 | Gauss loss:   11.22
# Epoch   464 / 10000 | Total loss:    59.0 | Recon loss:   36.47 | Gauss loss:   11.27
# Epoch   465 / 10000 | Total loss:    60.3 | Recon loss:    37.5 | Gauss loss:    11.4
# Epoch   466 / 10000 | Total loss:   60.33 | Recon loss:   37.64 | Gauss loss:   11.35
# Epoch   467 / 10000 | Total loss:   58.88 | Recon loss:   36.41 | Gauss loss:   11.24
# Epoch   468 / 10000 | Total loss:   57.72 | Recon loss:   35.18 | Gauss loss:   11.27
# Epoch   469 / 10000 | Total loss:   56.93 | Recon loss:   34.43 | Gauss loss:   11.25
# Epoch   470 / 10000 | Total loss:   57.04 | Recon loss:    34.8 | Gauss loss:   11.12
# Epoch   471 / 10000 | Total loss:    58.4 | Recon loss:   35.82 | Gauss loss:   11.29
# Epoch   472 / 10000 | Total loss:   59.67 | Recon loss:   37.23 | Gauss loss:   11.22
# Epoch   473 / 10000 | Total loss:   59.71 | Recon loss:    36.9 | Gauss loss:   11.41
# Epoch   474 / 10000 | Total loss:   58.59 | Recon loss:   35.97 | Gauss loss:   11.31
# Epoch   475 / 10000 | Total loss:   59.02 | Recon loss:   36.25 | Gauss loss:   11.39
# Epoch   476 / 10000 | Total loss:   60.45 | Recon loss:   37.66 | Gauss loss:   11.39
# Epoch   477 / 10000 | Total loss:   58.86 | Recon loss:    36.3 | Gauss loss:   11.28
# Epoch   478 / 10000 | Total loss:   59.24 | Recon loss:   36.81 | Gauss loss:   11.22
# Epoch   479 / 10000 | Total loss:   61.65 | Recon loss:   38.79 | Gauss loss:   11.43
# Epoch   480 / 10000 | Total loss:    63.2 | Recon loss:   40.32 | Gauss loss:   11.44
# Epoch   481 / 10000 | Total loss:   64.41 | Recon loss:    41.5 | Gauss loss:   11.45
# Epoch   482 / 10000 | Total loss:    64.1 | Recon loss:   41.22 | Gauss loss:   11.44
# Epoch   483 / 10000 | Total loss:   62.38 | Recon loss:   39.52 | Gauss loss:   11.43
# Epoch   484 / 10000 | Total loss:   60.56 | Recon loss:   37.78 | Gauss loss:   11.39
# Epoch   485 / 10000 | Total loss:   61.01 | Recon loss:   38.19 | Gauss loss:   11.41
# Epoch   486 / 10000 | Total loss:   60.38 | Recon loss:   37.64 | Gauss loss:   11.37
# Epoch   487 / 10000 | Total loss:   58.51 | Recon loss:   35.95 | Gauss loss:   11.28
# Epoch   488 / 10000 | Total loss:   56.17 | Recon loss:   33.47 | Gauss loss:   11.35
# Epoch   489 / 10000 | Total loss:    54.3 | Recon loss:   31.88 | Gauss loss:   11.21
# Epoch   490 / 10000 | Total loss:    54.9 | Recon loss:    32.4 | Gauss loss:   11.25
# Epoch   491 / 10000 | Total loss:   54.99 | Recon loss:   32.47 | Gauss loss:   11.26
# Epoch   492 / 10000 | Total loss:   54.91 | Recon loss:   32.24 | Gauss loss:   11.33
# Epoch   493 / 10000 | Total loss:   55.72 | Recon loss:   33.02 | Gauss loss:   11.35
# Epoch   494 / 10000 | Total loss:   54.82 | Recon loss:    32.3 | Gauss loss:   11.26
# Epoch   495 / 10000 | Total loss:   55.02 | Recon loss:   32.53 | Gauss loss:   11.25
# Epoch   496 / 10000 | Total loss:   55.53 | Recon loss:   33.09 | Gauss loss:   11.22
# Epoch   497 / 10000 | Total loss:   55.43 | Recon loss:   32.82 | Gauss loss:   11.31
# Epoch   498 / 10000 | Total loss:   55.78 | Recon loss:   33.25 | Gauss loss:   11.27
# Epoch   499 / 10000 | Total loss:   56.01 | Recon loss:   33.53 | Gauss loss:   11.24
# Epoch   500 / 10000 | Total loss:   54.41 | Recon loss:   31.82 | Gauss loss:   11.29
# Epoch   501 / 10000 | Total loss:   55.29 | Recon loss:    32.7 | Gauss loss:    11.3
# Epoch   502 / 10000 | Total loss:   56.14 | Recon loss:    33.4 | Gauss loss:   11.37
# Epoch   503 / 10000 | Total loss:   57.51 | Recon loss:   34.75 | Gauss loss:   11.38
# Epoch   504 / 10000 | Total loss:   59.22 | Recon loss:   36.23 | Gauss loss:   11.49
# Epoch   505 / 10000 | Total loss:   60.93 | Recon loss:   37.86 | Gauss loss:   11.54
# Epoch   506 / 10000 | Total loss:   62.97 | Recon loss:   39.91 | Gauss loss:   11.53
# Epoch   507 / 10000 | Total loss:   61.68 | Recon loss:   38.84 | Gauss loss:   11.42
# Epoch   508 / 10000 | Total loss:    61.5 | Recon loss:   38.68 | Gauss loss:   11.41
# Epoch   509 / 10000 | Total loss:    61.4 | Recon loss:   38.52 | Gauss loss:   11.44
# Epoch   510 / 10000 | Total loss:   58.43 | Recon loss:   35.51 | Gauss loss:   11.46
# Epoch   511 / 10000 | Total loss:   56.12 | Recon loss:   33.42 | Gauss loss:   11.35
# Epoch   512 / 10000 | Total loss:   55.97 | Recon loss:   33.24 | Gauss loss:   11.37
# Epoch   513 / 10000 | Total loss:   54.79 | Recon loss:   32.13 | Gauss loss:   11.33
# Epoch   514 / 10000 | Total loss:   53.78 | Recon loss:   31.25 | Gauss loss:   11.26
# Epoch   515 / 10000 | Total loss:   54.51 | Recon loss:   31.78 | Gauss loss:   11.37
# Epoch   516 / 10000 | Total loss:   54.02 | Recon loss:   31.62 | Gauss loss:    11.2
# Epoch   517 / 10000 | Total loss:   54.31 | Recon loss:    31.9 | Gauss loss:   11.21
# Epoch   518 / 10000 | Total loss:   56.43 | Recon loss:   33.61 | Gauss loss:   11.41
# Epoch   519 / 10000 | Total loss:   57.58 | Recon loss:   34.73 | Gauss loss:   11.43
# Epoch   520 / 10000 | Total loss:   56.16 | Recon loss:   33.53 | Gauss loss:   11.32
# Epoch   521 / 10000 | Total loss:   55.57 | Recon loss:   32.86 | Gauss loss:   11.35
# Epoch   522 / 10000 | Total loss:    56.8 | Recon loss:   34.09 | Gauss loss:   11.36
# Epoch   523 / 10000 | Total loss:    55.3 | Recon loss:   32.78 | Gauss loss:   11.26
# Epoch   524 / 10000 | Total loss:    55.5 | Recon loss:   32.71 | Gauss loss:    11.4
# Epoch   525 / 10000 | Total loss:   55.32 | Recon loss:   32.48 | Gauss loss:   11.42
# Epoch   526 / 10000 | Total loss:   55.58 | Recon loss:   32.86 | Gauss loss:   11.36
# Epoch   527 / 10000 | Total loss:   54.86 | Recon loss:   32.28 | Gauss loss:   11.29
# Epoch   528 / 10000 | Total loss:   54.44 | Recon loss:   31.85 | Gauss loss:    11.3
# Epoch   529 / 10000 | Total loss:    53.7 | Recon loss:   31.09 | Gauss loss:   11.31
# Epoch   530 / 10000 | Total loss:   53.55 | Recon loss:   30.81 | Gauss loss:   11.37
# Epoch   531 / 10000 | Total loss:   52.43 | Recon loss:   29.85 | Gauss loss:   11.29
# Epoch   532 / 10000 | Total loss:    54.1 | Recon loss:   31.38 | Gauss loss:   11.36
# Epoch   533 / 10000 | Total loss:   54.03 | Recon loss:   31.43 | Gauss loss:    11.3
# Epoch   534 / 10000 | Total loss:   55.61 | Recon loss:   32.84 | Gauss loss:   11.38
# Epoch   535 / 10000 | Total loss:   58.83 | Recon loss:   35.77 | Gauss loss:   11.53
# Epoch   536 / 10000 | Total loss:    60.6 | Recon loss:   37.47 | Gauss loss:   11.57
# Epoch   537 / 10000 | Total loss:    63.5 | Recon loss:   40.09 | Gauss loss:    11.7
# Epoch   538 / 10000 | Total loss:   59.24 | Recon loss:   36.22 | Gauss loss:   11.51
# Epoch   539 / 10000 | Total loss:   56.36 | Recon loss:   33.53 | Gauss loss:   11.41
# Epoch   540 / 10000 | Total loss:    54.0 | Recon loss:    31.2 | Gauss loss:    11.4
# Epoch   541 / 10000 | Total loss:   54.69 | Recon loss:   31.82 | Gauss loss:   11.44
# Epoch   542 / 10000 | Total loss:    55.9 | Recon loss:   33.26 | Gauss loss:   11.32
# Epoch   543 / 10000 | Total loss:   53.58 | Recon loss:   31.01 | Gauss loss:   11.28
# Epoch   544 / 10000 | Total loss:   52.32 | Recon loss:   29.63 | Gauss loss:   11.35
# Epoch   545 / 10000 | Total loss:   51.62 | Recon loss:   28.92 | Gauss loss:   11.35
# Epoch   546 / 10000 | Total loss:    51.4 | Recon loss:   28.82 | Gauss loss:   11.29
# Epoch   547 / 10000 | Total loss:   51.32 | Recon loss:    28.7 | Gauss loss:   11.31
# Epoch   548 / 10000 | Total loss:   52.18 | Recon loss:   29.47 | Gauss loss:   11.35
# Epoch   549 / 10000 | Total loss:   53.62 | Recon loss:   30.79 | Gauss loss:   11.41
# Epoch   550 / 10000 | Total loss:    56.1 | Recon loss:   33.08 | Gauss loss:   11.51
# Epoch   551 / 10000 | Total loss:   56.73 | Recon loss:    33.9 | Gauss loss:   11.42
# Epoch   552 / 10000 | Total loss:   54.94 | Recon loss:   32.22 | Gauss loss:   11.36
# Epoch   553 / 10000 | Total loss:   54.82 | Recon loss:   31.96 | Gauss loss:   11.43
# Epoch   554 / 10000 | Total loss:   56.64 | Recon loss:   33.67 | Gauss loss:   11.48
# Epoch   555 / 10000 | Total loss:   56.58 | Recon loss:   33.66 | Gauss loss:   11.46
# Epoch   556 / 10000 | Total loss:   54.98 | Recon loss:   32.04 | Gauss loss:   11.47
# Epoch   557 / 10000 | Total loss:   53.71 | Recon loss:   30.84 | Gauss loss:   11.44
# Epoch   558 / 10000 | Total loss:   53.16 | Recon loss:   30.47 | Gauss loss:   11.34
# ...
# Epoch  9815 / 10000 | Total loss:   29.19 | Recon loss:    5.44 | Gauss loss:   11.88
# Epoch  9816 / 10000 | Total loss:   28.11 | Recon loss:    4.68 | Gauss loss:   11.72
# Epoch  9817 / 10000 | Total loss:   27.51 | Recon loss:    4.04 | Gauss loss:   11.74
# Epoch  9818 / 10000 | Total loss:    27.0 | Recon loss:    4.15 | Gauss loss:   11.43
# Epoch  9819 / 10000 | Total loss:   30.45 | Recon loss:    7.11 | Gauss loss:   11.67
# Epoch  9820 / 10000 | Total loss:   31.98 | Recon loss:    8.15 | Gauss loss:   11.92
# Epoch  9821 / 10000 | Total loss:   41.64 | Recon loss:   16.86 | Gauss loss:   12.39
# Epoch  9822 / 10000 | Total loss:   47.38 | Recon loss:   21.93 | Gauss loss:   12.73
# Epoch  9823 / 10000 | Total loss:   39.44 | Recon loss:   13.84 | Gauss loss:    12.8
# Epoch  9824 / 10000 | Total loss:   33.19 | Recon loss:    8.23 | Gauss loss:   12.48
# Epoch  9825 / 10000 | Total loss:   28.45 | Recon loss:    4.26 | Gauss loss:    12.1
# Epoch  9826 / 10000 | Total loss:   26.85 | Recon loss:    3.32 | Gauss loss:   11.76
# Epoch  9827 / 10000 | Total loss:   26.21 | Recon loss:    3.02 | Gauss loss:   11.59
# Epoch  9828 / 10000 | Total loss:   26.14 | Recon loss:    3.16 | Gauss loss:   11.49
# Epoch  9829 / 10000 | Total loss:   29.23 | Recon loss:    5.82 | Gauss loss:   11.71
# Epoch  9830 / 10000 | Total loss:    27.8 | Recon loss:    4.24 | Gauss loss:   11.78
# Epoch  9831 / 10000 | Total loss:   26.14 | Recon loss:     3.0 | Gauss loss:   11.57
# Epoch  9832 / 10000 | Total loss:   25.52 | Recon loss:    2.73 | Gauss loss:    11.4
# Epoch  9833 / 10000 | Total loss:   25.62 | Recon loss:    2.95 | Gauss loss:   11.34
# Epoch  9834 / 10000 | Total loss:   25.72 | Recon loss:    2.93 | Gauss loss:   11.39
# Epoch  9835 / 10000 | Total loss:    26.8 | Recon loss:    4.11 | Gauss loss:   11.34
# Epoch  9836 / 10000 | Total loss:   27.78 | Recon loss:    4.85 | Gauss loss:   11.46
# Epoch  9837 / 10000 | Total loss:   29.23 | Recon loss:    5.44 | Gauss loss:   11.89
# Epoch  9838 / 10000 | Total loss:   27.25 | Recon loss:    3.85 | Gauss loss:    11.7
# Epoch  9839 / 10000 | Total loss:   25.89 | Recon loss:     3.0 | Gauss loss:   11.45
# Epoch  9840 / 10000 | Total loss:   26.02 | Recon loss:    3.15 | Gauss loss:   11.43
# Epoch  9841 / 10000 | Total loss:   26.62 | Recon loss:     3.8 | Gauss loss:   11.41
# Epoch  9842 / 10000 | Total loss:   27.76 | Recon loss:    4.58 | Gauss loss:   11.59
# Epoch  9843 / 10000 | Total loss:   27.18 | Recon loss:    4.05 | Gauss loss:   11.57
# Epoch  9844 / 10000 | Total loss:   26.11 | Recon loss:    3.28 | Gauss loss:   11.41
# Epoch  9845 / 10000 | Total loss:   28.62 | Recon loss:    5.24 | Gauss loss:   11.69
# Epoch  9846 / 10000 | Total loss:   26.34 | Recon loss:    3.17 | Gauss loss:   11.58
# Epoch  9847 / 10000 | Total loss:   25.94 | Recon loss:    3.03 | Gauss loss:   11.45
# Epoch  9848 / 10000 | Total loss:   26.11 | Recon loss:    3.31 | Gauss loss:    11.4
# Epoch  9849 / 10000 | Total loss:   27.51 | Recon loss:    4.36 | Gauss loss:   11.57
# Epoch  9850 / 10000 | Total loss:   28.26 | Recon loss:    5.19 | Gauss loss:   11.53
# Epoch  9851 / 10000 | Total loss:   32.82 | Recon loss:    9.38 | Gauss loss:   11.72
# Epoch  9852 / 10000 | Total loss:   30.42 | Recon loss:    6.17 | Gauss loss:   12.12
# Epoch  9853 / 10000 | Total loss:   27.29 | Recon loss:    3.77 | Gauss loss:   11.76
# Epoch  9854 / 10000 | Total loss:   26.31 | Recon loss:    3.22 | Gauss loss:   11.55
# Epoch  9855 / 10000 | Total loss:   26.61 | Recon loss:    3.71 | Gauss loss:   11.45
# Epoch  9856 / 10000 | Total loss:   29.99 | Recon loss:    6.68 | Gauss loss:   11.65
# Epoch  9857 / 10000 | Total loss:   28.77 | Recon loss:    5.32 | Gauss loss:   11.73
# Epoch  9858 / 10000 | Total loss:   33.27 | Recon loss:    8.99 | Gauss loss:   12.14
# Epoch  9859 / 10000 | Total loss:   28.05 | Recon loss:    4.38 | Gauss loss:   11.84
# Epoch  9860 / 10000 | Total loss:   26.71 | Recon loss:    3.63 | Gauss loss:   11.54
# Epoch  9861 / 10000 | Total loss:   26.77 | Recon loss:    3.74 | Gauss loss:   11.52
# Epoch  9862 / 10000 | Total loss:   34.06 | Recon loss:   10.38 | Gauss loss:   11.84
# Epoch  9863 / 10000 | Total loss:   33.66 | Recon loss:    9.36 | Gauss loss:   12.15
# Epoch  9864 / 10000 | Total loss:   34.13 | Recon loss:    9.79 | Gauss loss:   12.17
# Epoch  9865 / 10000 | Total loss:   29.03 | Recon loss:    5.05 | Gauss loss:   11.99
# Epoch  9866 / 10000 | Total loss:   27.68 | Recon loss:    4.26 | Gauss loss:   11.71
# Epoch  9867 / 10000 | Total loss:   26.85 | Recon loss:    3.66 | Gauss loss:    11.6
# Epoch  9868 / 10000 | Total loss:   30.91 | Recon loss:    7.67 | Gauss loss:   11.62
# Epoch  9869 / 10000 | Total loss:   40.49 | Recon loss:   16.22 | Gauss loss:   12.13
# Epoch  9870 / 10000 | Total loss:   48.11 | Recon loss:   23.02 | Gauss loss:   12.55
# Epoch  9871 / 10000 | Total loss:   43.14 | Recon loss:   17.12 | Gauss loss:   13.01
# Epoch  9872 / 10000 | Total loss:   33.11 | Recon loss:    8.03 | Gauss loss:   12.54
# Epoch  9873 / 10000 | Total loss:   28.57 | Recon loss:    4.63 | Gauss loss:   11.97
# Epoch  9874 / 10000 | Total loss:   26.41 | Recon loss:     3.0 | Gauss loss:   11.71
# Epoch  9875 / 10000 | Total loss:   26.16 | Recon loss:    3.17 | Gauss loss:    11.5
# Epoch  9876 / 10000 | Total loss:   25.37 | Recon loss:     2.5 | Gauss loss:   11.44
# Epoch  9877 / 10000 | Total loss:   25.62 | Recon loss:    2.83 | Gauss loss:    11.4
# Epoch  9878 / 10000 | Total loss:   25.94 | Recon loss:    3.26 | Gauss loss:   11.34
# Epoch  9879 / 10000 | Total loss:   29.58 | Recon loss:    5.99 | Gauss loss:   11.79
# Epoch  9880 / 10000 | Total loss:   27.16 | Recon loss:     3.8 | Gauss loss:   11.68
# Epoch  9881 / 10000 | Total loss:   25.23 | Recon loss:    2.54 | Gauss loss:   11.35
# Epoch  9882 / 10000 | Total loss:   26.12 | Recon loss:    3.38 | Gauss loss:   11.37
# Epoch  9883 / 10000 | Total loss:   26.42 | Recon loss:    3.67 | Gauss loss:   11.38
# Epoch  9884 / 10000 | Total loss:   28.88 | Recon loss:    5.47 | Gauss loss:   11.71
# Epoch  9885 / 10000 | Total loss:   27.38 | Recon loss:    4.02 | Gauss loss:   11.68
# Epoch  9886 / 10000 | Total loss:   25.43 | Recon loss:    2.66 | Gauss loss:   11.39
# Epoch  9887 / 10000 | Total loss:   25.82 | Recon loss:    3.03 | Gauss loss:   11.39
# Epoch  9888 / 10000 | Total loss:   26.69 | Recon loss:    3.76 | Gauss loss:   11.46
# Epoch  9889 / 10000 | Total loss:   26.28 | Recon loss:    3.37 | Gauss loss:   11.45
# Epoch  9890 / 10000 | Total loss:   26.93 | Recon loss:    3.74 | Gauss loss:   11.59
# Epoch  9891 / 10000 | Total loss:   25.24 | Recon loss:    2.47 | Gauss loss:   11.39
# Epoch  9892 / 10000 | Total loss:   26.21 | Recon loss:     3.6 | Gauss loss:    11.3
# Epoch  9893 / 10000 | Total loss:   25.31 | Recon loss:    2.44 | Gauss loss:   11.43
# Epoch  9894 / 10000 | Total loss:   26.41 | Recon loss:    3.82 | Gauss loss:    11.3
# Epoch  9895 / 10000 | Total loss:   28.45 | Recon loss:    5.01 | Gauss loss:   11.72
# Epoch  9896 / 10000 | Total loss:   29.89 | Recon loss:    6.43 | Gauss loss:   11.73
# Epoch  9897 / 10000 | Total loss:   36.92 | Recon loss:   13.11 | Gauss loss:    11.9
# Epoch  9898 / 10000 | Total loss:   39.01 | Recon loss:   13.68 | Gauss loss:   12.67
# Epoch  9899 / 10000 | Total loss:   32.74 | Recon loss:    8.42 | Gauss loss:   12.16
# Epoch  9900 / 10000 | Total loss:   30.79 | Recon loss:    6.81 | Gauss loss:   11.99
# Epoch  9901 / 10000 | Total loss:   28.18 | Recon loss:     4.7 | Gauss loss:   11.74
# Epoch  9902 / 10000 | Total loss:   29.26 | Recon loss:    6.08 | Gauss loss:   11.59
# Epoch  9903 / 10000 | Total loss:   32.19 | Recon loss:    7.99 | Gauss loss:    12.1
# Epoch  9904 / 10000 | Total loss:   31.73 | Recon loss:    7.48 | Gauss loss:   12.12
# Epoch  9905 / 10000 | Total loss:   28.92 | Recon loss:    5.29 | Gauss loss:   11.82
# Epoch  9906 / 10000 | Total loss:   28.01 | Recon loss:    4.56 | Gauss loss:   11.73
# Epoch  9907 / 10000 | Total loss:   26.69 | Recon loss:    3.45 | Gauss loss:   11.62
# Epoch  9908 / 10000 | Total loss:   26.01 | Recon loss:    3.27 | Gauss loss:   11.37
# Epoch  9909 / 10000 | Total loss:   25.46 | Recon loss:    2.74 | Gauss loss:   11.36
# Epoch  9910 / 10000 | Total loss:   25.23 | Recon loss:    2.56 | Gauss loss:   11.34
# Epoch  9911 / 10000 | Total loss:   25.49 | Recon loss:    2.93 | Gauss loss:   11.28
# Epoch  9912 / 10000 | Total loss:   25.98 | Recon loss:    3.13 | Gauss loss:   11.43
# Epoch  9913 / 10000 | Total loss:   26.29 | Recon loss:    3.59 | Gauss loss:   11.35
# Epoch  9914 / 10000 | Total loss:   28.92 | Recon loss:    5.55 | Gauss loss:   11.68
# Epoch  9915 / 10000 | Total loss:   27.42 | Recon loss:    3.98 | Gauss loss:   11.72
# Epoch  9916 / 10000 | Total loss:   25.71 | Recon loss:    2.68 | Gauss loss:   11.52
# Epoch  9917 / 10000 | Total loss:   25.89 | Recon loss:    3.37 | Gauss loss:   11.26
# Epoch  9918 / 10000 | Total loss:    29.8 | Recon loss:    6.53 | Gauss loss:   11.63
# Epoch  9919 / 10000 | Total loss:   30.77 | Recon loss:    7.09 | Gauss loss:   11.84
# Epoch  9920 / 10000 | Total loss:   27.38 | Recon loss:    3.77 | Gauss loss:    11.8
# Epoch  9921 / 10000 | Total loss:   25.84 | Recon loss:    2.89 | Gauss loss:   11.48
# Epoch  9922 / 10000 | Total loss:    27.4 | Recon loss:    4.32 | Gauss loss:   11.54
# Epoch  9923 / 10000 | Total loss:   27.11 | Recon loss:     3.9 | Gauss loss:   11.61
# Epoch  9924 / 10000 | Total loss:   27.27 | Recon loss:    4.13 | Gauss loss:   11.57
# Epoch  9925 / 10000 | Total loss:   27.22 | Recon loss:    4.03 | Gauss loss:   11.59
# Epoch  9926 / 10000 | Total loss:   26.64 | Recon loss:     3.5 | Gauss loss:   11.57
# Epoch  9927 / 10000 | Total loss:   29.15 | Recon loss:    6.06 | Gauss loss:   11.54
# Epoch  9928 / 10000 | Total loss:   30.02 | Recon loss:    6.47 | Gauss loss:   11.78
# Epoch  9929 / 10000 | Total loss:   28.44 | Recon loss:    5.05 | Gauss loss:    11.7
# Epoch  9930 / 10000 | Total loss:   29.55 | Recon loss:    6.22 | Gauss loss:   11.67
# Epoch  9931 / 10000 | Total loss:   29.45 | Recon loss:    5.46 | Gauss loss:   11.99
# Epoch  9932 / 10000 | Total loss:   28.07 | Recon loss:    4.64 | Gauss loss:   11.71
# Epoch  9933 / 10000 | Total loss:   27.24 | Recon loss:     4.0 | Gauss loss:   11.62
# Epoch  9934 / 10000 | Total loss:   26.64 | Recon loss:    3.62 | Gauss loss:   11.51
# Epoch  9935 / 10000 | Total loss:   28.41 | Recon loss:    5.02 | Gauss loss:    11.7
# Epoch  9936 / 10000 | Total loss:   32.13 | Recon loss:    8.17 | Gauss loss:   11.98
# Epoch  9937 / 10000 | Total loss:   33.27 | Recon loss:    8.74 | Gauss loss:   12.27
# Epoch  9938 / 10000 | Total loss:    28.7 | Recon loss:    5.01 | Gauss loss:   11.84
# Epoch  9939 / 10000 | Total loss:   32.11 | Recon loss:    8.32 | Gauss loss:    11.9
# Epoch  9940 / 10000 | Total loss:   29.53 | Recon loss:    5.62 | Gauss loss:   11.96
# Epoch  9941 / 10000 | Total loss:   29.35 | Recon loss:    5.76 | Gauss loss:   11.79
# Epoch  9942 / 10000 | Total loss:   29.71 | Recon loss:    6.02 | Gauss loss:   11.85
# Epoch  9943 / 10000 | Total loss:   29.04 | Recon loss:     5.2 | Gauss loss:   11.92
# Epoch  9944 / 10000 | Total loss:   28.14 | Recon loss:    4.63 | Gauss loss:   11.76
# Epoch  9945 / 10000 | Total loss:   27.17 | Recon loss:    3.79 | Gauss loss:   11.69
# Epoch  9946 / 10000 | Total loss:   26.06 | Recon loss:    2.94 | Gauss loss:   11.56
# Epoch  9947 / 10000 | Total loss:   25.29 | Recon loss:    2.62 | Gauss loss:   11.33
# Epoch  9948 / 10000 | Total loss:   25.16 | Recon loss:    2.66 | Gauss loss:   11.25
# Epoch  9949 / 10000 | Total loss:    25.7 | Recon loss:    3.06 | Gauss loss:   11.32
# Epoch  9950 / 10000 | Total loss:   27.86 | Recon loss:    4.75 | Gauss loss:   11.56
# Epoch  9951 / 10000 | Total loss:   27.18 | Recon loss:    3.92 | Gauss loss:   11.63
# Epoch  9952 / 10000 | Total loss:   25.65 | Recon loss:    2.99 | Gauss loss:   11.33
# Epoch  9953 / 10000 | Total loss:    31.4 | Recon loss:    8.59 | Gauss loss:    11.4
# Epoch  9954 / 10000 | Total loss:    47.6 | Recon loss:   22.52 | Gauss loss:   12.54
# Epoch  9955 / 10000 | Total loss:   42.93 | Recon loss:    17.0 | Gauss loss:   12.97
# Epoch  9956 / 10000 | Total loss:   34.91 | Recon loss:   10.07 | Gauss loss:   12.42
# Epoch  9957 / 10000 | Total loss:   30.83 | Recon loss:    6.75 | Gauss loss:   12.04
# Epoch  9958 / 10000 | Total loss:   28.44 | Recon loss:    4.49 | Gauss loss:   11.97
# Epoch  9959 / 10000 | Total loss:   26.41 | Recon loss:    3.21 | Gauss loss:    11.6
# Epoch  9960 / 10000 | Total loss:   27.24 | Recon loss:    4.35 | Gauss loss:   11.44
# Epoch  9961 / 10000 | Total loss:   26.46 | Recon loss:    3.28 | Gauss loss:   11.59
# Epoch  9962 / 10000 | Total loss:   25.35 | Recon loss:    2.56 | Gauss loss:   11.39
# Epoch  9963 / 10000 | Total loss:    25.3 | Recon loss:    2.89 | Gauss loss:   11.21
# Epoch  9964 / 10000 | Total loss:   25.57 | Recon loss:    2.88 | Gauss loss:   11.35
# Epoch  9965 / 10000 | Total loss:   25.15 | Recon loss:    2.57 | Gauss loss:   11.29
# Epoch  9966 / 10000 | Total loss:   25.27 | Recon loss:     2.9 | Gauss loss:   11.18
# Epoch  9967 / 10000 | Total loss:   27.01 | Recon loss:    4.09 | Gauss loss:   11.46
# Epoch  9968 / 10000 | Total loss:   27.74 | Recon loss:    4.59 | Gauss loss:   11.57
# Epoch  9969 / 10000 | Total loss:   29.88 | Recon loss:    6.83 | Gauss loss:   11.52
# Epoch  9970 / 10000 | Total loss:   37.08 | Recon loss:   12.71 | Gauss loss:   12.19
# Epoch  9971 / 10000 | Total loss:   44.33 | Recon loss:   19.51 | Gauss loss:   12.41
# Epoch  9972 / 10000 | Total loss:    39.7 | Recon loss:   14.31 | Gauss loss:   12.69
# Epoch  9973 / 10000 | Total loss:    32.0 | Recon loss:    7.59 | Gauss loss:   12.21
# Epoch  9974 / 10000 | Total loss:   29.35 | Recon loss:     5.5 | Gauss loss:   11.92
# Epoch  9975 / 10000 | Total loss:   26.79 | Recon loss:    3.47 | Gauss loss:   11.66
# Epoch  9976 / 10000 | Total loss:   25.54 | Recon loss:    2.74 | Gauss loss:    11.4
# Epoch  9977 / 10000 | Total loss:   25.71 | Recon loss:    2.91 | Gauss loss:    11.4
# Epoch  9978 / 10000 | Total loss:   25.52 | Recon loss:    2.75 | Gauss loss:   11.38
# Epoch  9979 / 10000 | Total loss:   25.25 | Recon loss:    2.71 | Gauss loss:   11.27
# Epoch  9980 / 10000 | Total loss:    26.4 | Recon loss:    3.62 | Gauss loss:   11.39
# Epoch  9981 / 10000 | Total loss:   25.71 | Recon loss:    2.91 | Gauss loss:    11.4
# Epoch  9982 / 10000 | Total loss:   25.83 | Recon loss:    2.97 | Gauss loss:   11.43
# Epoch  9983 / 10000 | Total loss:    26.1 | Recon loss:    3.48 | Gauss loss:   11.31
# Epoch  9984 / 10000 | Total loss:    25.3 | Recon loss:    2.75 | Gauss loss:   11.27
# Epoch  9985 / 10000 | Total loss:   25.32 | Recon loss:    2.93 | Gauss loss:   11.19
# Epoch  9986 / 10000 | Total loss:   25.91 | Recon loss:    3.35 | Gauss loss:   11.28
# Epoch  9987 / 10000 | Total loss:   27.38 | Recon loss:    4.24 | Gauss loss:   11.57
# Epoch  9988 / 10000 | Total loss:   28.84 | Recon loss:    5.43 | Gauss loss:   11.71
# Epoch  9989 / 10000 | Total loss:    29.9 | Recon loss:    6.45 | Gauss loss:   11.73
# Epoch  9990 / 10000 | Total loss:   40.75 | Recon loss:   16.57 | Gauss loss:   12.09
# Epoch  9991 / 10000 | Total loss:   46.09 | Recon loss:   20.17 | Gauss loss:   12.96
# Epoch  9992 / 10000 | Total loss:    35.3 | Recon loss:   10.19 | Gauss loss:   12.55
# Epoch  9993 / 10000 | Total loss:   30.67 | Recon loss:    6.31 | Gauss loss:   12.18
# Epoch  9994 / 10000 | Total loss:   29.92 | Recon loss:    6.37 | Gauss loss:   11.78
# Epoch  9995 / 10000 | Total loss:   41.83 | Recon loss:   17.77 | Gauss loss:   12.03
# Epoch  9996 / 10000 | Total loss:   36.71 | Recon loss:    11.8 | Gauss loss:   12.46
# Epoch  9997 / 10000 | Total loss:   30.05 | Recon loss:    5.87 | Gauss loss:   12.09
# Epoch  9998 / 10000 | Total loss:   26.85 | Recon loss:    3.41 | Gauss loss:   11.72
# Epoch  9999 / 10000 | Total loss:   26.56 | Recon loss:    3.37 | Gauss loss:   11.59
# Epoch 10000 / 10000 | Total loss:   26.45 | Recon loss:    3.31 | Gauss loss:   11.57

# %%
torch.save(vae.network.state_dict(), f'smba_vae_{num_epochs}.pth')

# %%
gmvae.network.load_state_dict(torch.load(f'smba_vae_{num_epochs}.pth'))
# Out:
# <All keys matched successfully>

# %% [markdown]
# ## Image Reconstruction

# %%
original, reconstructed = vae.reconstruct_data(train_dl, len(train_ds))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-57-ce7630d052d4> in <module>
# ----> 1 original, reconstructed = vae.reconstruct_data(train_dl, len(train_ds))
#
# ~/projects/gmvae_and_gmmvae/pytorch/model/VAE.py in reconstruct_data(self, data_loader, sample_size)
#     298     # obtain values
#     299     it = iter(test_random_loader)
# --> 300     test_batch_data, _ = it.next()
#     301     original = test_batch_data.data.numpy()
#     302     if self.cuda:
#
# ValueError: not enough values to unpack (expected 2, got 1)

# %%
original_int = original.reshape(len(train_ds), 16, 16, 12).argmax(axis=-1)
reconstructed_int = reconstructed.reshape(len(train_ds), 16, 16, 12).argmax(axis=-1)

# %%
np.sum(original_int != reconstructed_int) / len(train_ds)
# Out:
# 3.095626389918458

# %%
def get_classes(chunks_int):
    classes = []
    for i in chunks_int:
        if i.max() == 6:
            classes.append('kia')
        else:
            classes.append('smba')
    return np.array(classes)

# %%
org_classes = get_classes(original_int)
rec_classes = get_classes(reconstructed_int)
assert np.sum(org_classes == rec_classes) == len(org_classes)

# %%
def get_images(chunks_int):
    images = []
    for game, chunk in zip(get_classes(chunks_int), chunks_int):
        images.append(vglc_with_path_encodings.array_to_image([chunk], game=game)[0])
    return images

# %%
org_images = get_images(original_int)
rec_images = get_images(reconstructed_int)
len(org_images), len(rec_images)
# Out:
# (15, 15)

# %%
fig, axes = plt.subplots(nrows=3, ncols=10, figsize=(24, 8))
axes = axes.flatten()
nrows, ncols = 3, 10

org_idxs = np.arange(0, 29, 2)
rec_idxs = org_idxs + 1

for idx in org_idxs:
        
    ax = axes[idx]

    ax.imshow(np.asarray(org_images[idx // 2]))
    ax.set_title(f'Org {idx // 2 + 1}')
    
    ax.axis('off')

for idx in rec_idxs:
        
    ax = axes[idx]

    ax.imshow(np.asarray(rec_images[idx // 2]))
    ax.set_title(f'Rec {idx // 2 + 1}')

    ax.axis('off')
    
plt.show()

# %% [markdown]
# ## Random Generation per Category

# %%
def display_random_generation(generated, num_classes, n=10):
    plt.figure(figsize=[24,5])
    for c in range(num_classes):
        for i in range(n):
            plt.subplot(num_classes, n, (c * n) + i + 1)
            chunk_int = generated[(c * n) + i].reshape(16, 16, 12).argmax(axis=-1)
            chunk_pix = vglc_with_path_encodings.array_to_image([chunk_int], game='smba')[0]
            plt.imshow(chunk_pix)
            plt.gray()
            plt.axis('off')
    plt.show()

elem_per_category = 15
generated = gmvae.random_generation(elem_per_category)
display_random_generation(generated, args.num_classes, elem_per_category)

# %%
generated = vae.random_generation(10000)
generated.shape
# Out:
# (10000, 3072)

# %%
generated_int = generated.reshape(-1, 16, 16, 12).argmax(axis=-1)

# %%
generated_int.shape
# Out:
# (10000, 16, 16)

# %%
# since this code chunk depends on random seed, it shouldn't be run again
with open(f'../smba_generations/smba_vae_{num_epochs}.json', 'w+') as json_f:
    json.dump(generated_int.tolist(), json_f)

# %% [markdown]
# ## Visualization of the feature latent space

# %%
# get feature representations
test_features, test_labels = gmvae.latent_features(train_dl, True)

# %%
# import TSNE from scikit-learn library
from sklearn.manifold import TSNE

# reduce dimensionality to 2D, we consider a subset of data because TSNE
# is a slow algorithm

first_n = 1000
tsne_features = TSNE(n_components=2).fit_transform(test_features[:first_n])

# %%
test_labels_subset = test_labels[:first_n]

# %%
X_, Y_ = np.s_[:,0], np.s_[:,1]

# %%
fig = plt.figure(figsize=(5, 5))

plt.scatter(tsne_features[X_], tsne_features[Y_])

plt.title('Projection from latent space to 2D')
plt.show()
